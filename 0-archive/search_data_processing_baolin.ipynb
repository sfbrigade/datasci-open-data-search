# %% [markdown]
# Search Data Processing
# =========================

# %%
import numpy as np
import pandas as pd
import pyspark
import re
import string

# %%
search_data = pd.read_csv("./data/sample_openData_searchTerms_clean.csv")

# %%
search_data.shape
# Out:
# (5000, 8)

# %%
search_data.tail()
# Out:
#                          Search Term  \
# 4995                   address range
# 4996               address shapefile
# 4997  address to geographic location
# 4998     address with resident names
# 4999                        addresse
#
#                                               Exit Page  \
# 4995  /Geographic-Locations-and-Boundaries/Streets-o...
# 4996  /browse/embed?category=&limit=20&limitTo=&q=ad...
# 4997  /browse/embed?category=&limit=20&limitTo=&q=ad...
# 4998  /browse/embed?category=&limit=20&limitTo=&q=ad...
# 4999  /browse/embed?category=&limit=20&limitTo=&q=po...
#
#       Total Unique Searches  Results Pageviews / Search % Search Exits  \
# 4995                      2                         1.5          0.00%
# 4996                      2                         1.5          0.00%
# 4997                      2                         1.0          0.00%
# 4998                      2                         1.0          0.00%
# 4999                      2                         1.0          0.00%
#
#      % Search Refinements Time after Search  Average Search Depth
# 4995                0.00%           0:02:09                   8.0
# 4996               66.67%           0:00:18                   3.0
# 4997                0.00%           0:00:03                   1.5
# 4998                0.00%           0:00:05                   1.5
# 4999              100.00%           0:00:03                   1.5

# %%
#search_data[search_data['Total Unique Searches']<5]

# %%
search_terms = list(set(search_data['Search Term']))

# %%
len(search_terms)
# Out:
# 2451

# %%
#print search_terms

# %%
search_data.ix[search_data["Search Term"] == "194415"]
# Out:
#      Search Term                                          Exit Page  \
# 3519      194415  /Economy-and-Community/Registered-Business-Loc...
#
#       Total Unique Searches  Results Pageviews / Search % Search Exits  \
# 3519                      2                           1          0.00%
#
#      % Search Refinements Time after Search  Average Search Depth
# 3519                0.00%           0:00:06                   2.5

# %%
search_terms_data = search_data[["Search Term"]]
search_terms_data = search_terms_data.rename(columns={"Search Term": "search_term"})

# %%
search_terms_data.head()
# Out:
#   search_term
# 0    business
# 1       crime
# 2       crime
# 3         311
# 4     streets

# %%
search_terms_data['processed_data'] = search_terms_data.search_term\
                                        .apply(lambda text: text.decode('ascii' ,"ignore" ).decode('utf-8','ignore'))\
                                        .apply(lambda text: text.lower())

# %%
search_terms_list =  list(set(search_terms_data.processed_data))
#print search_terms_list

# %% [markdown]
# #### We need to generally tag searches in categories of quality
#
# Many search terms indicate that users are not informed on what the purpose of the website is or how to properly use search
#
# Search Tags
# * Good Quality Search
#     * complete words or phrases
#     * minor typos
# * Bad Quality
#     * Addresses
#     * Dates
#     * Zipcodes or just a string of numbers
#     * General nonsenses eg. ('></script><script>alert(1)</script>', '///', '16exc-3031')

# %%
dates_r = re.compile('[0-9]/[0-9]/[0-9]')
numbers_r = re.compile('^[0-9][0-9]*[0-9]$')
html_r = re.compile('^<.*>$')

# %%
filter(dates_r.match, search_terms_list)
# Out:
# [u'9/1/01', u'3/1/01']

# %%
print filter(html_r.match, search_terms_list)
# Out:
# [u'</script><script>alert(1)</script>']

# %%
# removing punctuation

def removePunctuation(text):

    for c in string.punctuation:
        text = text.replace(c,"").strip().lower()
    return text

# %%
# iterative process

def text_processing(search):
    
    return [removePunctuation(i) for i in search]

# %%
search = text_processing(search_terms_list)
#search

# %%
regex = "\d{1,4}.?\d{0,4}\s[a-zA-Z|\d+]{2,30}\s[a-zA-Z]|\s[a-zA-Z]*"

f = [re.findall(regex, i) for i in search
     if re.findall(regex, i)!= [] 
     if re.findall(regex, i)[0][:3] != '311'
     ]

# http://regexlib.com/REDetails.aspx?regexp_id=430

# %%
year = [str(j) for j in range(2000,2017)]

addresses = [i for i in f if i[0][:4] not in year ]
#addresses

# %%
# applying existing code to the full data

query = pd.read_csv("./data/all_queries.csv")

# %%
query.head()
# Out:
#   ga.searchKeyword ga.searchStartPage  \
# 0            crime                 '/
# 1         business                 '/
# 2              311                 '/
# 3            crime                 '/
# 4          streets                 '/
#
#                        ga.searchAfterDestinationPage  ga.searchUniques  \
# 0                                '/data?search=crime               451
# 1                             '/data?search=business               319
# 2                                  '/data?search=311               221
# 3  '/browse/embed?Department-Metrics_Publishing-D...               200
# 4                              '/data?search=streets               169
#
#    ga.avgSearchResultViews  ga.avgSearchDepth  ga.percentSearchRefinements  \
# 0                 1.066519               0.00                     0.000000
# 1                 1.106583               0.00                     0.000000
# 2                 1.135747               0.00                     0.000000
# 3                 1.070000               4.54                    12.149533
# 4                 1.047337               0.00                     0.000000
#
#    ga.searchDuration  ga.searchExitRate
# 0                 62                  0
# 1                  5                  0
# 2                  7                  0
# 3              48646                  0
# 4                  3                  0

# %%
query.shape
# Out:
# (116339, 9)

# %%
# seeing the data

query_list =  list(query['ga.searchKeyword'].values)
query_list = [str(word).decode('ascii' ,"ignore" ).decode('utf-8','ignore') for word in query_list]

# %%
set_query = len(set(query_list))
set_query
# Out:
# 20600

# %%
#adresses
regex = "\d{1,4}.?\d{0,4}\s[a-zA-Z|\d+|\W+]{2,30}\s[a-zA-Z]{2,15}"

full = [re.findall(regex, i) for i in query_list
     if re.findall(regex, i)!= [] 
     if re.findall(regex, i)[0][:3] != '311'
     ]

# %%
len(full)
# Out:
# 1967

# %%
full
# Out:
# [[u'2010 census tracts'],
#  [u'460 forms Schedule'],
#  [u'1010 fitzgerald ave, san francisco, ca'],
#  [u'1600 California street'],
#  [u'1996-2013 city survey'],
#  [u'2 hour parking'],
#  [u'2 hour parking'],
#  [u'2011 herrera campaign contributions'],
#  [u'2012 SFO Customer Survey'],
#  [u'2013 housing inventory'],
#  [u'2598 Mission Street'],
#  [u'405 howard st'],
#  [u'5 thomas mellon circle'],
#  [u'2000 Blocks (no water'],
#  [u'2000 Blocks (no water'],
#  [u'2000 Tracts (no water'],
#  [u'2000 Tracts (no water'],
#  [u'2000 Blocks (no water'],
#  [u'2000 blocks (no water'],
#  [u'2000 tracts (no water'],
#  [u'2000 tracts (no water'],
#  [u'120 lake street'],
#  [u'0 Beatrice Rd, Brisbane, CA'],
#  [u'19/2015 dashiell hammet'],
#  [u'1 Embarcadero San Francisco'],
#  [u'1 Hawkins Ln SF CA'],
#  [u'1 Longview Court'],
#  [u'1 Polk st'],
#  [u'1 Tuscany Alley'],
#  [u'1 hour parking'],
#  [u'1 post st'],
#  [u'1 scott street'],
#  [u'1 south van ness ave'],
#  [u'1 south vanness'],
#  [u'1. BRIAN DUSSEAULT'],
#  [u'10 gb dataset'],
#  [u'10 glendale street'],
#  [u'100 church street'],
#  [u'100 delano ave'],
#  [u'100 year flood'],
#  [u'100 year flood plain'],
#  [u'100 year storm flood plain'],
#  [u'1000 Sutter Street'],
#  [u'1000 brannan street'],
#  [u'1000 howard st'],
#  [u'1008 Santiago street, san francisco'],
#  [u'101 SAN ALESO AVENIE'],
#  [u'101 utah street'],
#  [u'1023 vallejo street'],
#  [u'1033 polk street'],
#  [u'1040 howard st'],
#  [u'1049 Market Street'],
#  [u'1050 Sansome St'],
#  [u'1051 de haro'],
#  [u'1051 grant ave, sf'],
#  [u'1051 market st'],
#  [u'106 Powell Street'],
#  [u'106 grand view'],
#  [u'1071 Alabama St'],
#  [u'110 sylvan drive, san francisco'],
#  [u'1100 divisadero st'],
#  [u'11025 Carolina Place Pkwy, Pineville'],
#  [u'11025 Carolina Place Pkwy, Pineville', u'8134, United States'],
#  [u'111 4th ave'],
#  [u'111 Ellis Street'],
#  [u'111 powell street'],
#  [u'112 7th street'],
#  [u'1122 Vallejo St'],
#  [u'1125 17th avenue'],
#  [u'1131 Mission St'],
#  [u'114 Henry street'],
#  [u'114 powell street, san francisco, ca'],
#  [u'1146a Guerrero Street, San Francisco'],
#  [u'1155 folsom at'],
#  [u'1155 folsom st'],
#  [u'1158 noe street'],
#  [u'1160 Mission St, San Francisco, cA'],
#  [u'1177 California st'],
#  [u'1188 Harrison Street'],
#  [u'1188 Harrrison Street'],
#  [u'12 hillview court'],
#  [u'1218 44th Ave., San Francisco'],
#  [u'122 farallones st'],
#  [u'1225 17th avenue'],
#  [u'123 Retiro way'],
#  [u'1230 markert st'],
#  [u'1230 market st'],
#  [u'1231 20th ave, san francisco'],
#  [u'1231 MArket St'],
#  [u'1235 Florida Street'],
#  [u'1238 39th avenue'],
#  [u'124 Molimo dr'],
#  [u'126 fillmore street'],
#  [u'126 fillmore stret'],
#  [u'127 san jose ave'],
#  [u'129 randall st'],
#  [u'13 Melrose ave'],
#  [u'13 Melrose ave'],
#  [u'13 Melrose ave'],
#  [u'1300 block of mcallister'],
#  [u'131 Franklin street'],
#  [u'132 corbett ave'],
#  [u'1327 Leavenworth St'],
#  [u'1328a kobbe avenue'],
#  [u'1343 28th avenue'],
#  [u'135 Post Street'],
#  [u'135 seacliff ave'],
#  [u'1355 market street san francisco'],
#  [u'1358 28th avenue, san francisco, ca'],
#  [u'1359 sacramento st'],
#  [u'136 arlington street'],
#  [u'136 rivoli street'],
#  [u'1363 alabama street'],
#  [u'1365 Noriega Street'],
#  [u'138 03rd street'],
#  [u'1381 quesada avenue'],
#  [u'1385 carroll ave'],
#  [u'1390 market street'],
#  [u'140 mason street'],
#  [u'140 new Montgomery st'],
#  [u'140 new Montgomery st'],
#  [u'1405 Van Ness Ave'],
#  [u'1407 EGBERT STREET SAN FRANCISCO'],
#  [u'1409 EGBERT STREET SAN FRANCISCO'],
#  [u'141 Milton Street'],
#  [u'141 Milton Street San Francisco, CA'],
#  [u'141 Milton Street San Francisco, CA'],
#  [u'141 eddy street'],
#  [u'141 eddy street sf ca'],
#  [u'1412 hudson ave'],
#  [u'1415 scott street'],
#  [u'1416 polk street'],
#  [u'1420 5th Ave., san francisco, ca'],
#  [u'1423 golden gate'],
#  [u'1426 48th avenue'],
#  [u'1427 11th Ave'],
#  [u'1428 jackson st'],
#  [u'1432 grove street san francisco ca'],
#  [u'1439 16th ave'],
#  [u'1442 43rd ave'],
#  [u'1443 46th ave'],
#  [u'1444 market st'],
#  [u'1450 green st'],
#  [u'1453 mission st'],
#  [u'1453 mission street'],
#  [u'1455 Custer Street'],
#  [u'146 galewood circle'],
#  [u'1480 larkin st'],
#  [u'150 Lawrence Ave'],
#  [u'150 Lawrence Ave san francisco'],
#  [u'1500 Mission Street'],
#  [u'1500 mc allister street san francisco'],
#  [u'1500 mc allister street san francisco'],
#  [u'1514 alemany blvd'],
#  [u'1515 s. van ness'],
#  [u'1523 guerrero st'],
#  [u'153 college ave'],
#  [u'155 arbor st'],
#  [u'155 park st san francsico ca'],
#  [u'1560 8th ave'],
#  [u'1560 howard street'],
#  [u'1560 howard stret'],
#  [u'1578 Newhall St. San Francisco'],
#  [u'158 maynarad st'],
#  [u'160 Swiss Avenue'],
#  [u'1600 California street'],
#  [u'1600 Fell street'],
#  [u'162 landers st'],
#  [u'163 Liberty Street'],
#  [u'163 Ney St'],
#  [u'163 russ st'],
#  [u'1630 30th Avenue'],
#  [u'1660 Stockton at'],
#  [u'1660 Stockton street'],
#  [u'1683 42nd Ave, San Francisco CA'],
#  [u'1683 7th avenue'],
#  [u'169 Steuart St'],
#  [u'169 Steuart St; San Francisco, CA'],
#  [u'169 Steuart St; San Francisco, CA'],
#  [u'1693 7th avenue'],
#  [u'17 San Andreas Way, San francisco'],
#  [u'17 Silverview Drive'],
#  [u'1700 Newhall street'],
#  [u'1700 Owens street'],
#  [u'1700 california st'],
#  [u'1709 Broderick St, San Francisco, CA'],
#  [u'1709 Broderick Street'],
#  [u'1738 Ocean Avenue San Francisco, CA'],
#  [u'1740 Cesar Chavez'],
#  [u'1740 Cesar Chavez'],
#  [u'1746 Church Street, San Francisco'],
#  [u'175 Ney Street'],
#  [u'1755 clay st'],
#  [u'177 Stillman St'],
#  [u'177 Stillman Street'],
#  [u'177 Stillman Street report'],
#  [u'177 Stillman Street report'],
#  [u'177 Stillman Street, San Francisco'],
#  [u'177 Stillman Street, San Francisco'],
#  [u'177 Stillman Street, San Francisco'],
#  [u'177 stillman st. sf'],
#  [u'177 stillman st., san francisco, ca'],
#  [u'1773 chestnut st'],
#  [u'1798 grove street'],
#  [u'1798 grove street'],
#  [u'18 latona st'],
#  [u'1801 silliman st'],
#  [u'1805 S. Van Ness'],
#  [u'1813 15th Street'],
#  [u'186 valley street'],
#  [u'1865 4th St, San Francisco'],
#  [u'1895 sacramento st'],
#  [u'19 rausch street'],
#  [u'1900 ferry route'],
#  [u'1917 Broderick street'],
#  [u'1931 35th Ave San Francisco, CA'],
#  [u'1939 Oakdale Ave'],
#  [u'1941 ocean avenue San Francisco California'],
#  [u'1951 oak st'],
#  [u'1952 larkin street'],
#  [u'1970 census block'],
#  [u'1975 Jim Jones'],
#  [u'1977 20th Avenue San Francisco ca'],
#  [u'198 waterville street, san francisco'],
#  [u'199 new Montgomery'],
#  [u'199 new Montgomery st'],
#  [u'199 new montgomery'],
#  [u'1994 Carroll Avenue'],
#  [u'1994 Union St'],
#  [u'1996-2011 City Survey Database'],
#  [u'1996-2013 SF City Survey'],
#  [u'1996-2013 city survey data'],
#  [u'2 Crestline Dr'],
#  [u'2 bedroom homesale'],
#  [u'2 casa way'],
#  [u'2 hour parking'],
#  [u'2 hour parking'],
#  [u'2 hour street parking 2999 California'],
#  [u'2 plus 2 bookeeping'],
#  [u'20 Roussea Street'],
#  [u'20 jones st'],
#  [u'200 6th st'],
#  [u'200 hazelwood ave'],
#  [u'200 mississippi street'],
#  [u'2000 census shapefile'],
#  [u'2000 census tract'],
#  [u'2000 census tract shapefile'],
#  [u'2000 census tracts'],
#  [u'2000 census tracts'],
#  [u'2000 population density'],
#  [u'2004 bicycle network'],
#  [u'2004 bike network'],
#  [u'2004 food vendors'],
#  [u'2005 Pipeline Report'],
#  [u'2005 housing inventory'],
#  [u'2005 housing inventory'],
#  [u'2007 housing inventory'],
#  [u'2007 housing inventory'],
#  [u'2008 crime data'],
#  [u'2009 housing inventory'],
#  [u'201 Hale Street'],
#  [u'2010 census block'],
#  [u'2010 census block centroids'],
#  [u'2010 census house hold data by taz'],
#  [u'2010 census population'],
#  [u'2010 census tracts'],
#  [u'2010 census tracts no water'],
#  [u'2010 map:crime incidents'],
#  [u'2010 population shapefile'],
#  [u'2010 tract population'],
#  [u'2010 us census data'],
#  [u'2010 vehicle ownership'],
#  [u'2011 Customer Survey Dataset'],
#  [u'2011 herrera campaign contributions'],
#  [u'2011 herrera mayor campaign contributions'],
#  [u'2011 mayor campaign contributions'],
#  [u'2011 pipeline report'],
#  [u'2012 Housing Inventory'],
#  [u'2012 SFO Customer Survey'],
#  [u'2012 campaign finance'],
#  [u'2012 campaign finance'],
#  [u'2012 campaign finance'],
#  [u'2012 census population'],
#  [u'2012 housing inventory'],
#  [u'2012 housing inventory'],
#  [u'2013 City Survey Report'],
#  [u'2013 Housing Inventory'],
#  [u'2013 SFO Customer Survey'],
#  [u'2013 building permits'],
#  [u'2013 census shapefile'],
#  [u'2013 housing inventory'],
#  [u'2013 housing inventory'],
#  [u'2013 sfpd incidents'],
#  [u'2014 City Serve report'],
#  [u'2014 Housing Inventory'],
#  [u'2014 census tracts'],
#  [u'2014 energy benchmark 285 geary'],
#  [u'2014 housing inventory'],
#  [u'2014 housing inventory'],
#  [u'2014 housing inventory'],
#  [u'2014 housing inventory'],
#  [u'2014 housing inventory'],
#  [u'2014 map:crime incidents'],
#  [u'2014 q4 planning pipeline'],
#  [u'2015 311 budget'],
#  [u'2015 Crime Statistics'],
#  [u'2015 Form 460; Schedule'],
#  [u'2015 Housing Inventory'],
#  [u'2015 Housing Inventory'],
#  [u'2015 Housing Inventory'],
#  [u'2015 Murder by race statistics'],
#  [u'2015 Neighborhood profiles'],
#  [u'2015 Q4 pipeline'],
#  [u'2015 budget information'],
#  [u'2015 city survey'],
#  [u'2015 crime statistics'],
#  [u'2015 enacted budget'],
#  [u'2015 housing inventory'],
#  [u'2015 housing inventory'],
#  [u'2015 residential development pipeline'],
#  [u'2016 Assessor map'],
#  [u'2016 Assessor map updates'],
#  [u'2016 Feb 26 arrests in bay view'],
#  [u'2016 budget publication'],
#  [u'2016 housing development'],
#  [u'201o census population'],
#  [u'2020 Ellis st'],
#  [u'2021 baker st'],
#  [u'203 Cotter st'],
#  [u'2030 alemany blvd'],
#  [u'205 Upper Terrace'],
#  [u'2079 15TH AVENUE'],
#  [u'208 caselli ave'],
#  [u'2090 Evans Avenue'],
#  [u'2096 castro street'],
#  [u'2124 Great Hwy'],
#  [u'2130 22nd St San Francisco CA'],
#  [u'2130 JAckson street'],
#  [u'2134 GREEN STREET #3 SAN FRANCISCO, CA'],
#  [u'2135 mission street'],
#  [u'2145 19th Ave, San Francisco, CA'],
#  [u'215 Niagara Ave Permit Parking'],
#  [u'2166 32nd ave'],
#  [u'2172 Pacific Avenue'],
#  [u'2174 California Street'],
#  [u'2190 Lombard St, San Francisco, CA'],
#  [u'220 30th Ave'],
#  [u'2200 market permit'],
#  [u'2201 Market Street'],
#  [u'2208 MISSION STREET'],
#  [u'2208 Mission Street'],
#  [u'221 san carlos'],
#  [u'2211 stockton st'],
#  [u'224 ordway st'],
#  [u'2240 Market Street'],
#  [u'2243 32nd Avenue'],
#  [u'2250 POWELL STREET'],
#  [u'2259 25th ave'],
#  [u'2275 sutter st'],
#  [u'2279 Mission Street'],
#  [u'2282 Market Street'],
#  [u'2282 market st'],
#  [u'2282 market street'],
#  [u'2283 37th ave'],
#  [u'230 Eddy Street'],
#  [u'2310 mason street'],
#  [u'2325 Pine Street'],
#  [u'233 San Carlos'],
#  [u'2332 TARAVAL ST SF'],
#  [u'2338 TARAVAL ST SF'],
#  [u'2349 Francisco St'],
#  [u'235 Presidio Avenue'],
#  [u'2385 bush st'],
#  [u'2385 bush street'],
#  [u'239 carl street'],
#  [u'2394 Mariner Square Drive, Alameda, CA'],
#  [u'240 2nd Street'],
#  [u'240 Dolores St'],
#  [u'2400 14th avenue'],
#  [u'2400 CALIFORNIA ST SAN FRANCISCO CA'],
#  [u'2412 Harrison st'],
#  [u'245 San Jose'],
#  [u'2455 Polk Street'],
#  [u'246 2nd street'],
#  [u'2462 30th street'],
#  [u'250 Executive park'],
#  [u'2500 bryant st, san francisco ca'],
#  [u'251 frederick st'],
#  [u'252 27TH Ave, San Francisco, CA'],
#  [u'255 King Stree'],
#  [u'256 Fowler Ave'],
#  [u'2577 1/2 post street'],
#  [u'258 9 th st'],
#  [u'258 9th st'],
#  [u'26 eagle street'],
#  [u'260 church st'],
#  [u'2650 green, Sf'],
#  [u'2652 Harrison St'],
#  [u'2652 Harrison St'],
#  [u'2660 San Bruno Avenue, San Francisco'],
#  [u'267 Green Street'],
#  [u'267 Green Street'],
#  [u'269 joost ave'],
#  [u'2695 43rd avenue'],
#  [u'270 McAllister Street'],
#  [u'270 McAllister Street, San Francisco'],
#  [u'277 Columbus Ave'],
#  [u'278 states street'],
#  [u'280 circular ave'],
#  [u'282 harbor rd san francsico, ca'],
#  [u'284 12th avenue'],
#  [u'285 geary st'],
#  [u'285 geary st energy audit'],
#  [u'288 GOLD MINE DRIVE'],
#  [u'29 Downey st'],
#  [u'2901 sacramento st'],
#  [u'2911 16th st police'],
#  [u'2912 19th ave'],
#  [u'2915 Octavia St'],
#  [u'2919 folsom st'],
#  [u'2919 folsom st'],
#  [u'2919 mission street'],
#  [u'2919-21 folsom st'],
#  [u'2922 sacramento street'],
#  [u'2923 lawton st'],
#  [u'2945 baker st apt'],
#  [u'2950 Vallejo st, sf'],
#  [u'2950 valajo st, sf'],
#  [u'299 Fremont Street'],
#  [u'3 buena vista ave east, sf'],
#  [u'3 rudden avenue sf ca'],
#  [u'300 sea cliff'],
#  [u'3000 Washington Street 4000 Washington'],
#  [u'3008 18th street'],
#  [u'301 Claremont Blvd'],
#  [u'301 baltimore way'],
#  [u'301 king st'],
#  [u'3024 mission st'],
#  [u'3024 mission st'],
#  [u'3060 16th Street'],
#  [u'3060 16th Street building'],
#  [u'3067 25th street'],
#  [u'3067 25th street san francisco ca'],
#  [u'307 Niagra Ave'],
#  [u'308 Font blvd'],
#  [u'3092 16th St'],
#  [u'31 Mullen ave'],
#  [u'313 POTRERO AVE'],
#  [u'3130 Webster St San Francisco, CA'],
#  [u'3139 mission street'],
#  [u'3143 folsom st'],
#  [u'315 28th avenue'],
#  [u'317 oak park dr'],
#  [u'3180 18th Street, San Francisco, CA'],
#  [u'32 richland avenue steven holland'],
#  [u'321 marietta drive'],
#  [u'322 30th ave'],
#  [u'323 cumberland st'],
#  [u'324 arkansas st'],
#  [u'3247 reserve ct, san jose, ca'],
#  [u'329 bryant street san francisco, ca'],
#  [u'33 Albion Street'],
#  [u'33 allston way'],
#  [u'331 jersey st'],
#  [u'331 jersey st parcel map'],
#  [u'3314 STEINER ST'],
#  [u"333 O'Farrell St, San Francisco, CA"],
#  [u'333 lake street'],
#  [u'333 market street'],
#  [u'333 market street energy'],
#  [u'3333 California Street'],
#  [u'334 harriet st'],
#  [u'336 moraga ave'],
#  [u'337 spurce st san francisco ca'],
#  [u'337 spurce streeet'],
#  [u'337 spurce street'],
#  [u'340 church st'],
#  [u'340 mason street'],
#  [u'340 mason street investors'],
#  [u'340 warren drive san francisco, ca'],
#  [u'3401 clement st'],
#  [u'342 24th ave'],
#  [u'3434 21st st'],
#  [u'3440 Broderick Street'],
#  [u'345 Williams Avenue'],
#  [u'345 Williams Avenue, San Francisco'],
#  [u'345 spear st'],
#  [u'3465 25th st'],
#  [u'347 precita Ave San Francisco CA'],
#  [u'347-349 Precita Ave'],
#  [u'3490 20th st'],
#  [u'350 2nd st'],
#  [u'350 laurel st san francisco'],
#  [u'350 mission street'],
#  [u'3520 18th partners'],
#  [u'3520 18th partners Business Account Number'],
#  [u'353 BEACH RD, BURLINGAME, CA'],
#  [u'354 Peralta Street'],
#  [u'355 1st street'],
#  [u'355 Bocana Street'],
#  [u'355 Serrano dr'],
#  [u'357 Hayes St'],
#  [u'360 somerset st'],
#  [u'360 somerset street'],
#  [u'361 3rd ave'],
#  [u'372 Point Lobos Ave'],
#  [u'374 5th street san francisco'],
#  [u'375 bush street'],
#  [u'3750 18 street sf ca'],
#  [u'376 ellis street'],
#  [u'3800 16th street san francisco, ca'],
#  [u'3864 23rd street'],
#  [u'3864 23rd street ban'],
#  [u'387 ellis street'],
#  [u'387 ellis street, san francisco, ca'],
#  [u'390 Fremont St'],
#  [u'390 diamond street'],
#  [u'3938 Geary Blvd. San Francisco, CA'],
#  [u'3951 Mission St'],
#  [u'3953 24th street'],
#  [u'397 9th St'],
#  [u'3D Building Model'],
#  [u'3D building model'],
#  [u'3D building models'],
#  [u'3D building models'],
#  [u'3D public art'],
#  [u'3d building model'],
#  [u'4 PERSIA AVENUE'],
#  [u'40 Annapolis Terrace, San Francisco'],
#  [u'40 genebern way, sf'],
#  [u'40 jessie street'],
#  [u'400 Castro Street'],
#  [u'400 Castro soul cycle'],
#  [u'400 Duboce Street'],
#  [u'405 howard st'],
#  [u'4058 17th st'],
#  [u'407 jackson st'],
#  [u'407 sanchez street'],
#  [u'409 Dolores Street'],
#  [u'41 genebern way, sf'],
#  [u'4130 mission street'],
#  [u'4130 mission street'],
#  [u'415 Euclid Ave'],
#  [u'415 Jones St'],
#  [u'415 myra way'],
#  [u'4175 Mission St'],
#  [u'418 Jessie St'],
#  [u'4182 Mission Street'],
#  [u'42 jules avenue'],
#  [u'424 octavia st'],
#  [u'425 10th st'],
#  [u'425 market energy'],
#  [u'425 market street'],
#  [u'425 market street energy'],
#  [u'428 chicago way'],
#  [u'43 ruth street, san francisco'],
#  [u'430 lake st'],
#  [u'439 Duboce Ave'],
#  [u'44 samoset st'],
#  [u'442 holloway ave., SF'],
#  [u'4431 mission st'],
#  [u'444 de haro st'],
#  [u'444 townsend st'],
#  [u'447 Broadway Street'],
#  [u'450 golden gate'],
#  [u'450 golden gate'],
#  [u'453 masonic st'],
#  [u'456 montgomery street suite 2200 san'],
#  [u'459 geary LLC'],
#  [u'46 El Sereno Court'],
#  [u'460 dwight street'],
#  [u'460 forms Schedule'],
#  [u'460 forms Schedule'],
#  [u'460 forms Schedule'],
#  [u'460 forms Schedule'],
#  [u'460 forms Schedule'],
#  [u'460 forms schedul'],
#  [u'460 forms schedula'],
#  [u'460 forms schedule'],
#  [u'460 forms schedule'],
#  [u'460 forms schedule'],
#  [u'460 forms schedule'],
#  [u'460 post street'],
#  [u'460 post street business search'],
#  [u'4610 mission street'],
#  [u'462 DOUGLASS SR'],
#  [u'462 DOUGLASS ST'],
#  [u'466 9th avenue'],
#  [u'4689 mission st'],
#  [u'469 eddy street'],
#  [u'469 union st'],
#  [u'470 lake st'],
#  [u'476 Ellington Ave'],
#  [u'476 Ellington ave'],
#  [u'478 utah st'],
#  [u'487 dolores st'],
#  [u'487 dolores street'],
#  [u'49 Christopher Dr, San Francisco, CA'],
#  [u'49 Christopher Dr, San Francisco, CA'],
#  [u'49 mile scenic drive'],
#  [u'49 south park st'],
#  [u'490 POST ST'],
#  [u'495 geary street'],
#  [u'5 DAY WATER RELATED'],
#  [u'5 Hudson Ct, San Francisco, CA'],
#  [u'5 year plan'],
#  [u'50 Main Street, San Francisco'],
#  [u'50 quint street'],
#  [u'501 The Embarcadero; San Francisco'],
#  [u'501 columbus Ave'],
#  [u'5060 WEST 14TH STREET GREELEY CO'],
#  [u'508 Haight st'],
#  [u'519 capp street san francisco'],
#  [u'521 clement street'],
#  [u'525 29th st'],
#  [u'5252 mission street'],
#  [u'527 42nd ave'],
#  [u'530 Brannan Street'],
#  [u'530 brannan street'],
#  [u'530 brannan street business lincenses'],
#  [u'5300 3rd street'],
#  [u'534 4th street'],
#  [u'5400 mission san francisco'],
#  [u'5413 Hillside av.,el cerrito'],
#  [u'5413 Hillside av.,el cerrito'],
#  [u'543 19TH AVE'],
#  [u'543 columbus Ave'],
#  [u'544 Castro St'],
#  [u'545 sutter street, san francisco'],
#  [u'548 Banks St, San Francisco'],
#  [u'55 Cyril Magnin Street'],
#  [u'550 3rd street san francisco ca'],
#  [u'550 Van Ness'],
#  [u'554 irving street, san francisco'],
#  [u'555 4th st'],
#  [u'555 market street'],
#  [u'555 minnesota street'],
#  [u'56 moss st'],
#  [u'560 davis st san francisco'],
#  [u'560 mission street'],
#  [u'562 Monterey Blvd, San Francisco, CA'],
#  [u'568 Brannan St'],
#  [u'573 andover street'],
#  [u'576 natoma st, san francisco, ca'],
#  [u'579 Teresita Blvd'],
#  [u'5800 3rd St'],
#  [u'584 filbert street'],
#  [u'589 Post St, San Francisco, CA'],
#  [u'595 Market Street, San Francisco, CA'],
#  [u'60 Garcia ave'],
#  [u'60 agua way'],
#  [u'600 Van Ness'],
#  [u'600 fell st'],
#  [u'600 san bruno ave'],
#  [u'601 laguna street'],
#  [u'601 van ness ave'],
#  [u'606 post street'],
#  [u'610 page street'],
#  [u'619 Missouri St., San Francisco, CA'],
#  [u'619 union street'],
#  [u'62 Allston way'],
#  [u'62 linden avenue, san bruno, ca'],
#  [u'62 washburn st'],
#  [u'620 Green Street'],
#  [u'622 Green Street'],
#  [u'625 46th ave'],
#  [u'626 Green Street'],
#  [u'631 cole st'],
#  [u'631 folsom st'],
#  [u'64 Perine Place, Sf'],
#  [u'650 40th ave'],
#  [u'654 46th Avenue'],
#  [u'663 haight street'],
#  [u'665 pine st'],
#  [u'67 Silverview Drive'],
#  [u'675 Naples Street'],
#  [u'677 page st'],
#  [u'677-679 page st'],
#  [u'679 Page STreet'],
#  [u'679 san jose san Francisco'],
#  [u'68 cervantes blvd'],
#  [u'689 20th avenue'],
#  [u'690 folsom street'],
#  [u'690 long bridge street'],
#  [u'700 pennsylvania ave'],
#  [u'701 GOLDEN GATE AV'],
#  [u'701 Minnesota street'],
#  [u'701 Teresita San Francisco, CA'],
#  [u'705 vallejo street'],
#  [u'709 geary st'],
#  [u'71 ford st'],
#  [u'711 clayton st'],
#  [u'72 hour parking restriction'],
#  [u'721 18th avenue'],
#  [u'729 Shotwell St'],
#  [u'735 fell street'],
#  [u'739 Washington Street, Suite'],
#  [u'74 6th Street'],
#  [u'74 granada avenue san francisco'],
#  [u'744 MONTGOMERY ST'],
#  [u'749-757 Jackson St'],
#  [u'75 Dore Street'],
#  [u'750 Sutter St, San Francisco, CA'],
#  [u'754 moultrie group'],
#  [u'755 union st'],
#  [u'755 union st owner name'],
#  [u'760 Geary Steet'],
#  [u'766 vallejo street'],
#  [u'77 beale street buildings'],
#  [u'77 san juan ave'],
#  [u'78 Ina Court'],
#  [u'79 Midcrest Way'],
#  [u'80.004 Employee Compensation report'],
#  [u'800 university avenue, palo alto, california'],
#  [u'810 Dolores san francisco, ca'],
#  [u'810 clay street, san francisco, ca'],
#  [u'812 Guerrero Street'],
#  [u'815 laguna honda'],
#  [u'820 jones street'],
#  [u'822 Irving St'],
#  [u'823 lake street'],
#  [u'829 york street'],
#  [u'83 leo street'],
#  [u'83 mc allister st 513, san francisco'],
#  [u'83 mc allister st, san francisco, ca'],
#  [u'83 mcallister st, san francisco'],
#  [u'8300 Oceanview Terrace'],
#  [u'8300 Oceanview Terrace, 304, San Francisco'],
#  [u'838 detroit street'],
#  [u'838 grant ave'],
#  [u'846 Junipero Serra blvd'],
#  [u'855 folsom st, san francisco'],
#  [u'857 39th Ave'],
#  [u'882 31st ave'],
#  [u'887 45th ave'],
#  [u'887 4th ave'],
#  [u'899 Howard Street San Francisco, CA'],
#  [u'9 county boundary'],
#  [u'9 geneva ave'],
#  [u'9 geneva ave'],
#  [u'90 day cases'],
#  [u'916 pine street'],
#  [u'929 oak st'],
#  [u'929 oak st., sf, ca'],
#  [u'933 treat ave'],
#  [u'939 jackson st'],
#  [u'94 stratford drive'],
#  [u'944 treat av'],
#  [u'944 treat ave'],
#  [u'944 treat avenue'],
#  [u'959 noe street'],
#  [u'960 howard street'],
#  [u'970 key ave'],
#  [u'595 Market Street, San Francisco, CA'],
#  [u'460 - Schedule A - Monetary Contributions'],
#  [u'460 - Schedule E - Payments Made'],
#  [u'460 - Schedule a - Payments Made'],
#  [u'465 - Supplemental Independent Expenditure',
#   u'3 - Independent Expenditures Made',
#   u'3, 2015 Election'],
#  [u'460 cover Page'],
#  [u'460 cover Page'],
#  [u'4 2014 Election'],
#  [u'2000 Block Group'],
#  [u'2000 Blocks (no water'],
#  [u'2000 Blocks (no water'],
#  [u'2000 Blocks (no water'],
#  [u'2000 Blocks (no water) Census'],
#  [u'2000 Tracts (no water'],
#  [u'2000 Tracts (no water'],
#  [u'2000 Tracts (no water'],
#  [u'2000 Tracts (no water'],
#  [u'2000 Tracts (no water'],
#  [u'2000 block group'],
#  [u'2010: Census Block Groups'],
#  [u'2015 in San Francisco'],
#  [u'5 year plan'],
#  [u'202 24th ave sf'],
#  [u'355 24th ave'],
#  [u'2. Increase jobs that provide healthy'],
#  [u'65 AND OLDER'],
#  [u'14 Street Sidewalk Evaluation Results'],
#  [u'2130 22nd St San Francisco CA'],
#  [u'90 day emergency shelter waitlist'],
#  [u'90 day emergency shelter waitlist'],
#  [u'38 Air Pollutant Exposure Zone'],
#  [u'1975 Jim Jones'],
#  [u'98 battery st suite'],
#  [u'98 battery st suite'],
#  [u'15% fund raising target'],
#  [u'403 main st'],
#  [u'65 in zip code'],
#  [u'65 in zip code'],
#  [u'65 in zip code'],
#  [u'2 2015 pipeline'],
#  [u'5m water rise'],
#  [u'5m water rise'],
#  [u'5m water rise'],
#  [u'445 Athens Street'],
#  [u'445 Athens Street'],
#  [u'445 Athens Street'],
#  [u'83 California State Plane Zone'],
#  [u'88 INVESTMENT PARTNERS, LLC'],
#  [u'2 hour street parking 2999 California'],
#  [u'39 liveaboard marina'],
#  [u'1 2015 pipline'],
#  [u'700) - Filers with unpaid late filing'],
#  [u'700) Filers with unpaid late filing fees'],
#  [u'700) Non Filers'],
#  [u'388 Market Street, Suite'],
#  [u'0 Miles 1 Note: For Neighborhood Commercial',
#   u'5: Generalized Neighborhoods Commercial',
#   u'00 Use: ArcMap 1:70,650 scale for this'],
#  [u'0 Miles 1 Note: For Neighborhood Commercial',
#   u'5: Generalized Neighborhoods Commercial',
#   u'00 Use: ArcMap 1:70,650 scale for this'],
#  [u'2010 Demographic Profile Data, SF County'],
#  [u'201 california llc'],
#  [u'201 california owner llc'],
#  [u'2015 richmond district'],
#  [u'1000 feet school'],
#  [u'32 richland avenue'],
#  [u'2000 Block group'],
#  [u'2000 Tracts (no water'],
#  [u'2000 block (no water'],
#  [u'2000 block goup'],
#  [u'2000 block group'],
#  [u'2000 block group'],
#  [u'2000 block group'],
#  [u'2000 blocks (no water'],
#  [u'2000 blocks (no water'],
#  [u'2000 blocks (no water'],
#  [u'2000 blocks (no water'],
#  [u'2000 blocks (no water'],
#  [u'2000 blocks (no water'],
#  [u'2000 blocks (no water'],
#  [u'2000 blocks no water'],
#  [u'2000 blocks no water'],
#  [u'2000 no water'],
#  [u'2000 no water'],
#  [u'2000 no water'],
#  [u'2000 tracts (no water'],
#  [u'2000 tracts (no water'],
#  [u'2000 tracts (no water'],
#  [u'2000 tracts (no water'],
#  [u'2000 tracts (no water'],
#  [u'2000 tracts (no water'],
#  [u'2000 tracts no water'],
#  [u'2000 tracts no water'],
#  [u'2010 block groups'],
#  [u'2010 block groups'],
#  [u'2010 census block for san francisco'],
#  [u'2010 census block for san francisco'],
#  [u'2010 census blocks'],
#  [u'2010 census blocks for san francisco'],
#  [u'2010 census blocks for san francisco'],
#  [u'2010: census blocks'],
#  [u'2010: census blocks for san'],
#  [u'2010: census blocks for san'],
#  [u'2010: census blocks for san francisco'],
#  [u'2010: census blocks for san francisco'],
#  [u'2000 no water'],
#  [u'2000 tracts (no water'],
#  [u'2000 no water'],
#  [u'5 zip codes'],
#  [u'2009 sfo survey'],
#  [u'460 cover apge'],
#  [u'26 curtis street san francisco'],
#  [u'8300 Oceanview Terrace 304, San Francisco'],
#  [u'1 to April'],
#  [u'98 battery st suite'],
#  [u'15% fund raising target'],
#  [u'403 main st'],
#  [u'348 church street'],
#  [u'65 in zip code'],
#  [u'2 2011 pipeline'],
#  [u'2 2011 pipeline report'],
#  [u'2 2015 pipeline'],
#  [u'5m water rise'],
#  [u'202 4th ave'],
#  [u'1618 POLK ST SAN FRANCISCO, CA, US'],
#  [u'5 immigrants in california'],
#  [u'5m water rise'],
#  [u'445 Athens Street'],
#  [u'120 lake street'],
#  [u'19/2015 dashiell hammet'],
#  [u'1 Hawkins Ln SF CA'],
#  [u'1 Hawkins Ln SF CA'],
#  [u'1 Longview Court'],
#  [u'1 hour parking'],
#  [u'1 scott street'],
#  [u'1 scott street'],
#  [u'1 south van ness ave'],
#  [u'1 south vanness'],
#  [u'1. BRIAN DUSSEAULT'],
#  [u'10 gb dataset'],
#  [u'10 glendale street'],
#  [u'10 glendale street'],
#  [u'10 glendale street'],
#  [u'10 glendale street'],
#  [u'10 glendale street'],
#  [u'100 delano ave'],
#  [u'100 delano ave'],
#  [u'100 delano ave'],
#  [u'100 delano ave'],
#  [u'100 delano ave'],
#  [u'100 delano ave'],
#  [u'100 delano ave'],
#  [u'100 year flood'],
#  [u'100 year flood'],
#  [u'100 year flood plain'],
#  [u'100 year storm flood plain'],
#  [u'1000 brannan street'],
#  [u'1008 Santiago street, san francisco'],
#  [u'1008 Santiago street, san francisco'],
#  [u'1008 Santiago street, san francisco'],
#  [u'101 SAN ALESO AVENIE'],
#  [u'1010 fitzgerald ave, san francisco, ca'],
#  [u'1010 fitzgerald ave, san francisco, ca'],
#  [u'1033 polk street'],
#  [u'1033 polk street'],
#  [u'1040 howard st'],
#  [u'1049 Market Street'],
#  [u'1051 de haro'],
#  [u'1051 grant ave, sf'],
#  [u'1051 grant ave, sf'],
#  [u'1051 grant ave, sf'],
#  [u'1051 market st'],
#  [u'106 Powell Street'],
#  [u'106 Powell Street'],
#  [u'1071 Alabama St'],
#  [u'110 sylvan drive, san francisco'],
#  [u'1100 divisadero st'],
#  [u'111 4th ave'],
#  [u'111 powell street'],
#  [u'112 7th street'],
#  [u'1122 Vallejo St'],
#  [u'1131 Mission St'],
#  [u'114 Henry street'],
#  [u'114 powell street, san francisco, ca'],
#  [u'114 powell street, san francisco, ca'],
#  [u'114 powell street, san francisco, ca'],
#  [u'114 powell street, san francisco, ca'],
#  [u'1146a Guerrero Street, San Francisco'],
#  [u'1160 Mission St, San Francisco, cA'],
#  [u'1177 California st'],
#  [u'12 hillview court'],
#  [u'1218 44th Ave., San Francisco'],
#  [u'122 farallones st'],
#  [u'1230 markert st'],
#  [u'1230 markert st'],
#  [u'1230 market st'],
#  [u'1230 market st'],
#  [u'1230 market st'],
#  [u'1231 20th ave, san francisco'],
#  [u'1231 MArket St'],
#  [u'1235 Florida Street'],
#  [u'1238 39th avenue'],
#  [u'129 randall st'],
#  [u'1300 block of mcallister'],
#  [u'1300 block of mcallister'],
#  [u'132 corbett ave'],
#  [u'1327 Leavenworth St'],
#  [u'1328a kobbe avenue'],
#  [u'1328a kobbe avenue'],
#  [u'1343 28th avenue'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'135 Post Street'],
#  [u'1355 market street san francisco'],
#  [u'1355 market street san francisco'],
#  [u'1355 market street san francisco'],
#  [u'1355 market street san francisco'],
#  [u'138 03rd street'],
#  [u'138 03rd street'],
#  [u'138 03rd street'],
#  [u'138 03rd street'],
#  [u'138 03rd street'],
#  [u'138 03rd street'],
#  [u'138 03rd street'],
#  [u'1381 quesada avenue'],
#  [u'1385 carroll ave'],
#  [u'1390 market street'],
#  [u'1390 market street'],
#  [u'140 mason street'],
#  [u'1405 Van Ness Ave'],
#  [u'1405 Van Ness Ave'],
#  [u'1407 EGBERT STREET SAN FRANCISCO'],
#  [u'1409 EGBERT STREET SAN FRANCISCO'],
#  [u'141 Milton Street'],
#  [u'141 Milton Street San Francisco, CA'],
#  [u'141 Milton Street San Francisco, CA'],
#  [u'141 eddy street'],
#  [u'141 eddy street sf ca'],
#  ...]

# %%
# flatten full list 
full = sc.parallelize(full).flatMap(lambda row: row).collect()

# %%
len(full)
# Out:
# 1978

# %%
(696.0 / 18520.0) * 100
# Out:
# 3.7580993520518358

# %%
year_full = [str(j) for j in range(2000,2017)]
# taking out the years

addresses_full = [i.lower() for i in full if i[:4] not in year ]
addresses_full = list(set(addresses_full))
addresses_full
# Out:
# [u'141 milton street san francisco, ca',
#  u'220 30th ave',
#  u'631 folsom st',
#  u'939 jackson st',
#  u'1480 larkin st',
#  u'425 10th st',
#  u'135 post street',
#  u'400 duboce street',
#  u'466 9th avenue',
#  u'32 richland avenue',
#  u'56 moss st',
#  u'1. brian dusseault',
#  u'619 union street',
#  u'1700 newhall street',
#  u'3067 25th street san francisco ca',
#  u'20 jones st',
#  u'425 market street energy',
#  u'2201 market street',
#  u'1416 polk street',
#  u'944 treat av',
#  u'3864 23rd street',
#  u'1500 mc allister street san francisco',
#  u'201 hale street',
#  u'1407 egbert street san francisco',
#  u'141 eddy street sf ca',
#  u'5 thomas mellon circle',
#  u'729 shotwell st',
#  u'322 30th ave',
#  u'200 mississippi street',
#  u'521 clement street',
#  u'3143 folsom st',
#  u'33 allston way',
#  u'5300 3rd street',
#  u'1146a guerrero street, san francisco',
#  u'601 van ness ave',
#  u'1630 30th avenue',
#  u'1385 carroll ave',
#  u'3060 16th street building',
#  u'60 agua way',
#  u'111 powell street',
#  u'4182 mission street',
#  u'337 spurce st san francisco ca',
#  u'345 williams avenue',
#  u'68 cervantes blvd',
#  u'00 use: arcmap 1:70,650 scale for this',
#  u'1231 20th ave, san francisco',
#  u'1023 vallejo street',
#  u'13 melrose ave',
#  u'846 junipero serra blvd',
#  u'760 geary steet',
#  u'3864 23rd street ban',
#  u'78 ina court',
#  u'1895 sacramento st',
#  u'430 lake st',
#  u'11025 carolina place pkwy, pineville',
#  u'94 stratford drive',
#  u'162 landers st',
#  u'100 year storm flood plain',
#  u'1798 grove street',
#  u'208 caselli ave',
#  u'1359 sacramento st',
#  u'4 persia avenue',
#  u'1225 17th avenue',
#  u'3 rudden avenue sf ca',
#  u'2385 bush street',
#  u'62 allston way',
#  u'501 the embarcadero; san francisco',
#  u'106 grand view',
#  u'10 glendale street',
#  u'1363 alabama street',
#  u'90 day cases',
#  u'700) - filers with unpaid late filing',
#  u'1000 feet school',
#  u'88 investment partners, llc',
#  u'390 fremont st',
#  u'3247 reserve ct, san jose, ca',
#  u'205 upper terrace',
#  u'4610 mission street',
#  u'3 buena vista ave east, sf',
#  u'123 retiro way',
#  u'1773 chestnut st',
#  u'2130 jackson street',
#  u'308 font blvd',
#  u'1738 ocean avenue san francisco, ca',
#  u'323 cumberland st',
#  u'158 maynarad st',
#  u'5252 mission street',
#  u'83 mc allister st, san francisco, ca',
#  u'282 harbor rd san francsico, ca',
#  u'245 san jose',
#  u'415 jones st',
#  u'534 4th street',
#  u'501 columbus ave',
#  u'64 perine place, sf',
#  u'2915 octavia st',
#  u'735 fell street',
#  u'1683 7th avenue',
#  u'766 vallejo street',
#  u'163 russ st',
#  u'1328a kobbe avenue',
#  u'79 midcrest way',
#  u'374 5th street san francisco',
#  u'55 cyril magnin street',
#  u'2282 market street',
#  u'425 market energy',
#  u'150 lawrence ave',
#  u'4 2014 election',
#  u'933 treat ave',
#  u'1010 fitzgerald ave, san francisco, ca',
#  u'5413 hillside av.,el cerrito',
#  u'407 jackson st',
#  u'548 banks st, san francisco',
#  u'519 capp street san francisco',
#  u'829 york street',
#  u'606 post street',
#  u'2950 vallejo st, sf',
#  u'1917 broderick street',
#  u'460 - schedule e - payments made',
#  u'8300 oceanview terrace, 304, san francisco',
#  u'299 fremont street',
#  u'450 golden gate',
#  u'415 myra way',
#  u'970 key ave',
#  u'1390 market street',
#  u'754 moultrie group',
#  u'2 casa way',
#  u'400 castro soul cycle',
#  u'33 albion street',
#  u'584 filbert street',
#  u'1405 van ness ave',
#  u'1365 noriega street',
#  u'2945 baker st apt',
#  u"333 o'farrell st, san francisco, ca",
#  u'800 university avenue, palo alto, california',
#  u'530 brannan street',
#  u'2919 folsom st',
#  u'301 king st',
#  u'2282 market st',
#  u'140 mason street',
#  u'155 arbor st',
#  u'250 executive park',
#  u'3180 18th street, san francisco, ca',
#  u'26 curtis street san francisco',
#  u'2172 pacific avenue',
#  u'576 natoma st, san francisco, ca',
#  u'169 steuart st; san francisco, ca',
#  u'240 2nd street',
#  u'199 new montgomery st',
#  u'1050 sansome st',
#  u'5 zip codes',
#  u'1218 44th ave., san francisco',
#  u'439 duboce ave',
#  u'114 henry street',
#  u'31 mullen ave',
#  u'1514 alemany blvd',
#  u'46 el sereno court',
#  u'355 bocana street',
#  u'8300 oceanview terrace',
#  u'1515 s. van ness',
#  u'456 montgomery street suite 2200 san',
#  u'677 page st',
#  u'899 howard street san francisco, ca',
#  u'1 embarcadero san francisco',
#  u'337 spurce street',
#  u'3067 25th street',
#  u'650 40th ave',
#  u'136 arlington street',
#  u'415 euclid ave',
#  u'1300 block of mcallister',
#  u'397 9th st',
#  u'1442 43rd ave',
#  u'215 niagara ave permit parking',
#  u'1683 42nd ave, san francisco ca',
#  u'1996-2013 city survey',
#  u'1051 grant ave, sf',
#  u'2325 pine street',
#  u'1230 market st',
#  u'3d public art',
#  u'2 plus 2 bookeeping',
#  u'916 pine street',
#  u'444 de haro st',
#  u'560 davis st san francisco',
#  u'929 oak st',
#  u'122 farallones st',
#  u'340 mason street',
#  u'562 monterey blvd, san francisco, ca',
#  u'701 teresita san francisco, ca',
#  u'1188 harrrison street',
#  u'1746 church street, san francisco',
#  u'101 utah street',
#  u'1049 market street',
#  u'19 rausch street',
#  u'258 9th st',
#  u'690 long bridge street',
#  u'3 - independent expenditures made',
#  u'1355 market street san francisco',
#  u'1051 de haro',
#  u'2 2011 pipeline',
#  u'3490 20th st',
#  u'579 teresita blvd',
#  u'2412 harrison st',
#  u'336 moraga ave',
#  u'1 south vanness',
#  u'812 guerrero street',
#  u'260 church st',
#  u'1160 mission st, san francisco, ca',
#  u'43 ruth street, san francisco',
#  u'2240 market street',
#  u'1426 48th avenue',
#  u'360 somerset street',
#  u'388 market street, suite',
#  u'4058 17th st',
#  u'1238 39th avenue',
#  u'2598 mission street',
#  u'1700 owens street',
#  u'487 dolores st',
#  u'136 rivoli street',
#  u'810 clay street, san francisco, ca',
#  u'3750 18 street sf ca',
#  u'701 golden gate av',
#  u'348 church street',
#  u'1 tuscany alley',
#  u'3953 24th street',
#  u'141 eddy street',
#  u'838 grant ave',
#  u'340 mason street investors',
#  u'460 post street business search',
#  u'3401 clement st',
#  u'5 hudson ct, san francisco, ca',
#  u'1100 divisadero st',
#  u'2400 14th avenue',
#  u'2919-21 folsom st',
#  u'665 pine st',
#  u'10 gb dataset',
#  u'462 douglass sr',
#  u'345 spear st',
#  u'462 douglass st',
#  u'90 day emergency shelter waitlist',
#  u'269 joost ave',
#  u'67 silverview drive',
#  u'1740 cesar chavez',
#  u'1 scott street',
#  u'1 polk st',
#  u'1000 howard st',
#  u'1409 egbert street san francisco',
#  u'525 29th st',
#  u'1 2015 pipline',
#  u'460 cover page',
#  u'40 jessie street',
#  u'2923 lawton st',
#  u'201 california owner llc',
#  u'2174 california street',
#  u'50 quint street',
#  u'453 masonic st',
#  u'0 beatrice rd, brisbane, ca',
#  u'201o census population',
#  u'1122 vallejo st',
#  u'929 oak st., sf, ca',
#  u'882 31st ave',
#  u'1358 28th avenue, san francisco, ca',
#  u'186 valley street',
#  u'331 jersey st',
#  u'1975 jim jones',
#  u'390 diamond street',
#  u'555 minnesota street',
#  u'221 san carlos',
#  u'177 stillman street',
#  u'1343 28th avenue',
#  u'690 folsom street',
#  u'80.004 employee compensation report',
#  u'944 treat avenue',
#  u'15% fund raising target',
#  u'74 6th street',
#  u'2283 37th ave',
#  u'354 peralta street',
#  u'284 12th avenue',
#  u'1444 market st',
#  u'1578 newhall st. san francisco',
#  u'2096 castro street',
#  u'3d building models',
#  u'106 powell street',
#  u'2 2015 pipeline',
#  u'403 main st',
#  u'1 hawkins ln sf ca',
#  u'459 geary llc',
#  u'600 san bruno ave',
#  u'3139 mission street',
#  u'469 eddy street',
#  u'1700 california st',
#  u'8300 oceanview terrace 304, san francisco',
#  u'49 christopher dr, san francisco, ca',
#  u'677-679 page st',
#  u'709 geary st',
#  u'270 mcallister street',
#  u'2. increase jobs that provide healthy',
#  u'2124 great hwy',
#  u'278 states street',
#  u'146 galewood circle',
#  u'280 circular ave',
#  u'3d building model',
#  u'1125 17th avenue',
#  u'820 jones street',
#  u'545 sutter street, san francisco',
#  u'1000 brannan street',
#  u'1235 florida street',
#  u'4130 mission street',
#  u'418 jessie st',
#  u'2310 mason street',
#  u'2130 22nd st san francisco ca',
#  u'400 castro street',
#  u'1443 46th ave',
#  u'98 battery st suite',
#  u'301 baltimore way',
#  u'1994 union st',
#  u'1131 mission st',
#  u'2349 francisco st',
#  u'126 fillmore stret',
#  u'2660 san bruno avenue, san francisco',
#  u'2190 lombard st, san francisco, ca',
#  u'1709 broderick street',
#  u'41 genebern way, sf',
#  u'2134 green street #3 san francisco, ca',
#  u'141 milton street',
#  u'465 - supplemental independent expenditure',
#  u'1000 sutter street',
#  u'9 geneva ave',
#  u'8134, united states',
#  u'1033 polk street',
#  u'135 seacliff ave',
#  u'387 ellis street',
#  u'177 stillman st',
#  u'749-757 jackson st',
#  u'5 year plan',
#  u'3434 21st st',
#  u'960 howard street',
#  u'337 spurce streeet',
#  u'543 columbus ave',
#  u'1996-2013 city survey data',
#  u'199 new montgomery',
#  u'177 stillman st., san francisco, ca',
#  u'654 46th avenue',
#  u'1423 golden gate',
#  u'124 molimo dr',
#  u'2090 evans avenue',
#  u'1523 guerrero st',
#  u'357 hayes st',
#  u'1952 larkin street',
#  u'347 precita ave san francisco ca',
#  u'527 42nd ave',
#  u'101 san aleso avenie',
#  u'270 mcallister street, san francisco',
#  u'5400 mission san francisco',
#  u'235 presidio avenue',
#  u'2275 sutter st',
#  u'944 treat ave',
#  u'177 stillman st. sf',
#  u'2462 30th street',
#  u'460 post street',
#  u'675 naples street',
#  u'460 - schedule a - monetary contributions',
#  u'129 randall st',
#  u'2020 ellis st',
#  u'2259 25th ave',
#  u'744 montgomery st',
#  u'334 harriet st',
#  u'2332 taraval st sf',
#  u'160 swiss avenue',
#  u'460 forms schedula',
#  u'1155 folsom st',
#  u'1 hour parking',
#  u'1453 mission st',
#  u'224 ordway st',
#  u'3, 2015 election',
#  u'601 laguna street',
#  u'111 ellis street',
#  u'1455 custer street',
#  u'127 san jose ave',
#  u'857 39th ave',
#  u'240 dolores st',
#  u'1970 census block',
#  u'610 page street',
#  u'5 immigrants in california',
#  u'555 4th st',
#  u'65 and older',
#  u'1618 polk st san francisco, ca, us',
#  u'1415 scott street',
#  u'3060 16th street',
#  u'701 minnesota street',
#  u'595 market street, san francisco, ca',
#  u'3314 steiner st',
#  u'17 silverview drive',
#  u'203 cotter st',
#  u'1155 folsom at',
#  u'460 cover apge',
#  u'3024 mission st',
#  u'111 4th ave',
#  u'619 missouri st., san francisco, ca',
#  u'49 south park st',
#  u'2211 stockton st',
#  u'2135 mission street',
#  u'65 in zip code',
#  u'663 haight street',
#  u'2079 15th avenue',
#  u'1693 7th avenue',
#  u'959 noe street',
#  u'345 williams avenue, san francisco',
#  u'1709 broderick st, san francisco, ca',
#  u'2 hour street parking 2999 california',
#  u'50 main street, san francisco',
#  u'201 california llc',
#  u'177 stillman street, san francisco',
#  u'600 van ness',
#  u'1439 16th ave',
#  u'3333 california street',
#  u'2385 bush st',
#  u'18 latona st',
#  u'508 haight st',
#  u'1177 california st',
#  u'2 crestline dr',
#  u'255 king stree',
#  u'444 townsend st',
#  u'83 california state plane zone',
#  u'74 granada avenue san francisco',
#  u'77 beale street buildings',
#  u'600 fell st',
#  u'1450 green st',
#  u'2950 valajo st, sf',
#  u'1600 fell street',
#  u'445 athens street',
#  u'375 bush street',
#  u'1188 harrison street',
#  u'3000 washington street 4000 washington',
#  u'1 post st',
#  u'83 mcallister st, san francisco',
#  u'333 market street energy',
#  u'424 octavia st',
#  u'246 2nd street',
#  u'689 20th avenue',
#  u'700) filers with unpaid late filing fees',
#  u'2912 19th ave',
#  u'4431 mission st',
#  u'1327 leavenworth st',
#  u'5m water rise',
#  u'333 lake street',
#  u'39 liveaboard marina',
#  u'256 fowler ave',
#  u'1994 carroll avenue',
#  u'361 3rd ave',
#  u'71 ford st',
#  u'2145 19th ave, san francisco, ca',
#  u'2030 alemany blvd',
#  u'573 andover street',
#  u'425 market street',
#  u'626 green street',
#  u'2338 taraval st sf',
#  u'1500 mission street',
#  u'750 sutter st, san francisco, ca',
#  u'560 mission street',
#  u'26 eagle street',
#  u'2500 bryant st, san francisco ca',
#  u'700 pennsylvania ave',
#  u'2 bedroom homesale',
#  u'2911 16th st police',
#  u'3130 webster st san francisco, ca',
#  u'447 broadway street',
#  u'568 brannan st',
#  u'705 vallejo street',
#  u'131 franklin street',
#  u'1801 silliman st',
#  u'1008 santiago street, san francisco',
#  u'1660 stockton street',
#  u'175 ney street',
#  u'3008 18th street',
#  u'355 24th ave',
#  u'622 green street',
#  u'38 air pollutant exposure zone',
#  u'333 market street',
#  u'1 longview court',
#  u'554 irving street, san francisco',
#  u'1939 oakdale ave',
#  u'100 year flood',
#  u'823 lake street',
#  u'2166 32nd ave',
#  u'1996-2011 city survey database',
#  u'1931 35th ave san francisco, ca',
#  u'2243 32nd avenue',
#  u'530 brannan street business lincenses',
#  u'100 delano ave',
#  u'631 cole st',
#  u'169 steuart st',
#  u'350 mission street',
#  u'355 serrano dr',
#  u'1453 mission street',
#  u'2021 baker st',
#  u'126 fillmore street',
#  u'428 chicago way',
#  u'887 45th ave',
#  u'2695 43rd avenue',
#  u'2455 polk street',
#  u'324 arkansas st',
#  u'5: generalized neighborhoods commercial',
#  u'17 san andreas way, san francisco',
#  u'9 county boundary',
#  u'1951 oak st',
#  u'340 warren drive san francisco, ca',
#  u'239 carl street',
#  u'331 jersey st parcel map',
#  u'490 post st',
#  u'163 liberty street',
#  u'4175 mission st',
#  u'2208 mission street',
#  u'5 day water related',
#  u'1560 8th ave',
#  u'711 clayton st',
#  u'1428 jackson st',
#  u'887 4th ave',
#  u'589 post st, san francisco, ca',
#  u'2394 mariner square drive, alameda, ca',
#  u'1813 15th street',
#  u'721 18th avenue',
#  u'810 dolores san francisco, ca',
#  u'543 19th ave',
#  u'342 24th ave',
#  u'2922 sacramento street',
#  u'1158 noe street',
#  u'32 richland avenue steven holland',
#  u'1941 ocean avenue san francisco california',
#  u'855 folsom st, san francisco',
#  u'2 hour parking',
#  u'550 3rd street san francisco ca',
#  u'114 powell street, san francisco, ca',
#  u'3465 25th st',
#  u'625 46th ave',
#  u'138 03rd street',
#  u'460 forms schedul',
#  u'120 lake street',
#  u'407 sanchez street',
#  u'4689 mission st',
#  u'1420 5th ave., san francisco, ca',
#  u'301 claremont blvd',
#  u'469 union st',
#  u'202 4th ave',
#  u'251 frederick st',
#  u'1996-2013 sf city survey',
#  u'1755 clay st',
#  u'2250 powell street',
#  u'112 7th street',
#  u'233 san carlos',
#  u'555 market street',
#  u'177 stillman street report',
#  u'1977 20th avenue san francisco ca',
#  u'285 geary st energy audit',
#  u'5060 west 14th street greeley co',
#  u'100 year flood plain',
#  u'3800 16th street san francisco, ca',
#  u'40 annapolis terrace, san francisco',
#  u'3440 broderick street',
#  u'1 to april',
#  u'62 washburn st',
#  u'3520 18th partners',
#  u'62 linden avenue, san bruno, ca',
#  u'3938 geary blvd. san francisco, ca',
#  u'2200 market permit',
#  u'230 eddy street',
#  u'2279 mission street',
#  u'60 garcia ave',
#  u'44 samoset st',
#  u'1231 market st',
#  u'1600 california street',
#  u'755 union st owner name',
#  u'442 holloway ave., sf',
#  u'355 1st street',
#  u'372 point lobos ave',
#  u'700) non filers',
#  u'2919 mission street',
#  u'1560 howard stret',
#  u'679 san jose san francisco',
#  u'321 marietta drive',
#  u'350 laurel st san francisco',
#  u'2577 1/2 post street',
#  u'2901 sacramento st',
#  u'1230 markert st',
#  u'75 dore street',
#  u'2 2011 pipeline report',
#  u'476 ellington ave',
#  u'340 church st',
#  u'100 church street',
#  u'1412 hudson ave',
#  u'14 street sidewalk evaluation results',
#  u'267 green street',
#  u'550 van ness',
#  u'77 san juan ave',
#  u'307 niagra ave',
#  u'252 27th ave, san francisco, ca',
#  u'329 bryant street san francisco, ca',
#  u'360 somerset st',
#  u'3520 18th partners business account number',
#  u'679 page street',
#  u'739 washington street, suite',
#  u'83 mc allister st 513, san francisco',
#  u'822 irving st',
#  u'288 gold mine drive',
#  u'313 potrero ave',
#  u'3092 16th st',
#  u'1040 howard st',
#  u'5800 3rd st',
#  u'202 24th ave sf',
#  u'478 utah st',
#  u'1560 howard street',
#  u'49 mile scenic drive',
#  u'460 forms schedule',
#  u'405 howard st',
#  u'300 sea cliff',
#  u'40 genebern way, sf',
#  u'1381 quesada avenue',
#  u'470 lake st',
#  u'347-349 precita ave',
#  u'1 south van ness ave',
#  u'409 dolores street',
#  u'200 6th st',
#  u'110 sylvan drive, san francisco',
#  u'258 9 th st',
#  u'2650 green, sf',
#  u'487 dolores street',
#  u'198 waterville street, san francisco',
#  u'277 columbus ave',
#  u'285 geary st',
#  u'815 laguna honda',
#  u'20 roussea street',
#  u'19/2015 dashiell hammet',
#  u'1660 stockton at',
#  u'29 downey st',
#  u'1427 11th ave',
#  u'315 28th avenue',
#  u'460 dwight street',
#  u'350 2nd st',
#  u'1805 s. van ness',
#  u'150 lawrence ave san francisco',
#  u'140 new montgomery st',
#  u'155 park st san francsico ca',
#  u'544 castro st',
#  u'1432 grove street san francisco ca',
#  u'460 - schedule a - payments made',
#  u'376 ellis street',
#  u'620 green street',
#  u'495 geary street',
#  u'2652 harrison st',
#  u'200 hazelwood ave',
#  u'83 leo street',
#  u'153 college ave',
#  u'1071 alabama st',
#  u'1865 4th st, san francisco',
#  u'3951 mission st',
#  u'838 detroit street',
#  u'2400 california st san francisco ca',
#  u'72 hour parking restriction',
#  u'387 ellis street, san francisco, ca',
#  u'163 ney st',
#  u'755 union st',
#  u'42 jules avenue',
#  u'12 hillview court',
#  u'1051 market st',
#  u'1900 ferry route',
#  u'317 oak park dr',
#  u'132 corbett ave',
#  u'0 miles 1 note: for neighborhood commercial',
#  u'353 beach rd, burlingame, ca']

# %%
year_listing = [i.lower() for i in full if i[:4] in year ]
year_listing = list(set(year_listing))
year_listing
# Out:
# [u'2000 block group',
#  u'2007 housing inventory',
#  u'2010 census block for san francisco',
#  u'2000 blocks (no water',
#  u'2010 census tracts no water',
#  u'2010: census blocks for san',
#  u'2016 assessor map',
#  u'2010 census population',
#  u'2015 crime statistics',
#  u'2014 energy benchmark 285 geary',
#  u'2009 sfo survey',
#  u'2015 enacted budget',
#  u'2010 tract population',
#  u'2015 housing inventory',
#  u'2013 city survey report',
#  u'2012 campaign finance',
#  u'2005 pipeline report',
#  u'2000 tracts no water',
#  u'2014 city serve report',
#  u'2016 budget publication',
#  u'2000 census tract',
#  u'2011 mayor campaign contributions',
#  u'2000 block goup',
#  u'2012 sfo customer survey',
#  u'2015 richmond district',
#  u'2010 demographic profile data, sf county',
#  u'2015 in san francisco',
#  u'2015 form 460; schedule',
#  u'2014 map:crime incidents',
#  u'2011 herrera campaign contributions',
#  u'2015 residential development pipeline',
#  u'2004 bicycle network',
#  u'2010 vehicle ownership',
#  u'2008 crime data',
#  u'2015 murder by race statistics',
#  u'2000 census tracts',
#  u'2000 census shapefile',
#  u'2010 census block',
#  u'2010: census block groups',
#  u'2010: census blocks',
#  u'2012 housing inventory',
#  u'2013 housing inventory',
#  u'2015 budget information',
#  u'2010 block groups',
#  u'2000 block (no water',
#  u'2011 customer survey dataset',
#  u'2013 building permits',
#  u'2011 herrera mayor campaign contributions',
#  u'2010 census blocks',
#  u'2000 census tract shapefile',
#  u'2014 q4 planning pipeline',
#  u'2015 q4 pipeline',
#  u'2010: census blocks for san francisco',
#  u'2010 population shapefile',
#  u'2000 blocks (no water) census',
#  u'2000 blocks no water',
#  u'2010 census blocks for san francisco',
#  u'2015 311 budget',
#  u'2009 housing inventory',
#  u'2015 city survey',
#  u'2000 no water',
#  u'2014 census tracts',
#  u'2004 food vendors',
#  u'2014 housing inventory',
#  u'2000 population density',
#  u'2010 census block centroids',
#  u'2000 tracts (no water',
#  u'2010 us census data',
#  u'2005 housing inventory',
#  u'2016 housing development',
#  u'2010 map:crime incidents',
#  u'2016 feb 26 arrests in bay view',
#  u'2013 sfpd incidents',
#  u'2016 assessor map updates',
#  u'2010 census house hold data by taz',
#  u'2015 neighborhood profiles',
#  u'2010 census tracts',
#  u'2013 census shapefile',
#  u'2011 pipeline report',
#  u'2013 sfo customer survey',
#  u'2004 bike network',
#  u'2012 census population']

# %%
clean_list = sc.parallelize(query_list).filter(lambda word: word.lower() not in addresses_full).collect()

# %%
links = "((https?|http):((//)|(\\\\))+[\w\d:#@%/;$()~_?\+-=\\\.&]*)"

https = [re.findall(links, i) for i in clean_list
     if re.findall(links, i)!= [] 
     if re.findall(links, i)!= "//" 
     ]
# http://stackoverflow.com/questions/6718633/python-regular-expression-again-match-url

# %%
# finding all the unique links that people have put into the search query

https = (sc.parallelize(https).flatMap(lambda word: word)
        .flatMap(lambda word: word)
        .filter(lambda word: word != '//')
        .filter(lambda word: word != 'https')
        .filter(lambda word: word != '''''')
        .filter(lambda word: word != 'http')
        .collect())

# %%
https
# Out:
# [u'https://data.sfgov.org/Public-Health/Excessive-Rent-Burden-San-Francisco-CA/9wty-qwgq',
#  u'https://data.sfgov.org/Public-Health/Restaurant-Scores/stya-26eb',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://www.bsis.ca.gov/forms_pubs/fire_fact.shtml',
#  u'http://www.datasf.org/story.php?title=street-sweeper-schedule-and-route-',
#  u'https://10.183.241.201/rgcertprintv2default.aspx',
#  u'https://data.sfgov.org/Economy-and-Community/Off-Sale-Alcohol-Outlets-San-Francisco-CA/fIy-9zhp',
#  u'https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis',
#  u'https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis?',
#  u'https://data.sfgov.org/d/ejmn-jyk6',
#  u'https://data.sfgov.org/data?category=',
#  u'https://data.sfgov.org/data?category=Transportation',
#  u'https://extxfer.sfdph.org/food/',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.kaggle.com/c/sf-crime',
#  u'https://data.sfgov.org/Public-Health/Excessive-Rent-Burden-San-Francisco-CA/9wty-qwgq',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://www.bsis.ca.gov/forms_pubs/fire_fact.shtml',
#  u'https://10.183.241.201/rgcertprintv2default.aspx',
#  u'https://10.183.241.201/rgcertprintv2default.aspx',
#  u'https://10.183.241.201/rgcertprintv2default.aspx',
#  u'https://data.sfgov.org/Economy-and-Community/Off-Sale-Alcohol-Outlets-San-Francisco-CA/fIy-9zhp',
#  u'https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis?',
#  u'https://data.sfgov.org/d/ejmn-jyk6',
#  u'https://data.sfgov.org/data?category=Transportation',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain']

# %%
clean_list = (sc.parallelize(query_list).map(lambda word: word.lower()).filter(lambda word: word not in https)
              .filter(lambda word: word not in addresses_full)
              .collect())

# %%
from collections import Counter
word_count = Counter(clean_list)
word_count_sorted = sorted(word_count.items(),key = lambda x: x[1], reverse=True)

# %%
word_count_sorted = [i[0] for i in word_count_sorted if i[1]>2]
word_count_sorted
# Out:
# [u'crime',
#  u'streets',
#  u'shapefile',
#  u'street',
#  u'parking',
#  u'census',
#  u'bike',
#  u'business',
#  u'building',
#  u'water',
#  u'neighborhood',
#  u'parks',
#  u'population',
#  u'311',
#  u'traffic',
#  u'bicycle',
#  u'muni',
#  u'parcel',
#  u'income',
#  u'fire',
#  u'housing',
#  u'school',
#  u'rent',
#  u'bart',
#  u'zoning',
#  u'land use',
#  u'neighborhoods',
#  u'bus',
#  u'gis',
#  u'parcels',
#  u'homeless',
#  u'elevation',
#  u'food',
#  u'restaurant',
#  u'buildings',
#  u'san francisco',
#  u'boundary',
#  u'pipeline',
#  u'roads',
#  u'police',
#  u'schools',
#  u'park',
#  u'address',
#  u'transit',
#  u'budget',
#  u'assessor',
#  u'tree',
#  u'transportation',
#  u'taxi',
#  u'sfmta',
#  u'restaurants',
#  u'building footprints',
#  u'property',
#  u'city',
#  u'trees',
#  u'pedestrian',
#  u'construction',
#  u'health',
#  u'businesses',
#  u'shapefiles',
#  u'bridge',
#  u'block',
#  u'education',
#  u'business license',
#  u'bay area',
#  u'district',
#  u'graffiti',
#  u'building permits',
#  u'building footprint',
#  u'street cleaning',
#  u'road',
#  u'sfpd',
#  u'permit',
#  u'census tract',
#  u'sewer',
#  u'blocks',
#  u'noise',
#  u'car',
#  u'map',
#  u'city boundary',
#  u'hospital',
#  u'districts',
#  u'airport',
#  u'zip code',
#  u'topography',
#  u'business licenses',
#  u'open space',
#  u'affordable housing',
#  u'contour',
#  u'accidents',
#  u'real estate',
#  u'permits',
#  u'eviction',
#  u'basemap',
#  u'parking meter',
#  u'sfo',
#  u'alcohol',
#  u'salary',
#  u'aerial',
#  u'parking meters',
#  u'demographics',
#  u'shoreline',
#  u'accident',
#  u'campaign finance',
#  u'flood',
#  u'air',
#  u'tax',
#  u'zip',
#  u'demographic',
#  u'contours',
#  u'evictions',
#  u'energy',
#  u'assessment',
#  u'weather',
#  u'age',
#  u'centerline',
#  u'bus stops',
#  u'art',
#  u'census shapefile',
#  u'employment',
#  u'streets of san francisco',
#  u'footprint',
#  u'planning',
#  u'addresses',
#  u'air quality',
#  u'centerlines',
#  u'bay',
#  u'sidewalk',
#  u'census tracts',
#  u'open spaces',
#  u'bike lanes',
#  u'cancer',
#  u'hotel',
#  u'landuse',
#  u'lobbyist',
#  u'zip codes',
#  u'waste',
#  u'city lots',
#  u'coffee',
#  u'business registration',
#  u'development pipeline',
#  u'public schools',
#  u'library',
#  u'boundaries',
#  u'dem',
#  u'bars',
#  u'census 2010',
#  u'facilities',
#  u'street sweeping',
#  u'poverty',
#  u'building permit',
#  u'census 2000',
#  u'hospitals',
#  u'housing inventory',
#  u'cleaning',
#  u'meter',
#  u'census block',
#  u'base map',
#  u'density',
#  u'wind',
#  u'population density',
#  u'bike parking',
#  u'cnn',
#  u'sidewalks',
#  u'topo',
#  u'bike network',
#  u'climate',
#  u'kml',
#  u'curb',
#  u'460',
#  u'business account number',
#  u'vacant',
#  u'public transportation',
#  u'highway',
#  u'bikeway',
#  u'retail',
#  u'crimes',
#  u'property assessment',
#  u'uber',
#  u'recreation',
#  u'employee',
#  u'json',
#  u'tourism',
#  u'parking tickets',
#  u'911',
#  u'race',
#  u'cad',
#  u'soil',
#  u'children',
#  u'curbs',
#  u'city limits',
#  u'police districts',
#  u'sales',
#  u'public',
#  u'street parking',
#  u'chinatown',
#  u'zoning districts',
#  u'building height',
#  u'tickets',
#  u'intersections',
#  u'community',
#  u'caltrain',
#  u'csv',
#  u'citation',
#  u'shore',
#  u'supervisor',
#  u'food truck',
#  u'height',
#  u'rental',
#  u'human waste',
#  u'college',
#  u'light',
#  u'job',
#  u'address locator',
#  u'commercial',
#  u'earthquake',
#  u'campaign',
#  u'ban',
#  u'tow',
#  u'vegetation',
#  u'lots',
#  u'survey',
#  u'residential',
#  u'rail',
#  u'bridges',
#  u'hiv',
#  u'shelter',
#  u'registered business',
#  u'poop',
#  u'footprints',
#  u'crime data',
#  u'fire incidents',
#  u'imagery',
#  u'2015',
#  u'vehicle',
#  u'trail',
#  u'shp',
#  u'base',
#  u'historic',
#  u'complaints',
#  u'bay area general',
#  u'street names',
#  u'tenderloin',
#  u'tract',
#  u'inventory',
#  u'port',
#  u'slope',
#  u'open business',
#  u'sfpd incidents',
#  u'water bodies in san francisco',
#  u'film',
#  u'homicide',
#  u'bicycle parking',
#  u'liquor',
#  u'incidents',
#  u'intersection',
#  u'orthophoto',
#  u'food trucks',
#  u'libraries',
#  u'land',
#  u'vendor',
#  u'mobile food',
#  u'garbage',
#  u'price',
#  u'building heights',
#  u'bus stop',
#  u'gps',
#  u'hotels',
#  u'sf shoreline and islands',
#  u'location',
#  u'ortho',
#  u'2014',
#  u'inclusionary housing',
#  u'ethnicity',
#  u'shape file',
#  u'street light',
#  u'events',
#  u'bike lane',
#  u'sffind neighborhoods',
#  u'route',
#  u'contracts',
#  u'insurance',
#  u'violations',
#  u'mission bay',
#  u'development',
#  u'rent control',
#  u'green',
#  u'street centerlines',
#  u'planning neighborhoods',
#  u'street trees',
#  u'violation',
#  u'bayview',
#  u'childcare',
#  u'lidar',
#  u'bus routes',
#  u'census blocks',
#  u'3d',
#  u'community gardens',
#  u'cable',
#  u'animal',
#  u'registered businesses',
#  u'board of supervisors',
#  u'speed',
#  u'popos',
#  u'sfpark',
#  u'fire stations',
#  u'calls for service',
#  u'shoreline shapefile',
#  u'public space',
#  u'grocery',
#  u'airbnb',
#  u'traffic counts',
#  u'sfshore',
#  u'ambulance',
#  u'asthma',
#  u'freeway',
#  u'sffd',
#  u'pollution',
#  u'salaries',
#  u'median income',
#  u'inclusionary',
#  u'block group',
#  u'trails',
#  u'supervisor districts',
#  u'utilities',
#  u'house',
#  u'ferry',
#  u'property tax',
#  u'presidio',
#  u'utility',
#  u'museum',
#  u'affordable',
#  u'collision',
#  u'green space',
#  u'meters',
#  u'disabled',
#  u'stclines',
#  u'highways',
#  u'bikes',
#  u'water bodies',
#  u'dpw',
#  u'treasure island',
#  u'jobs',
#  u'solar',
#  u'trash',
#  u'incident',
#  u'bike share',
#  u'street map',
#  u'compensation',
#  u'ocean',
#  u'wifi',
#  u'ticket',
#  u'license',
#  u'public housing',
#  u'taz',
#  u'homelessness',
#  u'citations',
#  u'spending',
#  u'mta',
#  u'traffic density',
#  u'coast',
#  u'colleges',
#  u'shape',
#  u'tow zone',
#  u'census 2000 tracts (no water)',
#  u'garden',
#  u'business registration certificate',
#  u'network',
#  u'bay area - general',
#  u'wireless',
#  u'sfmta bikeway network',
#  u'internet',
#  u'.shp',
#  u'public art',
#  u'crime incidents',
#  u'inspection',
#  u'building age',
#  u'county',
#  u'sanfrancisco.gdb',
#  u'unemployment',
#  u'temperature',
#  u'supervisor district',
#  u'real time',
#  u'housing prices',
#  u'article 11',
#  u'city survey',
#  u'death',
#  u'bicycle accidents',
#  u'topographic',
#  u'zipcode',
#  u'seismic',
#  u'murder',
#  u'fire department',
#  u'electricity',
#  u'traffic count',
#  u'parcel data',
#  u'emergency',
#  u'property assessment roll',
#  u'lyft',
#  u'stormwater',
#  u'theft',
#  u'property value',
#  u'movie',
#  u'farmers market',
#  u'terrain',
#  u'medical',
#  u'form 700',
#  u'electricity use',
#  u'traffic accidents',
#  u'city blocks',
#  u'household income',
#  u'apn',
#  u'pbc',
#  u'san francisco crime',
#  u'dbi',
#  u'rain',
#  u'fire station',
#  u'bernal lot size',
#  u'right of way',
#  u'citylots',
#  u'311 cases',
#  u'child',
#  u'benches',
#  u'open',
#  u'church',
#  u'article 10',
#  u'crime rate',
#  u'sro',
#  u'camera',
#  u'census 2000 blocks (no water)',
#  u'payroll',
#  u'parking lots',
#  u'berkeley',
#  u'telegraph hill',
#  u'dui',
#  u'something',
#  u'arrests',
#  u'speed limit',
#  u'truck',
#  u'apartment buildings',
#  u'image',
#  u'sweeping',
#  u'injury',
#  u'north beach',
#  u'watershed',
#  u'cafe',
#  u'sf solar map',
#  u'job density',
#  u'china',
#  u'car ownership',
#  u'obesity',
#  u'hydrology',
#  u'paving',
#  u'employees',
#  u'market',
#  u'oakland',
#  u'sanfrancisco',
#  u'border',
#  u'dog',
#  u'parking citation',
#  u'auto',
#  u'streets shapefile',
#  u'case',
#  u'complaint',
#  u'vendors',
#  u'street of san francisco',
#  u'api',
#  u'tech',
#  u'vote',
#  u'air pollution',
#  u'child care',
#  u'bay trail',
#  u'parking ticket',
#  u'police district',
#  u'sfusd',
#  u'census 2000 tracts',
#  u'zone',
#  u'film locations',
#  u'station',
#  u'parking citations',
#  u'landmark',
#  u'ada',
#  u'eas',
#  u'year built',
#  u'geojson',
#  u'food inspection',
#  u'ethics',
#  u'feces',
#  u'dpt_bike_network',
#  u'drug',
#  u'airports',
#  u'geology',
#  u'envista',
#  u'census 2000 blocks',
#  u'photo',
#  u'bicycle accident',
#  u'university',
#  u'trimmers',
#  u'outline',
#  u'finance',
#  u'train',
#  u'election',
#  u'contract',
#  u'speeding',
#  u'hazard',
#  u'lobby',
#  u'assessment roll',
#  u'social',
#  u'fte',
#  u'marriage',
#  u'precinct',
#  u'bird',
#  u'bank',
#  u'cab',
#  u'bus lines',
#  u'bar',
#  u'cable car',
#  u'ridership',
#  u'revenue',
#  u'housing price',
#  u'police stations',
#  u'travel',
#  u'wine',
#  u'lgbt',
#  u'flooding',
#  u'open business locations',
#  u'center lines',
#  u'dumping',
#  u'vendor payments',
#  u'sf shore',
#  u'pipeline 2015',
#  u'san francisco streets',
#  u'chicago',
#  u'coastal',
#  u'biz point',
#  u'road map',
#  u'pipe',
#  u'recycling',
#  u'campaign consultant',
#  u'street network',
#  u'street centerline',
#  u'union square',
#  u'lot',
#  u'city features',
#  u'bench',
#  u'biking',
#  u'bike theft',
#  u'movies',
#  u'public transit',
#  u'stations',
#  u'census2000',
#  u'services',
#  u'liquefaction',
#  u'toilet',
#  u'sweep',
#  u'sfpuc',
#  u'94110',
#  u'streetlight',
#  u'technology',
#  u'street shapefile',
#  u'planning districts',
#  u'advisories',
#  u'garage',
#  u'traffic accident',
#  u'tobacco',
#  u'allergies',
#  u'on street parking',
#  u'universities',
#  u'google',
#  u'arterial',
#  u'bathroom',
#  u'lobbyists',
#  u'gis data',
#  u'transit stops',
#  u'routes',
#  u'agriculture',
#  u'form 460',
#  u'bus accidents',
#  u'bike shapefile',
#  u'transport',
#  u'lobbyist activity',
#  u'high injury',
#  u'latitude',
#  u'data catalog',
#  u'museums',
#  u'2010 census',
#  u'open spaces city planning',
#  u'crime map',
#  u'pole',
#  u'avenida epitacio pessoa ipanema rio de janeiro',
#  u'parcel map',
#  u'storm',
#  u'dataset inventory',
#  u'castro',
#  u'address points',
#  u'health care',
#  u'2010',
#  u'health score',
#  u'bike route',
#  u'water usage',
#  u'use',
#  u'business locations',
#  u'inspections',
#  u'economic',
#  u'busines',
#  u'twitter',
#  u'cafe bakery',
#  u'collisions',
#  u'farmers markets',
#  u'active business',
#  u'maher',
#  u'elections',
#  u'raster',
#  u'chinese',
#  u'illegal dumping',
#  u'canopy',
#  u'traffic volume',
#  u'cannabis',
#  u'owner',
#  u'city limit',
#  u'restaurant inspection',
#  u'clean',
#  u'speed limits',
#  u'sf development pipeline',
#  u'maps',
#  u'general plan',
#  u'rent board',
#  u'business district',
#  u'landmarks',
#  u'coastal zone',
#  u'sea level rise',
#  u'curb ramp',
#  u'property owner',
#  u'cities',
#  u'avl',
#  u'pavement',
#  u'bayview hunters point',
#  u'data',
#  u'gdp',
#  u'at',
#  u'building outline',
#  u'sfdph',
#  u'census 2000 block group',
#  u'employee compensation',
#  u'beach',
#  u'restaurant inspections',
#  u'security',
#  u'schedule e',
#  u'cost',
#  u'fires',
#  u'landslide',
#  u'muni routes',
#  u'street lights',
#  u'bus route',
#  u'sf311',
#  u'wind monitoring',
#  u'new york',
#  u'home',
#  u'public works',
#  u'liquor store',
#  u'drainage',
#  u'environment',
#  u'brownfield',
#  u'community center',
#  u'san francisco shoreline',
#  u'affordability',
#  u'street sweep',
#  u'property values',
#  u'subway',
#  u'city boundaries',
#  u'expenditures',
#  u'center line',
#  u'business location',
#  u'vmt',
#  u'economy',
#  u'tree canopy',
#  u'area',
#  u'mobile',
#  u'pipeline 2012',
#  u'healthcare',
#  u'road network',
#  u'lights',
#  u'digital elevation model',
#  u'baker places',
#  u'parking restrictions',
#  u'performance',
#  u'cctv',
#  u'building outlines',
#  u'clinic',
#  u'tourist',
#  u'street tree',
#  u'sanitation',
#  u'traffic tickets',
#  u'plant',
#  u'prostitution',
#  u'basil thai',
#  u'university of san francisco',
#  u'workers',
#  u'point',
#  u'household',
#  u'facility',
#  u'altitude',
#  u'time',
#  u'parklet',
#  u'preservation',
#  u'parklets',
#  u'water quality',
#  u'eviction notices',
#  u'public health',
#  u'counties',
#  u'bikeway network',
#  u'churches',
#  u'ems',
#  u'birth',
#  u'nonprofit',
#  u'muni stops',
#  u'maintenance',
#  u'cell',
#  u'benchmark',
#  u'pothole',
#  u'car sharing',
#  u'san francisco boundary',
#  u'lobbying',
#  u'street center',
#  u'shop',
#  u'traffic lights',
#  u'commute',
#  u'precipitation',
#  u'2000',
#  u'recology',
#  u'shooting',
#  u'street maps',
#  u'cases',
#  u'cbd',
#  u'gentrification',
#  u'low income',
#  u'tracts',
#  u'460 e',
#  u'precincts',
#  u'certified payroll',
#  u'aspect',
#  u'golden gate',
#  u'animals',
#  u'motorcycle',
#  u'vacancy',
#  u'gardens',
#  u'cell phone',
#  u'tax lots',
#  u'test',
#  u'sffacs',
#  u'grocery stores',
#  u'commuting',
#  u'non profit',
#  u'coastline',
#  u'buisness',
#  u'pipeline 2013',
#  u'san francisco map',
#  u'bike accidents',
#  u'restroom',
#  u'railroad',
#  u'vision zero',
#  u'drain',
#  u'youth',
#  u'prices',
#  u'aadt',
#  u'names',
#  u'street sweeping schedule',
#  u'adt',
#  u'sf shoreline',
#  u'appeals',
#  u'fiber',
#  u'condominium',
#  u'building construction',
#  u'ethnic',
#  u'river',
#  u'burglary',
#  u'police station',
#  u'small business',
#  u'below market rate',
#  u'median rent',
#  u'food inspections',
#  u'mortgage',
#  u'uncashed',
#  u'bikeshare',
#  u'city outline',
#  u'county boundary',
#  u'parcel owner',
#  u'board',
#  u'parking signs',
#  u'creek',
#  u'parking lot',
#  u'sweeper',
#  u'registered business locations',
#  u'mission district',
#  u'foodtruck',
#  u'public library',
#  u'sf streets',
#  u'suicide',
#  u'.csv',
#  u'pci',
#  u'metro',
#  u'injuries',
#  u'parking violations',
#  u'criminal',
#  u'golden gate bridge',
#  u'search datasf',
#  u'crime statistics',
#  u'sports',
#  u'building use',
#  u'land cover',
#  u'developer',
#  u'dog patch',
#  u'realtor',
#  u'walk',
#  u'boundry',
#  u'grocery store',
#  u'base mao',
#  u'licenses',
#  u'bay area counties',
#  u'habitat',
#  u'san francisco shapefile',
#  u'pipeline 2014',
#  u'zipcodes',
#  u'fuel',
#  u'private schools',
#  u'stop',
#  u'pbc code',
#  u'appraisal roll',
#  u'entitlements',
#  u'marijuana',
#  u'basemap street centerlines shapefile',
#  u'gtfs',
#  u'gay',
#  u'rape',
#  u'city facilities',
#  u'news',
#  u'cancer risk',
#  u'bicycle theft',
#  u'mission',
#  u'tow away',
#  u'traffic light',
#  u'ownership',
#  u'people',
#  u'fog',
#  u'public parks',
#  u'resturant',
#  u'freeways',
#  u'cases by channel',
#  u'startup',
#  u'projects',
#  u'2013',
#  u'manhole',
#  u'taxes',
#  u'diabetes',
#  u'assess',
#  u'san francisco county',
#  u'sfopenbook',
#  u'sport',
#  u'census2000_blk_nowater',
#  u'event',
#  u'registered',
#  u'bike routes',
#  u'entertainment',
#  u'baytrail',
#  u'sea level',
#  u'naics',
#  u'companies',
#  u'waterfront',
#  u'grid',
#  u'bay area zip codes',
#  u'block groups',
#  u'homeless shelter',
#  u'excavation',
#  u'sales tax',
#  u'industrial',
#  u'co2',
#  u'cost of living',
#  u'deaths',
#  u'real-time',
#  u'conference',
#  u'home sales',
#  u'heat',
#  u'senior',
#  u'mental health',
#  u'catalog',
#  u'city map',
#  u'lottery',
#  u'sexual assault',
#  u'pdf parcel',
#  u'service requests',
#  u'btod',
#  u'fema',
#  u'land value',
#  u'workforce',
#  u'bike route network',
#  u'police department',
#  u'commute time',
#  u'recreation and parks',
#  u'puc',
#  u'taylor',
#  u'pier',
#  u'basemap street centerlines',
#  u'orthophotos',
#  u'dogs',
#  u'schedule a',
#  u'potholes',
#  u'cars',
#  u'excelsior',
#  u'460 forms schedule a',
#  u'public school',
#  u'checkbook',
#  u'purchase',
#  u'grade',
#  u'crime shapefile',
#  u'concealed weapons permits',
#  u'recreation centers',
#  u'dpt bike network',
#  u'candidate name',
#  u'congestion',
#  u'deed',
#  u'housing code violations',
#  u'health facilities',
#  u'business registration certificate number',
#  u'bay outline',
#  u'san francisco outline',
#  u'immigration',
#  u'house price',
#  u'open spaces - city planning',
#  u'national parks',
#  u'sf boundary',
#  u'abandoned',
#  u'sun',
#  u'311 case data',
#  u'condo',
#  u'resiliency',
#  u'occupation',
#  u'women',
#  u'dwg',
#  u'grafitti',
#  u'music',
#  u'motorcycle parking',
#  u'traffic signals',
#  u'films',
#  u'solar map',
#  u'sale',
#  u'public safety',
#  u'buyouts',
#  u'civic center',
#  u'sf flower mart',
#  u'bay area cities',
#  u'shape files',
#  u'stops',
#  u'enforcement',
#  u'benchmarking',
#  u'claims',
#  u'central subway',
#  u'foreclosure',
#  u'bart stations',
#  u'probation',
#  u'planning cases',
#  u'homicides',
#  u'street closures',
#  u'water use',
#  u'bus line',
#  u'business certificate',
#  u'arrest',
#  u'supervisorial districts',
#  u'neighborhood boundaries',
#  u'recycle',
#  u'external datasets',
#  u'murders',
#  u'ellis',
#  u'bcdc',
#  u'shelters',
#  u'property records',
#  u'impervious',
#  u'value',
#  u'heights',
#  u'3d building',
#  u'urban tree',
#  u'market street',
#  u'street center lines',
#  u'towing',
#  u'disabled parking',
#  u'toilets',
#  u'incomes',
#  u'meeting time',
#  u'car theft',
#  u'gang',
#  u'floodplain',
#  u'arcgis',
#  u'block lot',
#  u'rent prices',
#  u'business map',
#  u'diana lerner',
#  u'form 700 schedules',
#  u'classification',
#  u'disaster',
#  u'juvenile',
#  u'bay area shapefile',
#  ...]

# %%
string_word = removePunctuation(re.sub("\u" , '', str(word_count_sorted)))
string_word1 = removePunctuation(re.sub("\u" , '', str(query_list)))

# %%
from polyglot.text import Text

NER = Text(string_word1)

NER = words.entities

for entity in NER:
    if entity.tag == "I-PER":
        print entity
# Out:
# [u'bildings']
# [u'san']
# [u'bernal']
# [u'castro']
# [u'bsiness', u'maher']
# [u'san']
# [u'bart']
# [u'ellis']
# [u'diana', u'lerner']
# [u'ellis']
# [u'bart']
# [u'levis']
# [u'ord']
# [u'valle']
# [u'steven', u'holland']
# [u'consmer']
# [u'cort']
# [u'san', u'francisco']
# [u'drgs']
# [u'brigitte', u'wilson']
# [u'jane', u'kim']
# [u'aaron', u'peskin']
# [u'bart']
# [u'thomas', u'angelo', u'hetch']
# [u'stadim']
# [u'stitt']
# [u'salesforcecom', u'maher']
# [u'stosp']
# [u'aaron', u'apperson']
# [u'alain', u'gervais']
# [u'mintes']
# [u'soth', u'san']
# [u'soltions', u'san']
# [u'jeff', u'startps']
# [u'sadi']
# [u'jng', u'dccc']
# [u'christensen']
# [u'bilding', u'rajewen', u'haight']
# [u'watson']
# [u'lewis']
# [u'francisco']
# [u'bondary']
# [u'noe']
# [u'cort']
# [u'san']
# [u'jim', u'jones']
# [u'andrew', u'rex']
# [u'weiner']
# [u'bart']
# [u'sanborn']
# [u'ariel', u'tandoori']
# [u'kate', u'spasde', u'constrctionlist']
# [u'hosing', u'condit']
# [u'ca94118']
# [u'daly']
# [u'carman', u'tomarah', u'l']
# [u'anda', u'bsinesse', u'david', u'jordan', u'sfchamp']
# [u'apn']
# [u'christopher', u'charley', u'shapefile']
# [u'landmarcrimek']
# [u'webster']
# [u'jonah', u'yee']
# [u'corses', u'harrison']
# [u'kao']
# [u'amor', u'santiago']
# [u'bart']
# [u'san', u'francisco']
# [u'leo', u'brnett']
# [u'kevin', u'klng']
# [u'sfmta']
# [u'vallejo']
# [u'bart']
# [u'reqest']
# [u'rinary']
# [u'molly', u'saeger']
# [u'mathews', u'vassallo']
# [u'peskin', u'lalanne']
# [u'sfmta']
# [u'failre']
# [u'palo']
# [u'jlie', u'christensen']
# [u'accont']
# [u'roldan', u'enriqez', u'oter']
# [u'j']
# [u'charles', u'walton', u'censs']
# [u'sanfrancisco', u'impervios']
# [u'henry', u'albert', u'villarreal']
# [u'dolores']
# [u'anson', u'mooney']
# [u'larkin']
# [u'san']
# [u'pedicab', u'graff']
# [u'kristian']
# [u'bock']
# [u'san']
# [u'michael', u'schlz']
# [u'san']
# [u'shaprfile', u'valverde', u'constrction']
# [u'constrction']
# [u'san']
# [u'bsiness']
# [u'henderson']
# [u'jon']
# [u'bateman']
# [u'monments', u'starp']
# [u'ellis']
# [u'consmption']
# [u'jane', u'kim']
# [u'san']
# [u'francis', u'ngyen']
# [u'francisco', u'dem', u'david']
# [u'ber']
# [u'bart']
# [u'dennis', u'herrera']
# [u'lasala', u'nert']
# [u'hosing']
# [u'fazil']
# [u'melanie', u'lok']
# [u'alan']
# [u'hosing']
# [u'jennifer', u'wong', u'noi']
# [u'sorcing']
# [u'ami']
# [u'michel', u'legrand']
# [u'geocode', u'carlson']
# [u'san']
# [u'mary']
# [u'smmaries']
# [u'inclsionary']
# [u'restarants', u'casey']
# [u'phill', u'mnicipal']
# [u'vincent', u'kircher']
# [u'richard', u'chiriboga']
# [u'enterovirs']
# [u'mintes']
# [u'michael', u'jeff']
# [u'crim']
# [u'schedled']
# [u'noel', u'larios', u'scriptscriptalert1script']
# [u'polk', u'xlm']
# [u'calvin']
# [u'joanne', u'minsky']
# [u'san']
# [u'athority']
# [u'sara', u'reek']
# [u'roderick', u'baltazar', u'shapefile']
# [u'corey', u'canapary']
# [u'genrification']
# [u'mashp', u'levi', u'strass']
# [u'sanchez']
# [u'brigitte']
# [u'michael', u'webster']
# [u'bernal']
# [u'mary', u'jng', u'dccc']
# [u'bateman']
# [u'raymond', u'chow']
# [u'injry']
# [u'bildings']
# [u'shapefile']
# [u'ave', u'salla']
# [u'kwok']
# [u'ahmed']
# [u'shapefile']
# [u'holliday']
# [u'chaz']
# [u'harris']
# [u'matinez']
# [u'san']
# [u'david', u'owen', u'mni']
# [u'rashad', u'eid']
# [u'lombard']
# [u'cort']
# [u'shafter']
# [u'ayear']
# [u'san']
# [u'bdget']
# [u'cesar', u'chavez']
# [u'minh']
# [u'ngyen']
# [u'karen', u'lm']
# [u'colter']
# [u'howard']
# [u'commnity']
# [u'walsh']
# [u'san', u'francisco']
# [u'antonin', u'scalia']
# [u'conty']
# [u'ami']
# [u'cnn', u'frnitre']
# [u'stillman']
# [u'carl']
# [u'ada']
# [u'jessie']
# [u'brendan', u'y']
# [u'collison']
# [u'jean', u'ng']
# [u'armin']
# [u'bildings', u'harris']
# [u'aaron', u'peskin']
# [u'joseph']
# [u'james', u'peavey']
# [u'adrian']
# [u'sbdivisions', u'wiseman']
# [u'dorothy', u'tyson', u'san']
# [u'kenneth', u'malvar']
# [u'teng']
# [u'cliate']
# [u'rammp']
# [u'asdf', u'coates']
# [u'francisco', u'bart']
# [u'kim', u'reynolds']
# [u'serco']
# [u'molnar']
# [u'l']
# [u'toby', u'kanzawa']
# [u'solomon', u'pblic']
# [u'fnd', u'clementina']
# [u'tblreislotdetail', u'bart', u'statios']
# [u'alex', u'lebel']
# [u'ttx']
# [u'snset']
# [u'brlingame']
# [u'brannan']
# [u'san', u'francisco']
# [u'bart']
# [u'armando', u'lna']
# [u'lois']
# [u'wiener']
# [u'bart']
# [u'clement', u'brea']
# [u'cordova', u'fractre']
# [u'san', u'francisco', u'reqests']
# [u'bilding']
# [u'christopher', u'webster']
# [u'parkin']
# [u'brophy']
# [u'conway', u'brasilv']
# [u't2btt49r']
# [u'aaron', u'peskin', u'smmary']
# [u'townsend']
# [u'aaron', u'peskin']
# [u'dyogi']
# [u'anthony']
# [u'san']
# [u'joel']
# [u'pepi']
# [u'bart']
# [u'bidling']
# [u'san', u'francisco', u'birt']
# [u'linda']
# [u'fillmore', u'blake', u'rawdin']
# [u'hilary', u'ronen']
# [u'bilding']
# [u'alsabeel', u'aaron', u'peskin']
# [u'roedors']
# [u'hosing', u'constrcted']
# [u'certficate']
# [u'lerner']
# [u'vehiclar']
# [u'lydia', u'chavez']
# [u'ceccx', u'clifton']
# [u'san', u'francisco']

# %% [markdown]
# # important people:
# - dennis herrera , city attorney
# - aaron peskin , sf supervisor
# - jane kim , SF District 6 Supervisor
# - hilary ronen , SF District 9 supervisor
# - raymond chow , san francisco gangster/felon (high possibility)
# - Kenneth Malvar , City Sightseeing operator (high possibility)
# http://www.sfgate.com/bayarea/article/Driver-blamed-for-tour-bus-crash-in-SF-s-Union-6994435.php
#
#
# - Blake Rawdin , private MD(possibly)
# - Antonin Scalia, Supreme Court Justice (possibly)
# - charle, walton Co-Founder and Partner, Kindred Partners, LLC (possibly)
# - Henry albert , private eye doctor(possibly)
# - melanie lok , owner of mlok consulting private consulting (possibly)
# - bateman, bateman group(possibly)
# - David Owen , SF Attorney(possibly)
# - Jonah Yee, Private Eye Doctor(possibly)
# - Molly Seager, Private Therapist(possibly)
# - anson mooney(arrested)
# https://jailalert.com/arrest-records/anson-mooney-310655.html
# - alain gervais, private owner salon

# %%
#not_caught = [ '3180 18th street' , '100 church', '17th street' , '800 university avenue, palo alto, california', '17 san andreas way, san francisco' , '2631 23rd']

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF

# %%
vec=CountVectorizer(stop_words='english',analyzer='word')
X_train_counts = vec.fit_transform(word_count_sorted)
vocab = vec.get_feature_names()
nmf = NMF(n_components = 10, random_state = 1)
nmf.fit(X_train_counts)
# Out:
# NMF(alpha=0.0, beta=1, eta=0.1, init=None, l1_ratio=0.0, max_iter=200,
#   n_components=10, nls_max_iter=2000, random_state=1, shuffle=False,
#   solver='cd', sparseness=None, tol=0.0001, verbose=0)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))

# %%
print(print_top_words(nmf, clean_list, 50))
# Out:
# Topic #0:
# gtfs imagery graffiti ocean pipeline realtor_neighborhoods employment shapefile movie parking meters elevation buildings sanfrancisco.gdb sewer city owned race parking dem companies dog business license school fte hospital BART murder homeless recidivism income calls for service land-use lidar current year road network bicycle parking traffic citylots muni home sales elevation sfpd fires shapefile street neighborhood business license trees json street cleaning contracts building
# Topic #1:
# noise bay area parking taxi parcels SFMTA Bikeway Network san francisco streets supervisor districts building data graffiti Gentrification parcels historic districts meters airport Fire senior centers population recidivism chapter 20 pedestrian high injury SF solar map GPS crash human rights affordable housing evictions Street parking city map parcels BAN grafitti neighborhood city survey budget zoning house census bicycle accidents population neighborhood crime crime median income charity shapefile street library dataset gis evictions counties
# Topic #2:
# road network census museum shapefile street counties building sanfrancisco.gdb airport playground schedule e trees jobs pipeline building age median income business facilities planning AIDS cleaning avl crim recidivism restroom GPS libraries crime rates trees census shapefile labor playgrounds intersection housing inventory bus pipeline school shapefiles contour zoning planning neighborhoods cnn Tower gps street sweeping street cleaning restaurants footprints json homeless building footprint
# Topic #3:
# SF Shoreline and Islands human waste recidivism dog AIDS census shapefile bicycle birch realtor_neighborhoods bicycle current year map police incidents lidar cleaning historic zoning addresses airport pedestrian streets district highways soil crime building mission bay museum building footprints parking meters building height Crime soils SFPD reported incidents street centerline building footprint Restaurant city owned population building heights registered business locations pipeline businesses BART housing inventory survey retail crime land-use sfo
# Topic #4:
# street sweeping building footprint sanfrancisco.gdb historic planning assessor income planning police street cleaning bicycle police contracts bicycle parking meters earthquake trees hospital zip code block group landuse land-use temperature no parking parking cso bay area open business low income businesses restaurants residential elevation crim curbs street cleaning shapefiles pizza human waste human waste pipeline 2015 grocery store json business account number parcel dispensary city survey city survey airport sewer
# Topic #5:
# street evaluation building realtor_neighborhoods human waste sfpd housing price projects eviction notices planning district parcels parcel bike shapefile trail criminal budget school bicycle parking fte POPOS school businesses income shape files assessor property roll bikeshare street business account number inspection food zip code 311 call building age census light purchase order building evictions homeless fire station parking homeless population current year public schools language water assessor shapefile parking book contracts alikhani
# Topic #6:
# bay area cmt building age business data mental health sewer crime maps neighborhood buildings parcel POPOS current year crime curbs income permits BLOCK schedule e building ocean poverty Restaurant Restaurant charity zoning districts median income motionloft murder residential ocean 311 cases GDP sfo sewer Food truck historic business pipeline election results pipeline AIDS cad housing campaign business license airbnb water employee compensation supervisor districts bike
# Topic #7:
# dog employment shapefile ems FOIA block lot Murders traffic count counties events FOOTPRINT building age Restaurant Murder bike park hospital lobbyist contacts short term rental Movie locations traffic noise eviction building footprint parking charity business license taxi PARCELS bay area castro crime incident cost of living employees Restaurant shoreline eviction green space budget permit SF solar map healthcare pedestrian high injury IoE assessor property roll housing pipeline q4 chapter 20 census elevation water hospital shore line
# Topic #8:
# california accessor building footprint chapter 20 accident facilities street map bicycle parking parking Restaurant payroll assessment roll sfo library dataset drug use charity mental health shore line dem assault bike film locations income business license Murders median income Murder json historic districts retail building footprint bike lane contours POPOS Rent museum street trees crime data fleet parking meters permit shape files resturaunt hotels campaign finance library POPOS bikeshare pay CRIME
# Topic #9:
# json building building footprint realtor_neighborhoods human waste land-use police incidents ocean parcels shoreline Restaurant race bicycle accidents Restaurant hotels crime basemap drug use restaurant campaign homeless population dem footprints shapfiles street sweeping population taxi purchase order homeless cad trees block lot income bicycle parking address parcel parking museum bike parking parks parcel neighborhoods libraries envista community gardens secured property roll businesss New businesses Murder businesses
# None

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(word_count_sorted)
indices = np.argsort(vectorizer.idf_)
features = vectorizer.get_feature_names()
top_n = 100
top_features = [features[i] for i in indices[:top_n]] 

print top_features
# Out:
# [u'san', u'francisco', u'street', u'city', u'business', u'shapefile', u'data', u'of', u'census', u'building', u'map', u'parking', u'sf', u'and', u'bay', u'water', u'crime', u'housing', u'bike', u'area', u'district', u'public', u'traffic', u'property', u'block', u'in', u'streets', u'food', u'open', u'code', u'districts', u'campaign', u'population', u'income', u'use', u'tax', u'car', u'neighborhood', u'bicycle', u'2000', u'fire', u'by', u'buildings', u'health', u'gis', u'2015', u'community', u'transit', u'pipeline', u'planning', u'school', u'park', u'market', u'permit', u'land', u'parks', u'permits', u'number', u'bus', u'police', u'parcel', u'zip', u'muni', u'2010', u'for', u'zoning', u'center', u'460', u'sfpd', u'rent', u'finance', u'2014', u'neighborhoods', u'blocks', u'county', u'businesses', u'lines', u'commercial', u'ca', u'facilities', u'locations', u'space', u'service', u'construction', u'schedule', u'registered', u'no', u'rate', u'boundary', u'311', u'development', u'tree', u'incidents', u'assessor', u'art', u'network', u'tracts', u'services', u'restaurant', u'inventory']

# %% [markdown]
# # Recommendations:
#
# - spell corrector for mispelled words
# - recommendations for words while typing of words of correct search keywords, fuzzy matching
# - education for how to properly use the open data portal
