# %% [markdown]
# Search Data Processing
# =========================

# %%
import numpy as np
import pandas as pd
import re
import string
import pyspark

# %%
search_data = pd.read_csv("./data/sample_openData_searchTerms_clean.csv")

# %%
search_data.shape
# Out:
# (5000, 8)

# %%
search_data.tail()
# Out:
#                          Search Term  \
# 4995                   address range
# 4996               address shapefile
# 4997  address to geographic location
# 4998     address with resident names
# 4999                        addresse
#
#                                               Exit Page  \
# 4995  /Geographic-Locations-and-Boundaries/Streets-o...
# 4996  /browse/embed?category=&limit=20&limitTo=&q=ad...
# 4997  /browse/embed?category=&limit=20&limitTo=&q=ad...
# 4998  /browse/embed?category=&limit=20&limitTo=&q=ad...
# 4999  /browse/embed?category=&limit=20&limitTo=&q=po...
#
#       Total Unique Searches  Results Pageviews / Search % Search Exits  \
# 4995                      2                         1.5          0.00%
# 4996                      2                         1.5          0.00%
# 4997                      2                         1.0          0.00%
# 4998                      2                         1.0          0.00%
# 4999                      2                         1.0          0.00%
#
#      % Search Refinements Time after Search  Average Search Depth
# 4995                0.00%           0:02:09                   8.0
# 4996               66.67%           0:00:18                   3.0
# 4997                0.00%           0:00:03                   1.5
# 4998                0.00%           0:00:05                   1.5
# 4999              100.00%           0:00:03                   1.5

# %%
#search_data[search_data['Total Unique Searches']<5]

# %%
search_terms = list(set(search_data['Search Term']))

# %%
len(search_terms)
# Out:
# 2451

# %%
#print search_terms

# %%
search_data.ix[search_data["Search Term"] == "194415"]
# Out:
#      Search Term                                          Exit Page  \
# 3519      194415  /Economy-and-Community/Registered-Business-Loc...
#
#       Total Unique Searches  Results Pageviews / Search % Search Exits  \
# 3519                      2                           1          0.00%
#
#      % Search Refinements Time after Search  Average Search Depth
# 3519                0.00%           0:00:06                   2.5

# %%
search_terms_data = search_data[["Search Term"]]
search_terms_data = search_terms_data.rename(columns={"Search Term": "search_term"})

# %%
search_terms_data.head()
# Out:
#   search_term
# 0    business
# 1       crime
# 2       crime
# 3         311
# 4     streets

# %%
search_terms_data['processed_data'] = search_terms_data.search_term\
                                        .apply(lambda text: text.decode('ascii' ,"ignore" ).decode('utf-8','ignore'))\
                                        .apply(lambda text: text.lower())

# %%
search_terms_list =  list(set(search_terms_data.processed_data))
#print search_terms_list

# %% [markdown]
# #### We need to generally tag searches in categories of quality
#
# Many search terms indicate that users are not informed on what the purpose of the website is or how to properly use search
#
# Search Tags
# * Good Quality Search
#     * complete words or phrases
#     * minor typos
# * Bad Quality
#     * Addresses
#     * Dates
#     * Zipcodes or just a string of numbers
#     * General nonsenses eg. ('></script><script>alert(1)</script>', '///', '16exc-3031')

# %%
dates_r = re.compile('[0-9]/[0-9]/[0-9]')
numbers_r = re.compile('^[0-9][0-9]*[0-9]$')
html_r = re.compile('^<.*>$')

# %%
filter(dates_r.match, search_terms_list)
# Out:
# [u'9/1/01', u'3/1/01']

# %%
print filter(html_r.match, search_terms_list)
# Out:
# [u'</script><script>alert(1)</script>']

# %%
# removing punctuation

def removePunctuation(text):

    for c in string.punctuation:
        text = text.replace(c,"").strip().lower()
    return text

# %%
# iterative process

def text_processing(search):
    
    return [removePunctuation(i) for i in search]

# %%
search = text_processing(search_terms_list)
#search

# %%
regex = "\d{1,4}.?\d{0,4}\s[a-zA-Z|\d+]{2,30}\s[a-zA-Z]|\s[a-zA-Z]*"

f = [re.findall(regex, i) for i in search
     if re.findall(regex, i)!= [] 
     if re.findall(regex, i)[0][:3] != '311'
     ]

# http://regexlib.com/REDetails.aspx?regexp_id=430

# %%
year = [str(j) for j in range(2000,2017)]

addresses = [i for i in f if i[0][:4] not in year ]
#addresses

# %%
# applying existing code to the full data

query = pd.read_csv("./data/all_queries.csv")

# %%
query.head()
# Out:
#   ga.searchKeyword ga.searchStartPage  \
# 0            crime                 '/
# 1         business                 '/
# 2              311                 '/
# 3            crime                 '/
# 4          streets                 '/
#
#                        ga.searchAfterDestinationPage  ga.searchUniques  \
# 0                                '/data?search=crime               451
# 1                             '/data?search=business               319
# 2                                  '/data?search=311               221
# 3  '/browse/embed?Department-Metrics_Publishing-D...               200
# 4                              '/data?search=streets               169
#
#    ga.avgSearchResultViews  ga.avgSearchDepth  ga.percentSearchRefinements  \
# 0                 1.066519               0.00                     0.000000
# 1                 1.106583               0.00                     0.000000
# 2                 1.135747               0.00                     0.000000
# 3                 1.070000               4.54                    12.149533
# 4                 1.047337               0.00                     0.000000
#
#    ga.searchDuration  ga.searchExitRate
# 0                 62                  0
# 1                  5                  0
# 2                  7                  0
# 3              48646                  0
# 4                  3                  0

# %%
len(query)
# Out:
# 116339

# %%
query.shape
# Out:
# (116339, 9)

# %%
# seeing the data

query_list =  list(query['ga.searchKeyword'].values)
query_list = [str(word).decode('ascii' ,"ignore" ).decode('utf-8','ignore') for word in query_list]

# %%
set_query = len(set(query_list))
set_query
# Out:
# 20600

# %%
#adresses
regex = "\d{1,4}.?\d{0,4}\s[a-zA-Z|\d+|\W+]{2,30}\s[a-zA-Z]{2,15}"

full = [re.findall(regex, i) for i in query_list
     if re.findall(regex, i)!= [] 
     if re.findall(regex, i)[0][:3] != '311'
     ]

# %%
def search_term_type(text):
    regex = "\d{1,4}.?\d{0,4}\s[a-zA-Z|\d+|\W+]{2,30}\s[a-zA-Z]{2,15}"
    links = "((https?|http):((//)|(\\\\))+[\w\d:#@%/;$()~_?\+-=\\\.&]*)|www.*"
    #link = '[\w\d:#@%/;$()~_?\+-=\\\.&]*'
    years = [str(i) for i in range(2000,2017)]
    if len(re.findall(regex, text))> 0 and re.findall(regex, text)[0][:4] not in years and re.findall(regex, text)[0][:3] != '311':
        return "Address"
    if len(re.findall(links, text))> 0:
        return "Link"
    if len(re.findall(regex, text))> 0 and re.findall(regex, text)[0][:4] in years:
        return "Year"
    
    return "Valid Search Term"

# %%
years = [str(i) for i in range(2000,2017)]

# %%
string = 'data for crime'
search_term_type(string)
# Out:
# 'Valid Search Term'

# %%
query['Search Type'] = ['blank'] * len(query)

# %%
keywords = list(query['ga.searchKeyword'].values)

# %%
types = [search_term_type(str(word)) for word in keywords]

# %%
query['Search Type'] = types

# %%
query.to_csv('all_queries_w')

# %%
Address = query[query['Search Type'] == 'Address']
Address
# Out:
#                                          ga.searchKeyword  \
# 1552                                 460 forms Schedule A
# 2364               1010 fitzgerald ave, san francisco, ca
# 2365                               1600 California street
# 2366                                1996-2013 city survey
# 2367                                       2 hour parking
# 2368                                       2 hour parking
# 2379                                  2598 Mission Street
# 2403                                       405 howard st.
# 2417                               5 thomas mellon circle
# 4879                                    "120 lake street"
# 5195                    0 Beatrice Rd, Brisbane, CA 94005
# 5263                           06/19/2015 dashiell hammet
# 5271                          1 Embarcadero San Francisco
# 5272                                   1 Hawkins Ln SF CA
# 5273                                     1 Longview Court
# 5274                                            1 Polk st
# 5276                                      1 Tuscany Alley
# 5278                                       1 hour parking
# 5282                                            1 post st
# 5284                                       1 scott street
# 5285                                 1 south van ness ave
# 5286                                      1 south vanness
# 5289                                   1. BRIAN DUSSEAULT
# 5291                                        10 gb dataset
# 5292                                   10 glendale street
# 5297                                    100 church street
# 5298                                       100 delano ave
# 5300                                       100 year flood
# 5301                                 100 year flood plain
# 5302                           100 year storm flood plain
# ...                                                   ...
# 83568                NAD 83 California State Plane Zone 3
# 84247   Permits for 2 hour street parking 2999 Califor...
# 84523                                     Q1 2015 pipline
# 86018   Statement of Economic Interests (SEI) (Form 70...
# 86019   Statement of Economic Interests (SEI) (Form 70...
# 86020   Statement of Economic Interests Database (SEI)...
# 86205                 Subway 388 Market Street, Suite 102
# 86553   Transit Corridors 0 Miles 1 Note: For Neighbor...
# 88209                               ap 201 california llc
# 88210                               ap 201 california llc
# 88211                               ap 201 california llc
# 88212                               ap 201 california llc
# 88213                               ap 201 california llc
# 88214                         ap 201 california owner llc
# 88215                         ap 201 california owner llc
# 88216                         ap 201 california owner llc
# 88355                              areas 1000 feet school
# 92806            business registration 32 richland avenue
# 96557   Transit Corridors 0 Miles 1 Note: For Neighbor...
# 98213                               ap 201 california llc
# 98214                               ap 201 california llc
# 98215                               ap 201 california llc
# 98216                               ap 201 california llc
# 98217                               ap 201 california llc
# 98218                         ap 201 california owner llc
# 98219                         ap 201 california owner llc
# 98220                         ap 201 california owner llc
# 98359                              areas 1000 feet school
# 102810           business registration 32 richland avenue
# 107978                                       d5 zip codes
#
#                                        ga.searchStartPage  \
# 1552                                                   '/
# 2364                                                   '/
# 2365                                           (entrance)
# 2366                                                   '/
# 2367                                           (entrance)
# 2368                                           (entrance)
# 2379                                                   '/
# 2403                                           (entrance)
# 2417                                                   '/
# 4879                                                   '/
# 5195                                           (entrance)
# 5263    '/browse/embed?Department-Metrics_Publishing-D...
# 5271                                                   '/
# 5272                                                   '/
# 5273    '/browse/embed?category=Housing+and+Buildings&...
# 5274    '/browse/embed?Department-Metrics_Publishing-D...
# 5276    '/browse/embed?category=Public+Safety&limit=20...
# 5278    '/browse/embed?Department-Metrics_Publishing-D...
# 5282                                           (entrance)
# 5284                                                   '/
# 5285    '/browse/embed?Department-Metrics_Publishing-D...
# 5286                                                   '/
# 5289    '/browse/embed?Department-Metrics_Publishing-D...
# 5291    '/browse/embed?Department-Metrics_Publishing-D...
# 5292                                                   '/
# 5297                                                   '/
# 5298    '/browse/embed?category=Housing+and+Buildings&...
# 5300    '/browse/embed?category=&limit=20&limitTo=&q=b...
# 5301                                                   '/
# 5302                                                   '/
# ...                                                   ...
# 83568   '/browse/embed?category=Geographic+Locations+a...
# 84247   '/data?search=Permits+for+2+hour+street+parkin...
# 84523                       '/data?search=Q1+2015+pipline
# 86018   '/data?search=+Statement+of+Economic+Interests...
# 86019   '/data?search=+Statement+of+Economic+Interests...
# 86020   '/data?search=+Statement+of+Economic+Interests...
# 86205   '/data?search=Subway+388+Market+Street,+Suite+102
# 86553   '/data?search=Transit+Corridors+0+Miles+1+Note...
# 88209   '/browse/embed?Department-Metrics_Publishing-D...
# 88210   '/browse/embed?category=&limit=20&limitTo=&q=a...
# 88211   '/data?category=Culture and Recreation&dept=&t...
# 88212                 '/data?search=ap+201+california+llc
# 88213                 '/data?search=ap+201+california+llc
# 88214   '/browse/embed?category=&limit=20&limitTo=&q=&...
# 88215           '/data?search=ap+201+california+owner+llc
# 88216   '/data?search=ap+201+california+owner+llc&dept...
# 88355   '/data?search=areas+1000+feet+school&dept=&cat...
# 92806   '/data?search=business+registration+32+richlan...
# 96557   '/data?search=Transit+Corridors+0+Miles+1+Note...
# 98213   '/browse/embed?Department-Metrics_Publishing-D...
# 98214   '/browse/embed?category=&limit=20&limitTo=&q=a...
# 98215   '/data?category=Culture and Recreation&dept=&t...
# 98216                 '/data?search=ap+201+california+llc
# 98217                 '/data?search=ap+201+california+llc
# 98218   '/browse/embed?category=&limit=20&limitTo=&q=&...
# 98219           '/data?search=ap+201+california+owner+llc
# 98220   '/data?search=ap+201+california+owner+llc&dept...
# 98359   '/data?search=areas+1000+feet+school&dept=&cat...
# 102810  '/data?search=business+registration+32+richlan...
# 107978                         '/data?search=d5+zip+codes
#
#                             ga.searchAfterDestinationPage  ga.searchUniques  \
# 1552    '/browse/embed?category=&limit=20&limitTo=&q=4...                 3
# 2364    '/data?search=1010+fitzgerald+ave,+san+francis...                 2
# 2365                 '/data?search=1600+California+street                 2
# 2366    '/browse/embed?category=&limit=20&limitTo=&q=1...                 2
# 2367    '/browse/embed?category=&limit=20&limitTo=&q=2...                 2
# 2368                         '/data?search=2+hour+parking                 2
# 2379                    '/data?search=2598+Mission+Street                 2
# 2403    '/browse/embed?category=Energy+and+Environment...                 2
# 2417                 '/data?search=5+thomas+mellon+circle                 2
# 4879                      '/data?search="120+lake+street"                 1
# 5195    '/browse/embed?category=&limit=20&limitTo=&q=0...                 1
# 5263    '/browse/embed?Department-Metrics_Publishing-D...                 1
# 5271    '/browse/embed?Department-Metrics_Publishing-D...                 1
# 5272    '/browse/embed?Department-Metrics_Publishing-D...                 1
# 5273    '/data?search=1+Longview+Court&dept=&category=...                 1
# 5274    '/browse/embed?Department-Metrics_Publishing-D...                 1
# 5276    '/browse/embed?Department-Metrics_Publishing-D...                 1
# 5278    '/data?search=1+hour+parking&dept=&category=Tr...                 1
# 5282    '/browse/embed?category=&limit=20&limitTo=&q=1...                 1
# 5284    '/browse/embed?category=&limit=20&limitTo=&q=1...                 1
# 5285    '/data?search=1+south+van+ness+ave&dept=&categ...                 1
# 5286                        '/data?search=1+south+vanness                 1
# 5289    '/data?search=1. BRIAN+DUSSEAULT+&dept=&catego...                 1
# 5291    '/browse/embed?Department-Metrics_Publishing-D...                 1
# 5292                     '/data?search=10+glendale+street                 1
# 5297    '/browse/embed?Department-Metrics_Publishing-D...                 1
# 5298    '/data?search=100+delano+ave&dept=&category=Ho...                 1
# 5300    '/data?search=100+year+flood&dept=&category=&t...                 1
# 5301                   '/data?search=100+year+flood+plain                 1
# 5302             '/data?search=100+year+storm+flood+plain                 1
# ...                                                   ...               ...
# 83568   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 84247   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 84523   '/browse/embed?category=&limit=20&limitTo=&q=Q...                 0
# 86018   '/browse/embed?category=&limit=20&limitTo=&q=+...                 0
# 86019   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 86020   '/browse/embed?category=&limit=20&limitTo=&q=+...                 0
# 86205   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 86553   '/browse/embed?category=&limit=20&limitTo=&q=T...                 0
# 88209                 '/data?search=ap+201+california+llc                 0
# 88210   '/data?category=Culture and Recreation&dept=&t...                 0
# 88211   '/browse/embed?category=Culture+and+Recreation...                 0
# 88212                                                  '/                 0
# 88213   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 88214   '/data?search=ap+201+california+owner+llc&dept...                 0
# 88215   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 88216   '/browse/embed?category=&limit=20&limitTo=&q=a...                 0
# 88355   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 92806   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 96557   '/browse/embed?category=&limit=20&limitTo=&q=T...                 0
# 98213                 '/data?search=ap+201+california+llc                 0
# 98214   '/data?category=Culture and Recreation&dept=&t...                 0
# 98215   '/browse/embed?category=Culture+and+Recreation...                 0
# 98216                                                  '/                 0
# 98217   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 98218   '/data?search=ap+201+california+owner+llc&dept...                 0
# 98219   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 98220   '/browse/embed?category=&limit=20&limitTo=&q=a...                 0
# 98359   '/browse/embed?Department-Metrics_Publishing-D...                 0
# 102810  '/browse/embed?Department-Metrics_Publishing-D...                 0
# 107978  '/browse/embed?Department-Metrics_Publishing-D...                 0
#
#         ga.avgSearchResultViews  ga.avgSearchDepth  \
# 1552                          1           4.333333
# 2364                          1           0.000000
# 2365                          1           0.000000
# 2366                          1           3.000000
# 2367                          1           2.500000
# 2368                          1           0.000000
# 2379                          1           0.000000
# 2403                          1           2.000000
# 2417                          1           0.000000
# 4879                          1           0.000000
# 5195                          1           4.000000
# 5263                          1          10.000000
# 5271                          1           7.000000
# 5272                          1           2.000000
# 5273                          1           0.000000
# 5274                          1           3.000000
# 5276                          1           3.000000
# 5278                          1           0.000000
# 5282                          1           2.000000
# 5284                          1           3.000000
# 5285                          1           0.000000
# 5286                          1           0.000000
# 5289                          1           0.000000
# 5291                          1           3.000000
# 5292                          1           0.000000
# 5297                          1           2.000000
# 5298                          1           0.000000
# 5300                          1           0.000000
# 5301                          1           0.000000
# 5302                          1           0.000000
# ...                         ...                ...
# 83568                         0           0.000000
# 84247                         0           0.000000
# 84523                         0           0.000000
# 86018                         0           0.000000
# 86019                         0           0.000000
# 86020                         0           0.000000
# 86205                         0           0.000000
# 86553                         0           0.000000
# 88209                         0           0.000000
# 88210                         0           0.000000
# 88211                         0           0.000000
# 88212                         0           0.000000
# 88213                         0           0.000000
# 88214                         0           0.000000
# 88215                         0           0.000000
# 88216                         0           0.000000
# 88355                         0           0.000000
# 92806                         0           0.000000
# 96557                         0           0.000000
# 98213                         0           0.000000
# 98214                         0           0.000000
# 98215                         0           0.000000
# 98216                         0           0.000000
# 98217                         0           0.000000
# 98218                         0           0.000000
# 98219                         0           0.000000
# 98220                         0           0.000000
# 98359                         0           0.000000
# 102810                        0           0.000000
# 107978                        0           0.000000
#
#         ga.percentSearchRefinements  ga.searchDuration  ga.searchExitRate  \
# 1552                              0               1982                  0
# 2364                              0                  0                  0
# 2365                              0                  0                  0
# 2366                              0                 77                  0
# 2367                             50                 65                  0
# 2368                              0                  0                  0
# 2379                              0                  0                  0
# 2403                              0                 19                  0
# 2417                              0                  0                  0
# 4879                              0                  0                  0
# 5195                              0                 41                  0
# 5263                              0                  8                  0
# 5271                              0                 19                  0
# 5272                              0                 10                  0
# 5273                              0                  0                  0
# 5274                              0                 30                  0
# 5276                              0                  7                  0
# 5278                              0                  0                  0
# 5282                            100                 51                  0
# 5284                              0                 42                  0
# 5285                              0                  0                  0
# 5286                              0                  0                  0
# 5289                              0                  0                  0
# 5291                              0                101                  0
# 5292                              0                  0                  0
# 5297                            100                 31                  0
# 5298                              0                  0                  0
# 5300                              0                  0                  0
# 5301                              0                  0                  0
# 5302                              0                  0                  0
# ...                             ...                ...                ...
# 83568                             0                113                  0
# 84247                           100                 17                  0
# 84523                           100                 13                  0
# 86018                           100                 19                  0
# 86019                           100                 26                  0
# 86020                           100                 74                  0
# 86205                           100                 18                  0
# 86553                           100                  6                  0
# 88209                             0                  0                  0
# 88210                             0                  0                  0
# 88211                             0                 12                  0
# 88212                           100                 19                  0
# 88213                             0                206                  0
# 88214                             0                  0                  0
# 88215                             0                631                  0
# 88216                             0                858                  0
# 88355                             0                  5                  0
# 92806                             0                  8                  0
# 96557                           100                  6                  0
# 98213                             0                  0                  0
# 98214                             0                  0                  0
# 98215                             0                 12                  0
# 98216                           100                 19                  0
# 98217                             0                206                  0
# 98218                             0                  0                  0
# 98219                             0                631                  0
# 98220                             0                858                  0
# 98359                             0                  5                  0
# 102810                            0                  8                  0
# 107978                          100                 31                  0
#
#        Search Type
# 1552       Address
# 2364       Address
# 2365       Address
# 2366       Address
# 2367       Address
# 2368       Address
# 2379       Address
# 2403       Address
# 2417       Address
# 4879       Address
# 5195       Address
# 5263       Address
# 5271       Address
# 5272       Address
# 5273       Address
# 5274       Address
# 5276       Address
# 5278       Address
# 5282       Address
# 5284       Address
# 5285       Address
# 5286       Address
# 5289       Address
# 5291       Address
# 5292       Address
# 5297       Address
# 5298       Address
# 5300       Address
# 5301       Address
# 5302       Address
# ...            ...
# 83568      Address
# 84247      Address
# 84523      Address
# 86018      Address
# 86019      Address
# 86020      Address
# 86205      Address
# 86553      Address
# 88209      Address
# 88210      Address
# 88211      Address
# 88212      Address
# 88213      Address
# 88214      Address
# 88215      Address
# 88216      Address
# 88355      Address
# 92806      Address
# 96557      Address
# 98213      Address
# 98214      Address
# 98215      Address
# 98216      Address
# 98217      Address
# 98218      Address
# 98219      Address
# 98220      Address
# 98359      Address
# 102810     Address
# 107978     Address
#
# [1586 rows x 10 columns]

# %%
text = '2010 us census data'
regex = "\d{1,4}.?\d{0,4}\s[a-zA-Z|\d+|\W+]{2,30}\s[a-zA-Z]{2,15}"
r = re.findall(regex, text)[0][:4]
r in range(2000,2017)
# Out:
# False

# %%
# flatten full list
full = [j for i in full for j in i]
full
# Out:
# [u'2010 census tracts',
#  u'460 forms Schedule',
#  u'1010 fitzgerald ave, san francisco, ca',
#  u'1600 California street',
#  u'1996-2013 city survey',
#  u'2 hour parking',
#  u'2 hour parking',
#  u'2011 herrera campaign contributions',
#  u'2012 SFO Customer Survey',
#  u'2013 housing inventory',
#  u'2598 Mission Street',
#  u'405 howard st',
#  u'5 thomas mellon circle',
#  u'2000 Blocks (no water',
#  u'2000 Blocks (no water',
#  u'2000 Tracts (no water',
#  u'2000 Tracts (no water',
#  u'2000 Blocks (no water',
#  u'2000 blocks (no water',
#  u'2000 tracts (no water',
#  u'2000 tracts (no water',
#  u'120 lake street',
#  u'0 Beatrice Rd, Brisbane, CA',
#  u'19/2015 dashiell hammet',
#  u'1 Embarcadero San Francisco',
#  u'1 Hawkins Ln SF CA',
#  u'1 Longview Court',
#  u'1 Polk st',
#  u'1 Tuscany Alley',
#  u'1 hour parking',
#  u'1 post st',
#  u'1 scott street',
#  u'1 south van ness ave',
#  u'1 south vanness',
#  u'1. BRIAN DUSSEAULT',
#  u'10 gb dataset',
#  u'10 glendale street',
#  u'100 church street',
#  u'100 delano ave',
#  u'100 year flood',
#  u'100 year flood plain',
#  u'100 year storm flood plain',
#  u'1000 Sutter Street',
#  u'1000 brannan street',
#  u'1000 howard st',
#  u'1008 Santiago street, san francisco',
#  u'101 SAN ALESO AVENIE',
#  u'101 utah street',
#  u'1023 vallejo street',
#  u'1033 polk street',
#  u'1040 howard st',
#  u'1049 Market Street',
#  u'1050 Sansome St',
#  u'1051 de haro',
#  u'1051 grant ave, sf',
#  u'1051 market st',
#  u'106 Powell Street',
#  u'106 grand view',
#  u'1071 Alabama St',
#  u'110 sylvan drive, san francisco',
#  u'1100 divisadero st',
#  u'11025 Carolina Place Pkwy, Pineville',
#  u'11025 Carolina Place Pkwy, Pineville',
#  u'8134, United States',
#  u'111 4th ave',
#  u'111 Ellis Street',
#  u'111 powell street',
#  u'112 7th street',
#  u'1122 Vallejo St',
#  u'1125 17th avenue',
#  u'1131 Mission St',
#  u'114 Henry street',
#  u'114 powell street, san francisco, ca',
#  u'1146a Guerrero Street, San Francisco',
#  u'1155 folsom at',
#  u'1155 folsom st',
#  u'1158 noe street',
#  u'1160 Mission St, San Francisco, cA',
#  u'1177 California st',
#  u'1188 Harrison Street',
#  u'1188 Harrrison Street',
#  u'12 hillview court',
#  u'1218 44th Ave., San Francisco',
#  u'122 farallones st',
#  u'1225 17th avenue',
#  u'123 Retiro way',
#  u'1230 markert st',
#  u'1230 market st',
#  u'1231 20th ave, san francisco',
#  u'1231 MArket St',
#  u'1235 Florida Street',
#  u'1238 39th avenue',
#  u'124 Molimo dr',
#  u'126 fillmore street',
#  u'126 fillmore stret',
#  u'127 san jose ave',
#  u'129 randall st',
#  u'13 Melrose ave',
#  u'13 Melrose ave',
#  u'13 Melrose ave',
#  u'1300 block of mcallister',
#  u'131 Franklin street',
#  u'132 corbett ave',
#  u'1327 Leavenworth St',
#  u'1328a kobbe avenue',
#  u'1343 28th avenue',
#  u'135 Post Street',
#  u'135 seacliff ave',
#  u'1355 market street san francisco',
#  u'1358 28th avenue, san francisco, ca',
#  u'1359 sacramento st',
#  u'136 arlington street',
#  u'136 rivoli street',
#  u'1363 alabama street',
#  u'1365 Noriega Street',
#  u'138 03rd street',
#  u'1381 quesada avenue',
#  u'1385 carroll ave',
#  u'1390 market street',
#  u'140 mason street',
#  u'140 new Montgomery st',
#  u'140 new Montgomery st',
#  u'1405 Van Ness Ave',
#  u'1407 EGBERT STREET SAN FRANCISCO',
#  u'1409 EGBERT STREET SAN FRANCISCO',
#  u'141 Milton Street',
#  u'141 Milton Street San Francisco, CA',
#  u'141 Milton Street San Francisco, CA',
#  u'141 eddy street',
#  u'141 eddy street sf ca',
#  u'1412 hudson ave',
#  u'1415 scott street',
#  u'1416 polk street',
#  u'1420 5th Ave., san francisco, ca',
#  u'1423 golden gate',
#  u'1426 48th avenue',
#  u'1427 11th Ave',
#  u'1428 jackson st',
#  u'1432 grove street san francisco ca',
#  u'1439 16th ave',
#  u'1442 43rd ave',
#  u'1443 46th ave',
#  u'1444 market st',
#  u'1450 green st',
#  u'1453 mission st',
#  u'1453 mission street',
#  u'1455 Custer Street',
#  u'146 galewood circle',
#  u'1480 larkin st',
#  u'150 Lawrence Ave',
#  u'150 Lawrence Ave san francisco',
#  u'1500 Mission Street',
#  u'1500 mc allister street san francisco',
#  u'1500 mc allister street san francisco',
#  u'1514 alemany blvd',
#  u'1515 s. van ness',
#  u'1523 guerrero st',
#  u'153 college ave',
#  u'155 arbor st',
#  u'155 park st san francsico ca',
#  u'1560 8th ave',
#  u'1560 howard street',
#  u'1560 howard stret',
#  u'1578 Newhall St. San Francisco',
#  u'158 maynarad st',
#  u'160 Swiss Avenue',
#  u'1600 California street',
#  u'1600 Fell street',
#  u'162 landers st',
#  u'163 Liberty Street',
#  u'163 Ney St',
#  u'163 russ st',
#  u'1630 30th Avenue',
#  u'1660 Stockton at',
#  u'1660 Stockton street',
#  u'1683 42nd Ave, San Francisco CA',
#  u'1683 7th avenue',
#  u'169 Steuart St',
#  u'169 Steuart St; San Francisco, CA',
#  u'169 Steuart St; San Francisco, CA',
#  u'1693 7th avenue',
#  u'17 San Andreas Way, San francisco',
#  u'17 Silverview Drive',
#  u'1700 Newhall street',
#  u'1700 Owens street',
#  u'1700 california st',
#  u'1709 Broderick St, San Francisco, CA',
#  u'1709 Broderick Street',
#  u'1738 Ocean Avenue San Francisco, CA',
#  u'1740 Cesar Chavez',
#  u'1740 Cesar Chavez',
#  u'1746 Church Street, San Francisco',
#  u'175 Ney Street',
#  u'1755 clay st',
#  u'177 Stillman St',
#  u'177 Stillman Street',
#  u'177 Stillman Street report',
#  u'177 Stillman Street report',
#  u'177 Stillman Street, San Francisco',
#  u'177 Stillman Street, San Francisco',
#  u'177 Stillman Street, San Francisco',
#  u'177 stillman st. sf',
#  u'177 stillman st., san francisco, ca',
#  u'1773 chestnut st',
#  u'1798 grove street',
#  u'1798 grove street',
#  u'18 latona st',
#  u'1801 silliman st',
#  u'1805 S. Van Ness',
#  u'1813 15th Street',
#  u'186 valley street',
#  u'1865 4th St, San Francisco',
#  u'1895 sacramento st',
#  u'19 rausch street',
#  u'1900 ferry route',
#  u'1917 Broderick street',
#  u'1931 35th Ave San Francisco, CA',
#  u'1939 Oakdale Ave',
#  u'1941 ocean avenue San Francisco California',
#  u'1951 oak st',
#  u'1952 larkin street',
#  u'1970 census block',
#  u'1975 Jim Jones',
#  u'1977 20th Avenue San Francisco ca',
#  u'198 waterville street, san francisco',
#  u'199 new Montgomery',
#  u'199 new Montgomery st',
#  u'199 new montgomery',
#  u'1994 Carroll Avenue',
#  u'1994 Union St',
#  u'1996-2011 City Survey Database',
#  u'1996-2013 SF City Survey',
#  u'1996-2013 city survey data',
#  u'2 Crestline Dr',
#  u'2 bedroom homesale',
#  u'2 casa way',
#  u'2 hour parking',
#  u'2 hour parking',
#  u'2 hour street parking 2999 California',
#  u'2 plus 2 bookeeping',
#  u'20 Roussea Street',
#  u'20 jones st',
#  u'200 6th st',
#  u'200 hazelwood ave',
#  u'200 mississippi street',
#  u'2000 census shapefile',
#  u'2000 census tract',
#  u'2000 census tract shapefile',
#  u'2000 census tracts',
#  u'2000 census tracts',
#  u'2000 population density',
#  u'2004 bicycle network',
#  u'2004 bike network',
#  u'2004 food vendors',
#  u'2005 Pipeline Report',
#  u'2005 housing inventory',
#  u'2005 housing inventory',
#  u'2007 housing inventory',
#  u'2007 housing inventory',
#  u'2008 crime data',
#  u'2009 housing inventory',
#  u'201 Hale Street',
#  u'2010 census block',
#  u'2010 census block centroids',
#  u'2010 census house hold data by taz',
#  u'2010 census population',
#  u'2010 census tracts',
#  u'2010 census tracts no water',
#  u'2010 map:crime incidents',
#  u'2010 population shapefile',
#  u'2010 tract population',
#  u'2010 us census data',
#  u'2010 vehicle ownership',
#  u'2011 Customer Survey Dataset',
#  u'2011 herrera campaign contributions',
#  u'2011 herrera mayor campaign contributions',
#  u'2011 mayor campaign contributions',
#  u'2011 pipeline report',
#  u'2012 Housing Inventory',
#  u'2012 SFO Customer Survey',
#  u'2012 campaign finance',
#  u'2012 campaign finance',
#  u'2012 campaign finance',
#  u'2012 census population',
#  u'2012 housing inventory',
#  u'2012 housing inventory',
#  u'2013 City Survey Report',
#  u'2013 Housing Inventory',
#  u'2013 SFO Customer Survey',
#  u'2013 building permits',
#  u'2013 census shapefile',
#  u'2013 housing inventory',
#  u'2013 housing inventory',
#  u'2013 sfpd incidents',
#  u'2014 City Serve report',
#  u'2014 Housing Inventory',
#  u'2014 census tracts',
#  u'2014 energy benchmark 285 geary',
#  u'2014 housing inventory',
#  u'2014 housing inventory',
#  u'2014 housing inventory',
#  u'2014 housing inventory',
#  u'2014 housing inventory',
#  u'2014 map:crime incidents',
#  u'2014 q4 planning pipeline',
#  u'2015 311 budget',
#  u'2015 Crime Statistics',
#  u'2015 Form 460; Schedule',
#  u'2015 Housing Inventory',
#  u'2015 Housing Inventory',
#  u'2015 Housing Inventory',
#  u'2015 Murder by race statistics',
#  u'2015 Neighborhood profiles',
#  u'2015 Q4 pipeline',
#  u'2015 budget information',
#  u'2015 city survey',
#  u'2015 crime statistics',
#  u'2015 enacted budget',
#  u'2015 housing inventory',
#  u'2015 housing inventory',
#  u'2015 residential development pipeline',
#  u'2016 Assessor map',
#  u'2016 Assessor map updates',
#  u'2016 Feb 26 arrests in bay view',
#  u'2016 budget publication',
#  u'2016 housing development',
#  u'201o census population',
#  u'2020 Ellis st',
#  u'2021 baker st',
#  u'203 Cotter st',
#  u'2030 alemany blvd',
#  u'205 Upper Terrace',
#  u'2079 15TH AVENUE',
#  u'208 caselli ave',
#  u'2090 Evans Avenue',
#  u'2096 castro street',
#  u'2124 Great Hwy',
#  u'2130 22nd St San Francisco CA',
#  u'2130 JAckson street',
#  u'2134 GREEN STREET #3 SAN FRANCISCO, CA',
#  u'2135 mission street',
#  u'2145 19th Ave, San Francisco, CA',
#  u'215 Niagara Ave Permit Parking',
#  u'2166 32nd ave',
#  u'2172 Pacific Avenue',
#  u'2174 California Street',
#  u'2190 Lombard St, San Francisco, CA',
#  u'220 30th Ave',
#  u'2200 market permit',
#  u'2201 Market Street',
#  u'2208 MISSION STREET',
#  u'2208 Mission Street',
#  u'221 san carlos',
#  u'2211 stockton st',
#  u'224 ordway st',
#  u'2240 Market Street',
#  u'2243 32nd Avenue',
#  u'2250 POWELL STREET',
#  u'2259 25th ave',
#  u'2275 sutter st',
#  u'2279 Mission Street',
#  u'2282 Market Street',
#  u'2282 market st',
#  u'2282 market street',
#  u'2283 37th ave',
#  u'230 Eddy Street',
#  u'2310 mason street',
#  u'2325 Pine Street',
#  u'233 San Carlos',
#  u'2332 TARAVAL ST SF',
#  u'2338 TARAVAL ST SF',
#  u'2349 Francisco St',
#  u'235 Presidio Avenue',
#  u'2385 bush st',
#  u'2385 bush street',
#  u'239 carl street',
#  u'2394 Mariner Square Drive, Alameda, CA',
#  u'240 2nd Street',
#  u'240 Dolores St',
#  u'2400 14th avenue',
#  u'2400 CALIFORNIA ST SAN FRANCISCO CA',
#  u'2412 Harrison st',
#  u'245 San Jose',
#  u'2455 Polk Street',
#  u'246 2nd street',
#  u'2462 30th street',
#  u'250 Executive park',
#  u'2500 bryant st, san francisco ca',
#  u'251 frederick st',
#  u'252 27TH Ave, San Francisco, CA',
#  u'255 King Stree',
#  u'256 Fowler Ave',
#  u'2577 1/2 post street',
#  u'258 9 th st',
#  u'258 9th st',
#  u'26 eagle street',
#  u'260 church st',
#  u'2650 green, Sf',
#  u'2652 Harrison St',
#  u'2652 Harrison St',
#  u'2660 San Bruno Avenue, San Francisco',
#  u'267 Green Street',
#  u'267 Green Street',
#  u'269 joost ave',
#  u'2695 43rd avenue',
#  u'270 McAllister Street',
#  u'270 McAllister Street, San Francisco',
#  u'277 Columbus Ave',
#  u'278 states street',
#  u'280 circular ave',
#  u'282 harbor rd san francsico, ca',
#  u'284 12th avenue',
#  u'285 geary st',
#  u'285 geary st energy audit',
#  u'288 GOLD MINE DRIVE',
#  u'29 Downey st',
#  u'2901 sacramento st',
#  u'2911 16th st police',
#  u'2912 19th ave',
#  u'2915 Octavia St',
#  u'2919 folsom st',
#  u'2919 folsom st',
#  u'2919 mission street',
#  u'2919-21 folsom st',
#  u'2922 sacramento street',
#  u'2923 lawton st',
#  u'2945 baker st apt',
#  u'2950 Vallejo st, sf',
#  u'2950 valajo st, sf',
#  u'299 Fremont Street',
#  u'3 buena vista ave east, sf',
#  u'3 rudden avenue sf ca',
#  u'300 sea cliff',
#  u'3000 Washington Street 4000 Washington',
#  u'3008 18th street',
#  u'301 Claremont Blvd',
#  u'301 baltimore way',
#  u'301 king st',
#  u'3024 mission st',
#  u'3024 mission st',
#  u'3060 16th Street',
#  u'3060 16th Street building',
#  u'3067 25th street',
#  u'3067 25th street san francisco ca',
#  u'307 Niagra Ave',
#  u'308 Font blvd',
#  u'3092 16th St',
#  u'31 Mullen ave',
#  u'313 POTRERO AVE',
#  u'3130 Webster St San Francisco, CA',
#  u'3139 mission street',
#  u'3143 folsom st',
#  u'315 28th avenue',
#  u'317 oak park dr',
#  u'3180 18th Street, San Francisco, CA',
#  u'32 richland avenue steven holland',
#  u'321 marietta drive',
#  u'322 30th ave',
#  u'323 cumberland st',
#  u'324 arkansas st',
#  u'3247 reserve ct, san jose, ca',
#  u'329 bryant street san francisco, ca',
#  u'33 Albion Street',
#  u'33 allston way',
#  u'331 jersey st',
#  u'331 jersey st parcel map',
#  u'3314 STEINER ST',
#  u"333 O'Farrell St, San Francisco, CA",
#  u'333 lake street',
#  u'333 market street',
#  u'333 market street energy',
#  u'3333 California Street',
#  u'334 harriet st',
#  u'336 moraga ave',
#  u'337 spurce st san francisco ca',
#  u'337 spurce streeet',
#  u'337 spurce street',
#  u'340 church st',
#  u'340 mason street',
#  u'340 mason street investors',
#  u'340 warren drive san francisco, ca',
#  u'3401 clement st',
#  u'342 24th ave',
#  u'3434 21st st',
#  u'3440 Broderick Street',
#  u'345 Williams Avenue',
#  u'345 Williams Avenue, San Francisco',
#  u'345 spear st',
#  u'3465 25th st',
#  u'347 precita Ave San Francisco CA',
#  u'347-349 Precita Ave',
#  u'3490 20th st',
#  u'350 2nd st',
#  u'350 laurel st san francisco',
#  u'350 mission street',
#  u'3520 18th partners',
#  u'3520 18th partners Business Account Number',
#  u'353 BEACH RD, BURLINGAME, CA',
#  u'354 Peralta Street',
#  u'355 1st street',
#  u'355 Bocana Street',
#  u'355 Serrano dr',
#  u'357 Hayes St',
#  u'360 somerset st',
#  u'360 somerset street',
#  u'361 3rd ave',
#  u'372 Point Lobos Ave',
#  u'374 5th street san francisco',
#  u'375 bush street',
#  u'3750 18 street sf ca',
#  u'376 ellis street',
#  u'3800 16th street san francisco, ca',
#  u'3864 23rd street',
#  u'3864 23rd street ban',
#  u'387 ellis street',
#  u'387 ellis street, san francisco, ca',
#  u'390 Fremont St',
#  u'390 diamond street',
#  u'3938 Geary Blvd. San Francisco, CA',
#  u'3951 Mission St',
#  u'3953 24th street',
#  u'397 9th St',
#  u'3D Building Model',
#  u'3D building model',
#  u'3D building models',
#  u'3D building models',
#  u'3D public art',
#  u'3d building model',
#  u'4 PERSIA AVENUE',
#  u'40 Annapolis Terrace, San Francisco',
#  u'40 genebern way, sf',
#  u'40 jessie street',
#  u'400 Castro Street',
#  u'400 Castro soul cycle',
#  u'400 Duboce Street',
#  u'405 howard st',
#  u'4058 17th st',
#  u'407 jackson st',
#  u'407 sanchez street',
#  u'409 Dolores Street',
#  u'41 genebern way, sf',
#  u'4130 mission street',
#  u'4130 mission street',
#  u'415 Euclid Ave',
#  u'415 Jones St',
#  u'415 myra way',
#  u'4175 Mission St',
#  u'418 Jessie St',
#  u'4182 Mission Street',
#  u'42 jules avenue',
#  u'424 octavia st',
#  u'425 10th st',
#  u'425 market energy',
#  u'425 market street',
#  u'425 market street energy',
#  u'428 chicago way',
#  u'43 ruth street, san francisco',
#  u'430 lake st',
#  u'439 Duboce Ave',
#  u'44 samoset st',
#  u'442 holloway ave., SF',
#  u'4431 mission st',
#  u'444 de haro st',
#  u'444 townsend st',
#  u'447 Broadway Street',
#  u'450 golden gate',
#  u'450 golden gate',
#  u'453 masonic st',
#  u'456 montgomery street suite 2200 san',
#  u'459 geary LLC',
#  u'46 El Sereno Court',
#  u'460 dwight street',
#  u'460 forms Schedule',
#  u'460 forms Schedule',
#  u'460 forms Schedule',
#  u'460 forms Schedule',
#  u'460 forms Schedule',
#  u'460 forms schedul',
#  u'460 forms schedula',
#  u'460 forms schedule',
#  u'460 forms schedule',
#  u'460 forms schedule',
#  u'460 forms schedule',
#  u'460 post street',
#  u'460 post street business search',
#  u'4610 mission street',
#  u'462 DOUGLASS SR',
#  u'462 DOUGLASS ST',
#  u'466 9th avenue',
#  u'4689 mission st',
#  u'469 eddy street',
#  u'469 union st',
#  u'470 lake st',
#  u'476 Ellington Ave',
#  u'476 Ellington ave',
#  u'478 utah st',
#  u'487 dolores st',
#  u'487 dolores street',
#  u'49 Christopher Dr, San Francisco, CA',
#  u'49 Christopher Dr, San Francisco, CA',
#  u'49 mile scenic drive',
#  u'49 south park st',
#  u'490 POST ST',
#  u'495 geary street',
#  u'5 DAY WATER RELATED',
#  u'5 Hudson Ct, San Francisco, CA',
#  u'5 year plan',
#  u'50 Main Street, San Francisco',
#  u'50 quint street',
#  u'501 The Embarcadero; San Francisco',
#  u'501 columbus Ave',
#  u'5060 WEST 14TH STREET GREELEY CO',
#  u'508 Haight st',
#  u'519 capp street san francisco',
#  u'521 clement street',
#  u'525 29th st',
#  u'5252 mission street',
#  u'527 42nd ave',
#  u'530 Brannan Street',
#  u'530 brannan street',
#  u'530 brannan street business lincenses',
#  u'5300 3rd street',
#  u'534 4th street',
#  u'5400 mission san francisco',
#  u'5413 Hillside av.,el cerrito',
#  u'5413 Hillside av.,el cerrito',
#  u'543 19TH AVE',
#  u'543 columbus Ave',
#  u'544 Castro St',
#  u'545 sutter street, san francisco',
#  u'548 Banks St, San Francisco',
#  u'55 Cyril Magnin Street',
#  u'550 3rd street san francisco ca',
#  u'550 Van Ness',
#  u'554 irving street, san francisco',
#  u'555 4th st',
#  u'555 market street',
#  u'555 minnesota street',
#  u'56 moss st',
#  u'560 davis st san francisco',
#  u'560 mission street',
#  u'562 Monterey Blvd, San Francisco, CA',
#  u'568 Brannan St',
#  u'573 andover street',
#  u'576 natoma st, san francisco, ca',
#  u'579 Teresita Blvd',
#  u'5800 3rd St',
#  u'584 filbert street',
#  u'589 Post St, San Francisco, CA',
#  u'595 Market Street, San Francisco, CA',
#  u'60 Garcia ave',
#  u'60 agua way',
#  u'600 Van Ness',
#  u'600 fell st',
#  u'600 san bruno ave',
#  u'601 laguna street',
#  u'601 van ness ave',
#  u'606 post street',
#  u'610 page street',
#  u'619 Missouri St., San Francisco, CA',
#  u'619 union street',
#  u'62 Allston way',
#  u'62 linden avenue, san bruno, ca',
#  u'62 washburn st',
#  u'620 Green Street',
#  u'622 Green Street',
#  u'625 46th ave',
#  u'626 Green Street',
#  u'631 cole st',
#  u'631 folsom st',
#  u'64 Perine Place, Sf',
#  u'650 40th ave',
#  u'654 46th Avenue',
#  u'663 haight street',
#  u'665 pine st',
#  u'67 Silverview Drive',
#  u'675 Naples Street',
#  u'677 page st',
#  u'677-679 page st',
#  u'679 Page STreet',
#  u'679 san jose san Francisco',
#  u'68 cervantes blvd',
#  u'689 20th avenue',
#  u'690 folsom street',
#  u'690 long bridge street',
#  u'700 pennsylvania ave',
#  u'701 GOLDEN GATE AV',
#  u'701 Minnesota street',
#  u'701 Teresita San Francisco, CA',
#  u'705 vallejo street',
#  u'709 geary st',
#  u'71 ford st',
#  u'711 clayton st',
#  u'72 hour parking restriction',
#  u'721 18th avenue',
#  u'729 Shotwell St',
#  u'735 fell street',
#  u'739 Washington Street, Suite',
#  u'74 6th Street',
#  u'74 granada avenue san francisco',
#  u'744 MONTGOMERY ST',
#  u'749-757 Jackson St',
#  u'75 Dore Street',
#  u'750 Sutter St, San Francisco, CA',
#  u'754 moultrie group',
#  u'755 union st',
#  u'755 union st owner name',
#  u'760 Geary Steet',
#  u'766 vallejo street',
#  u'77 beale street buildings',
#  u'77 san juan ave',
#  u'78 Ina Court',
#  u'79 Midcrest Way',
#  u'80.004 Employee Compensation report',
#  u'800 university avenue, palo alto, california',
#  u'810 Dolores san francisco, ca',
#  u'810 clay street, san francisco, ca',
#  u'812 Guerrero Street',
#  u'815 laguna honda',
#  u'820 jones street',
#  u'822 Irving St',
#  u'823 lake street',
#  u'829 york street',
#  u'83 leo street',
#  u'83 mc allister st 513, san francisco',
#  u'83 mc allister st, san francisco, ca',
#  u'83 mcallister st, san francisco',
#  u'8300 Oceanview Terrace',
#  u'8300 Oceanview Terrace, 304, San Francisco',
#  u'838 detroit street',
#  u'838 grant ave',
#  u'846 Junipero Serra blvd',
#  u'855 folsom st, san francisco',
#  u'857 39th Ave',
#  u'882 31st ave',
#  u'887 45th ave',
#  u'887 4th ave',
#  u'899 Howard Street San Francisco, CA',
#  u'9 county boundary',
#  u'9 geneva ave',
#  u'9 geneva ave',
#  u'90 day cases',
#  u'916 pine street',
#  u'929 oak st',
#  u'929 oak st., sf, ca',
#  u'933 treat ave',
#  u'939 jackson st',
#  u'94 stratford drive',
#  u'944 treat av',
#  u'944 treat ave',
#  u'944 treat avenue',
#  u'959 noe street',
#  u'960 howard street',
#  u'970 key ave',
#  u'595 Market Street, San Francisco, CA',
#  u'460 - Schedule A - Monetary Contributions',
#  u'460 - Schedule E - Payments Made',
#  u'460 - Schedule a - Payments Made',
#  u'465 - Supplemental Independent Expenditure',
#  u'3 - Independent Expenditures Made',
#  u'3, 2015 Election',
#  u'460 cover Page',
#  u'460 cover Page',
#  u'4 2014 Election',
#  u'2000 Block Group',
#  u'2000 Blocks (no water',
#  u'2000 Blocks (no water',
#  u'2000 Blocks (no water',
#  u'2000 Blocks (no water) Census',
#  u'2000 Tracts (no water',
#  u'2000 Tracts (no water',
#  u'2000 Tracts (no water',
#  u'2000 Tracts (no water',
#  u'2000 Tracts (no water',
#  u'2000 block group',
#  u'2010: Census Block Groups',
#  u'2015 in San Francisco',
#  u'5 year plan',
#  u'202 24th ave sf',
#  u'355 24th ave',
#  u'2. Increase jobs that provide healthy',
#  u'65 AND OLDER',
#  u'14 Street Sidewalk Evaluation Results',
#  u'2130 22nd St San Francisco CA',
#  u'90 day emergency shelter waitlist',
#  u'90 day emergency shelter waitlist',
#  u'38 Air Pollutant Exposure Zone',
#  u'1975 Jim Jones',
#  u'98 battery st suite',
#  u'98 battery st suite',
#  u'15% fund raising target',
#  u'403 main st',
#  u'65 in zip code',
#  u'65 in zip code',
#  u'65 in zip code',
#  u'2 2015 pipeline',
#  u'5m water rise',
#  u'5m water rise',
#  u'5m water rise',
#  u'445 Athens Street',
#  u'445 Athens Street',
#  u'445 Athens Street',
#  u'83 California State Plane Zone',
#  u'88 INVESTMENT PARTNERS, LLC',
#  u'2 hour street parking 2999 California',
#  u'39 liveaboard marina',
#  u'1 2015 pipline',
#  u'700) - Filers with unpaid late filing',
#  u'700) Filers with unpaid late filing fees',
#  u'700) Non Filers',
#  u'388 Market Street, Suite',
#  u'0 Miles 1 Note: For Neighborhood Commercial',
#  u'5: Generalized Neighborhoods Commercial',
#  u'00 Use: ArcMap 1:70,650 scale for this',
#  u'0 Miles 1 Note: For Neighborhood Commercial',
#  u'5: Generalized Neighborhoods Commercial',
#  u'00 Use: ArcMap 1:70,650 scale for this',
#  u'2010 Demographic Profile Data, SF County',
#  u'201 california llc',
#  u'201 california owner llc',
#  u'2015 richmond district',
#  u'1000 feet school',
#  u'32 richland avenue',
#  u'2000 Block group',
#  u'2000 Tracts (no water',
#  u'2000 block (no water',
#  u'2000 block goup',
#  u'2000 block group',
#  u'2000 block group',
#  u'2000 block group',
#  u'2000 blocks (no water',
#  u'2000 blocks (no water',
#  u'2000 blocks (no water',
#  u'2000 blocks (no water',
#  u'2000 blocks (no water',
#  u'2000 blocks (no water',
#  u'2000 blocks (no water',
#  u'2000 blocks no water',
#  u'2000 blocks no water',
#  u'2000 no water',
#  u'2000 no water',
#  u'2000 no water',
#  u'2000 tracts (no water',
#  u'2000 tracts (no water',
#  u'2000 tracts (no water',
#  u'2000 tracts (no water',
#  u'2000 tracts (no water',
#  u'2000 tracts (no water',
#  u'2000 tracts no water',
#  u'2000 tracts no water',
#  u'2010 block groups',
#  u'2010 block groups',
#  u'2010 census block for san francisco',
#  u'2010 census block for san francisco',
#  u'2010 census blocks',
#  u'2010 census blocks for san francisco',
#  u'2010 census blocks for san francisco',
#  u'2010: census blocks',
#  u'2010: census blocks for san',
#  u'2010: census blocks for san',
#  u'2010: census blocks for san francisco',
#  u'2010: census blocks for san francisco',
#  u'2000 no water',
#  u'2000 tracts (no water',
#  u'2000 no water',
#  u'5 zip codes',
#  u'2009 sfo survey',
#  u'460 cover apge',
#  u'26 curtis street san francisco',
#  u'8300 Oceanview Terrace 304, San Francisco',
#  u'1 to April',
#  u'98 battery st suite',
#  u'15% fund raising target',
#  u'403 main st',
#  u'348 church street',
#  u'65 in zip code',
#  u'2 2011 pipeline',
#  u'2 2011 pipeline report',
#  u'2 2015 pipeline',
#  u'5m water rise',
#  u'202 4th ave',
#  u'1618 POLK ST SAN FRANCISCO, CA, US',
#  u'5 immigrants in california',
#  u'5m water rise',
#  u'445 Athens Street',
#  u'120 lake street',
#  u'19/2015 dashiell hammet',
#  u'1 Hawkins Ln SF CA',
#  u'1 Hawkins Ln SF CA',
#  u'1 Longview Court',
#  u'1 hour parking',
#  u'1 scott street',
#  u'1 scott street',
#  u'1 south van ness ave',
#  u'1 south vanness',
#  u'1. BRIAN DUSSEAULT',
#  u'10 gb dataset',
#  u'10 glendale street',
#  u'10 glendale street',
#  u'10 glendale street',
#  u'10 glendale street',
#  u'10 glendale street',
#  u'100 delano ave',
#  u'100 delano ave',
#  u'100 delano ave',
#  u'100 delano ave',
#  u'100 delano ave',
#  u'100 delano ave',
#  u'100 delano ave',
#  u'100 year flood',
#  u'100 year flood',
#  u'100 year flood plain',
#  u'100 year storm flood plain',
#  u'1000 brannan street',
#  u'1008 Santiago street, san francisco',
#  u'1008 Santiago street, san francisco',
#  u'1008 Santiago street, san francisco',
#  u'101 SAN ALESO AVENIE',
#  u'1010 fitzgerald ave, san francisco, ca',
#  u'1010 fitzgerald ave, san francisco, ca',
#  u'1033 polk street',
#  u'1033 polk street',
#  u'1040 howard st',
#  u'1049 Market Street',
#  u'1051 de haro',
#  u'1051 grant ave, sf',
#  u'1051 grant ave, sf',
#  u'1051 grant ave, sf',
#  u'1051 market st',
#  u'106 Powell Street',
#  u'106 Powell Street',
#  u'1071 Alabama St',
#  u'110 sylvan drive, san francisco',
#  u'1100 divisadero st',
#  u'111 4th ave',
#  u'111 powell street',
#  u'112 7th street',
#  u'1122 Vallejo St',
#  u'1131 Mission St',
#  u'114 Henry street',
#  u'114 powell street, san francisco, ca',
#  u'114 powell street, san francisco, ca',
#  u'114 powell street, san francisco, ca',
#  u'114 powell street, san francisco, ca',
#  u'1146a Guerrero Street, San Francisco',
#  u'1160 Mission St, San Francisco, cA',
#  u'1177 California st',
#  u'12 hillview court',
#  u'1218 44th Ave., San Francisco',
#  u'122 farallones st',
#  u'1230 markert st',
#  u'1230 markert st',
#  u'1230 market st',
#  u'1230 market st',
#  u'1230 market st',
#  u'1231 20th ave, san francisco',
#  u'1231 MArket St',
#  u'1235 Florida Street',
#  u'1238 39th avenue',
#  u'129 randall st',
#  u'1300 block of mcallister',
#  u'1300 block of mcallister',
#  u'132 corbett ave',
#  u'1327 Leavenworth St',
#  u'1328a kobbe avenue',
#  u'1328a kobbe avenue',
#  u'1343 28th avenue',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'135 Post Street',
#  u'1355 market street san francisco',
#  u'1355 market street san francisco',
#  u'1355 market street san francisco',
#  u'1355 market street san francisco',
#  u'138 03rd street',
#  u'138 03rd street',
#  u'138 03rd street',
#  u'138 03rd street',
#  u'138 03rd street',
#  u'138 03rd street',
#  u'138 03rd street',
#  u'1381 quesada avenue',
#  u'1385 carroll ave',
#  u'1390 market street',
#  u'1390 market street',
#  u'140 mason street',
#  u'1405 Van Ness Ave',
#  u'1405 Van Ness Ave',
#  ...]

# %%
year_full = [str(j) for j in range(2000,2017)]
# taking out the years

addresses_full = [i for i in full if i[:4] not in year ]
addresses_full = list(set(addresses_full))

# %%
year_listing = [i.lower() for i in full if i[:4] in year ]
year_listing = list(set(year_listing))
year_listing
# Out:
# [u'2000 block group',
#  u'2007 housing inventory',
#  u'2010 census block for san francisco',
#  u'2000 blocks (no water',
#  u'2010 census tracts no water',
#  u'2010: census blocks for san',
#  u'2016 assessor map',
#  u'2010 census population',
#  u'2015 crime statistics',
#  u'2014 energy benchmark 285 geary',
#  u'2009 sfo survey',
#  u'2015 enacted budget',
#  u'2010 tract population',
#  u'2015 housing inventory',
#  u'2013 city survey report',
#  u'2012 campaign finance',
#  u'2005 pipeline report',
#  u'2000 tracts no water',
#  u'2014 city serve report',
#  u'2016 budget publication',
#  u'2000 census tract',
#  u'2011 mayor campaign contributions',
#  u'2000 block goup',
#  u'2012 sfo customer survey',
#  u'2015 richmond district',
#  u'2010 demographic profile data, sf county',
#  u'2015 in san francisco',
#  u'2015 form 460; schedule',
#  u'2014 map:crime incidents',
#  u'2011 herrera campaign contributions',
#  u'2015 residential development pipeline',
#  u'2004 bicycle network',
#  u'2010 vehicle ownership',
#  u'2008 crime data',
#  u'2015 murder by race statistics',
#  u'2000 census tracts',
#  u'2000 census shapefile',
#  u'2010 census block',
#  u'2010: census block groups',
#  u'2010: census blocks',
#  u'2012 housing inventory',
#  u'2013 housing inventory',
#  u'2015 budget information',
#  u'2010 block groups',
#  u'2000 block (no water',
#  u'2011 customer survey dataset',
#  u'2013 building permits',
#  u'2011 herrera mayor campaign contributions',
#  u'2010 census blocks',
#  u'2000 census tract shapefile',
#  u'2014 q4 planning pipeline',
#  u'2015 q4 pipeline',
#  u'2010: census blocks for san francisco',
#  u'2010 population shapefile',
#  u'2000 blocks (no water) census',
#  u'2000 blocks no water',
#  u'2010 census blocks for san francisco',
#  u'2015 311 budget',
#  u'2009 housing inventory',
#  u'2015 city survey',
#  u'2000 no water',
#  u'2014 census tracts',
#  u'2004 food vendors',
#  u'2014 housing inventory',
#  u'2000 population density',
#  u'2010 census block centroids',
#  u'2000 tracts (no water',
#  u'2010 us census data',
#  u'2005 housing inventory',
#  u'2016 housing development',
#  u'2010 map:crime incidents',
#  u'2016 feb 26 arrests in bay view',
#  u'2013 sfpd incidents',
#  u'2016 assessor map updates',
#  u'2010 census house hold data by taz',
#  u'2015 neighborhood profiles',
#  u'2010 census tracts',
#  u'2013 census shapefile',
#  u'2011 pipeline report',
#  u'2013 sfo customer survey',
#  u'2004 bike network',
#  u'2012 census population']

# %%
#clean_list = sc.parallelize(query_list).filter(lambda word: word.lower() not in addresses_full).collect()

# %%
clean_list = [i for i in query_list if i.lower() not in addresses_full]
#clean_list

# %%
links = "((https?|http):((//)|(\\\\))+[\w\d:#@%/;$()~_?\+-=\\\.&]*)"

https = [re.findall(links, i) for i in clean_list
     if re.findall(links, i)!= [] 
     if re.findall(links, i)!= "//" 
     ]
# http://stackoverflow.com/questions/6718633/python-regular-expression-again-match-url

# %%
# finding all the unique links that people have put into the search query

# https = (sc.parallelize(https).flatMap(lambda word: word)
#         .flatMap(lambda word: word)
#         .filter(lambda word: word != '//')
#         .filter(lambda word: word != 'https')
#         .filter(lambda word: word != '''''')
#         .filter(lambda word: word != 'http')
#         .collect())

# %%
https = [i[0] for i in https]

# %%
https
# Out:
# [u'https://data.sfgov.org/Public-Health/Excessive-Rent-Burden-San-Francisco-CA/9wty-qwgq',
#  u'https://data.sfgov.org/Public-Health/Restaurant-Scores/stya-26eb',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://www.bsis.ca.gov/forms_pubs/fire_fact.shtml',
#  u'http://www.datasf.org/story.php?title=street-sweeper-schedule-and-route-',
#  u'https://10.183.241.201/rgcertprintv2default.aspx',
#  u'https://data.sfgov.org/Economy-and-Community/Off-Sale-Alcohol-Outlets-San-Francisco-CA/fIy-9zhp',
#  u'https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis',
#  u'https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis?',
#  u'https://data.sfgov.org/d/ejmn-jyk6',
#  u'https://data.sfgov.org/data?category=',
#  u'https://data.sfgov.org/data?category=Transportation',
#  u'https://extxfer.sfdph.org/food/',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.kaggle.com/c/sf-crime',
#  u'https://data.sfgov.org/Public-Health/Excessive-Rent-Burden-San-Francisco-CA/9wty-qwgq',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://googlewebmastercentral.blogspot.com/2014/11/helping-users-find-mobile-friendly-pages.html',
#  u'http://www.bsis.ca.gov/forms_pubs/fire_fact.shtml',
#  u'https://10.183.241.201/rgcertprintv2default.aspx',
#  u'https://10.183.241.201/rgcertprintv2default.aspx',
#  u'https://10.183.241.201/rgcertprintv2default.aspx',
#  u'https://data.sfgov.org/Economy-and-Community/Off-Sale-Alcohol-Outlets-San-Francisco-CA/fIy-9zhp',
#  u'https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis?',
#  u'https://data.sfgov.org/d/ejmn-jyk6',
#  u'https://data.sfgov.org/data?category=Transportation',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain',
#  u'https://www.fiverr.com/kawsarhossain']

# %%
# clean_list = (sc.parallelize(query_list).map(lambda word: word.lower()).filter(lambda word: word not in https)
#               .filter(lambda word: word not in addresses_full)
#               .collect())

# %%
clean_list = [word for word in query_list if word not in https if word not in addresses_full]

# %%
from collections import Counter
word_count = Counter(clean_list)
word_count_sorted = sorted(word_count.items(),key = lambda x: x[1], reverse=True)

# %%
word_count_sorted = [i[0] for i in word_count_sorted if i[1]>2]
word_count_sorted
# Out:
# [u'crime',
#  u'streets',
#  u'shapefile',
#  u'parking',
#  u'census',
#  u'street',
#  u'bike',
#  u'business',
#  u'building',
#  u'311',
#  u'population',
#  u'parks',
#  u'neighborhood',
#  u'water',
#  u'bicycle',
#  u'traffic',
#  u'income',
#  u'parcel',
#  u'fire',
#  u'housing',
#  u'school',
#  u'rent',
#  u'muni',
#  u'elevation',
#  u'buildings',
#  u'homeless',
#  u'parcels',
#  u'land use',
#  u'neighborhoods',
#  u'bus',
#  u'zoning',
#  u'restaurant',
#  u'boundary',
#  u'food',
#  u'bart',
#  u'roads',
#  u'park',
#  u'address',
#  u'pipeline',
#  u'police',
#  u'schools',
#  u'san francisco',
#  u'budget',
#  u'property',
#  u'transit',
#  u'assessor',
#  u'city',
#  u'gis',
#  u'trees',
#  u'restaurants',
#  u'bridge',
#  u'construction',
#  u'shapefiles',
#  u'pedestrian',
#  u'block',
#  u'businesses',
#  u'taxi',
#  u'transportation',
#  u'building footprints',
#  u'health',
#  u'business license',
#  u'tree',
#  u'building footprint',
#  u'district',
#  u'graffiti',
#  u'education',
#  u'permit',
#  u'census tract',
#  u'car',
#  u'building permits',
#  u'blocks',
#  u'sfmta',
#  u'road',
#  u'airport',
#  u'districts',
#  u'affordable housing',
#  u'bay area',
#  u'city boundary',
#  u'business licenses',
#  u'noise',
#  u'hospital',
#  u'map',
#  u'topography',
#  u'open space',
#  u'accidents',
#  u'street cleaning',
#  u'sewer',
#  u'Crime',
#  u'zip code',
#  u'real estate',
#  u'permits',
#  u'shoreline',
#  u'basemap',
#  u'eviction',
#  u'parking meter',
#  u'aerial',
#  u'salary',
#  u'alcohol',
#  u'contour',
#  u'air',
#  u'GIS',
#  u'accident',
#  u'age',
#  u'demographics',
#  u'demographic',
#  u'energy',
#  u'assessment',
#  u'weather',
#  u'census shapefile',
#  u'tax',
#  u'flood',
#  u'planning',
#  u'sfpd',
#  u'employment',
#  u'addresses',
#  u'bus stops',
#  u'air quality',
#  u'contours',
#  u'evictions',
#  u'centerline',
#  u'bike lanes',
#  u'bay',
#  u'waste',
#  u'cancer',
#  u'sidewalk',
#  u'census tracts',
#  u'parking meters',
#  u'library',
#  u'centerlines',
#  u'coffee',
#  u'bars',
#  u'art',
#  u'lobbyist',
#  u'poverty',
#  u'meter',
#  u'building permit',
#  u'zip codes',
#  u'cleaning',
#  u'boundaries',
#  u'census block',
#  u'footprint',
#  u'zip',
#  u'landuse',
#  u'development pipeline',
#  u'census 2000',
#  u'facilities',
#  u'base map',
#  u'public schools',
#  u'density',
#  u'460',
#  u'hotel',
#  u'sidewalks',
#  u'bike network',
#  u'highway',
#  u'city lots',
#  u'census 2010',
#  u'topo',
#  u'curb',
#  u'911',
#  u'json',
#  u'business registration',
#  u'street sweeping',
#  u'bike parking',
#  u'soil',
#  u'sales',
#  u'retail',
#  u'climate',
#  u'public transportation',
#  u'population density',
#  u'curbs',
#  u'caltrain',
#  u'shore',
#  u'race',
#  u'open spaces',
#  u'intersections',
#  u'kml',
#  u'children',
#  u'csv',
#  u'campaign finance',
#  u'parking tickets',
#  u'bikeway',
#  u'housing inventory',
#  u'college',
#  u'building height',
#  u'chinatown',
#  u'employee',
#  u'rental',
#  u'public',
#  u'commercial',
#  u'sfo',
#  u'light',
#  u'citation',
#  u'recreation',
#  u'wind',
#  u'STREETS',
#  u'lots',
#  u'community',
#  u'city limits',
#  u'hospitals',
#  u'vegetation',
#  u'shelter',
#  u'rail',
#  u'earthquake',
#  u'food truck',
#  u'2015',
#  u'crimes',
#  u'height',
#  u'STREET',
#  u'tourism',
#  u'supervisor',
#  u'survey',
#  u'base',
#  u'campaign',
#  u'imagery',
#  u'residential',
#  u'cad',
#  u'streets of san francisco',
#  u'shp',
#  u'BART',
#  u'human waste',
#  u'street parking',
#  u'address locator',
#  u'tract',
#  u'inventory',
#  u'slope',
#  u'tickets',
#  u'poop',
#  u'fire incidents',
#  u'tow',
#  u'historic',
#  u'Streets',
#  u'property assessment',
#  u'job',
#  u'vacant',
#  u'price',
#  u'building heights',
#  u'Parking',
#  u'crime data',
#  u'bus stop',
#  u'vendor',
#  u'SFMTA',
#  u'vehicle',
#  u'intersection',
#  u'footprints',
#  u'complaints',
#  u'bicycle parking',
#  u'cnn',
#  u'location',
#  u'garbage',
#  u'2014',
#  u'bridges',
#  u'MUNI',
#  u'homicide',
#  u'events',
#  u'ethnicity',
#  u'land',
#  u'film',
#  u'trail',
#  u'port',
#  u'rent control',
#  u'route',
#  u'street names',
#  u'liquor',
#  u'libraries',
#  u'ortho',
#  u'open business',
#  u'SFO',
#  u'animal',
#  u'street centerlines',
#  u'Muni',
#  u'street trees',
#  u'Traffic',
#  u'tenderloin',
#  u'bus routes',
#  u'insurance',
#  u'Tree',
#  u'food trucks',
#  u'shape file',
#  u'registered business',
#  u'inclusionary housing',
#  u'census blocks',
#  u'sfshore',
#  u'speed',
#  u'shoreline shapefile',
#  u'mobile food',
#  u'ambulance',
#  u'public space',
#  u'block group',
#  u'violation',
#  u'SFPD',
#  u'gps',
#  u'cable',
#  u'board of supervisors',
#  u'grocery',
#  u'street light',
#  u'freeway',
#  u'meters',
#  u'collision',
#  u'disabled',
#  u'childcare',
#  u'bikes',
#  u'green',
#  u'bike lane',
#  u'utilities',
#  u'hotels',
#  u'contracts',
#  u'affordable',
#  u'stclines',
#  u'violations',
#  u'bike share',
#  u'asthma',
#  u'incidents',
#  u'ban',
#  u'jobs',
#  u'house',
#  u'orthophoto',
#  u'airbnb',
#  u'license',
#  u'homelessness',
#  u'calls for service',
#  u'citations',
#  u'highways',
#  u'salaries',
#  u'median income',
#  u'inclusionary',
#  u'traffic density',
#  u'police districts',
#  u'museum',
#  u'coast',
#  u'colleges',
#  u'pollution',
#  u'bayview',
#  u'solar',
#  u'ferry',
#  u'incident',
#  u'dem',
#  u'public housing',
#  u'bay area general',
#  u'property tax',
#  u'spending',
#  u'garden',
#  u'presidio',
#  u'network',
#  u'street map',
#  u'building age',
#  u'sfpark',
#  u'green space',
#  u'business account number',
#  u'wifi',
#  u'ticket',
#  u'real time',
#  u'article 11',
#  u'Water',
#  u'topographic',
#  u'development',
#  u'shape',
#  u'fire stations',
#  u'seismic',
#  u'supervisor district',
#  u'electricity',
#  u'traffic count',
#  u'parcel data',
#  u'emergency',
#  u'.shp',
#  u'Uber',
#  u'city survey',
#  u'planning neighborhoods',
#  u'supervisor districts',
#  u'ocean',
#  u'community gardens',
#  u'mission bay',
#  u'city blocks',
#  u'San Francisco',
#  u'crime incidents',
#  u'registered businesses',
#  u'uber',
#  u'inspection',
#  u'HIV',
#  u'electricity use',
#  u'stormwater',
#  u'Business',
#  u'household income',
#  u'trash',
#  u'internet',
#  u'Street',
#  u'zoning districts',
#  u'bernal lot size',
#  u'medical',
#  u'theft',
#  u'temperature',
#  u'Fire',
#  u'benches',
#  u'church',
#  u'DEM',
#  u'article 10',
#  u'TRANSPORTATION',
#  u'utility',
#  u'payroll',
#  u'parking lots',
#  u'housing prices',
#  u'citylots',
#  u'treasure island',
#  u'something',
#  u'farmers market',
#  u'speed limit',
#  u'image',
#  u'lidar',
#  u'sfpd incidents',
#  u'CRIME',
#  u'injury',
#  u'fire station',
#  u'watershed',
#  u'cafe',
#  u'fire department',
#  u'unemployment',
#  u'wireless',
#  u'berkeley',
#  u'apartment buildings',
#  u'311 cases',
#  u'china',
#  u'movie',
#  u'car ownership',
#  u'paving',
#  u'rain',
#  u'market',
#  u'child',
#  u'sweeping',
#  u'bicycle accidents',
#  u'border',
#  u'county',
#  u'zipcode',
#  u'3d',
#  u'compensation',
#  u'murder',
#  u'complaint',
#  u'trails',
#  u'zone',
#  u'station',
#  u'terrain',
#  u'vendors',
#  u'right of way',
#  u'child care',
#  u'year built',
#  u'bay trail',
#  u'truck',
#  u'vote',
#  u'airports',
#  u'crime rate',
#  u'employees',
#  u'Census',
#  u'water bodies',
#  u'bicycle accident',
#  u'outline',
#  u'parking citation',
#  u'train',
#  u'election',
#  u'Trimmers',
#  u'speeding',
#  u'Housing',
#  u'open',
#  u'assessment roll',
#  u'property value',
#  u'parking ticket',
#  u'social',
#  u'dpt_bike_network',
#  u'bird',
#  u'police district',
#  u'cab',
#  u'Neighborhood',
#  u'north beach',
#  u'parking citations',
#  u'cable car',
#  u'Taxi',
#  u'landmark',
#  u'revenue',
#  u'housing price',
#  u'travel',
#  u'tech',
#  u'air pollution',
#  u'feces',
#  u'drug',
#  u'geology',
#  u'bank',
#  u'envista',
#  u'vendor payments',
#  u'death',
#  u'oakland',
#  u'dpw',
#  u'SanFrancisco.gdb',
#  u'dog',
#  u'form 700',
#  u'streets shapefile',
#  u'job density',
#  u'recycling',
#  u'coastal',
#  u'biz point',
#  u'Food',
#  u'api',
#  u'road map',
#  u'hazard',
#  u'police stations',
#  u'pipe',
#  u'arrests',
#  u'Water Bodies in San Francisco',
#  u'obesity',
#  u'bench',
#  u'biking',
#  u'public transit',
#  u'Parcel',
#  u'bike theft',
#  u'stations',
#  u'census2000',
#  u'ridership',
#  u'auto',
#  u'liquefaction',
#  u'traffic counts',
#  u'sweep',
#  u'geojson',
#  u'94110',
#  u'precinct',
#  u'dbi',
#  u'hydrology',
#  u'center lines',
#  u'dumping',
#  u'mta',
#  u'sf shore',
#  u'city features',
#  u'garage',
#  u'traffic accident',
#  u'camera',
#  u'tobacco',
#  u'popos',
#  u'on street parking',
#  u'traffic accidents',
#  u'arterial',
#  u'lobbyists',
#  u'apn',
#  u'allergies',
#  u'transit stops',
#  u'routes',
#  u'agriculture',
#  u'transport',
#  u'bus accidents',
#  u'Restaurant',
#  u'street centerline',
#  u'bus lines',
#  u'film locations',
#  u'bar',
#  u'ZIP',
#  u'universities',
#  u'chicago',
#  u'2010 census',
#  u'pole',
#  u'avenida epitacio pessoa ipanema rio de janeiro',
#  u'Pipeline',
#  u'lobby',
#  u'wine',
#  u'food inspection',
#  u'flooding',
#  u'collisions',
#  u'ethics',
#  u'campaign consultant',
#  u'marriage',
#  u'2010',
#  u'street network',
#  u'bike route',
#  u'planning districts',
#  u'advisories',
#  u'Building Footprints',
#  u'economic',
#  u'university',
#  u'busines',
#  u'san francisco streets',
#  u'pipeline 2015',
#  u'finance',
#  u'address points',
#  u'case',
#  u'museums',
#  u'bathroom',
#  u'raster',
#  u'contract',
#  u'SFMTA Bikeway Network',
#  u'illegal dumping',
#  u'hiv',
#  u'Zoning Districts',
#  u'dataset inventory',
#  u'crime map',
#  u'canopy',
#  u'sffd',
#  u'traffic volume',
#  u'cannabis',
#  u'owner',
#  u'sfusd',
#  u'water usage',
#  u'public art',
#  u'SanFrancisco',
#  u'photo',
#  u'inspections',
#  u'clean',
#  u'speed limits',
#  u'movies',
#  u'services',
#  u'high injury',
#  u'business district',
#  u'latitude',
#  u'cities',
#  u'toilet',
#  u'chinese',
#  u'castro',
#  u'pavement',
#  u'streetlight',
#  u'sfdph',
#  u'census 2000 tracts (no water)',
#  u'health care',
#  u'street shapefile',
#  u'beach',
#  u'restaurant inspections',
#  u'campaign Finance',
#  u'bike shapefile',
#  u'security',
#  u'fires',
#  u'landslide',
#  u'business locations',
#  u'street lights',
#  u'Restaurants',
#  u'liquor store',
#  u'rent board',
#  u'landmarks',
#  u'environment',
#  u'community center',
#  u'storm',
#  u'affordability',
#  u'building outline',
#  u'city boundaries',
#  u'technology',
#  u'expenditures',
#  u'center line',
#  u'san francisco crime',
#  u'city limit',
#  u'census 2000 tracts',
#  u'Neighborhoods',
#  u'traffic tickets',
#  u'pipeline 2012',
#  u'healthcare',
#  u'road network',
#  u'Zoning',
#  u'lights',
#  u'maher',
#  u'performance',
#  u'Street cleaning',
#  u'google',
#  u'building outlines',
#  u'data catalog',
#  u'clinic',
#  u'Business Account Number',
#  u'parcel map',
#  u'telegraph hill',
#  u'general plan',
#  u'taz',
#  u'point',
#  u'household',
#  u'street sweep',
#  u'facility',
#  u'Parks',
#  u'time',
#  u'data',
#  u'eviction notices',
#  u'public health',
#  u'counties',
#  u'bikeway network',
#  u'SFFind Neighborhoods',
#  u'nonprofit',
#  u'lot',
#  u'muni routes',
#  u'bus route',
#  u'maintenance',
#  u'benchmark',
#  u'car sharing',
#  u'active business',
#  u'shop',
#  u'property assessment roll',
#  u'street center',
#  u'traffic lights',
#  u'Vacant',
#  u'elections',
#  u'2000',
#  u'SF Development Pipeline',
#  u'coastal zone',
#  u'cases',
#  u'curb ramp',
#  u'brownfield',
#  u'Bay Area',
#  u'ZONING',
#  u'tracts',
#  u'gis data',
#  u'property values',
#  u'BIKE',
#  u'subway',
#  u'bayview hunters point',
#  u'golden gate',
#  u'names',
#  u'animals',
#  u'building construction',
#  u'vacancy',
#  u'restaurant inspection',
#  u'Health',
#  u'cell phone',
#  u'business registration certificate',
#  u'census 2000 blocks',
#  u'cost',
#  u'burglary',
#  u'commuting',
#  u'coastline',
#  u'pipeline 2013',
#  u'san francisco map',
#  u'wind monitoring',
#  u'bike accidents',
#  u'pothole',
#  u'condominium',
#  u'restroom',
#  u'drain',
#  u'youth',
#  u'aspect',
#  u'cctv',
#  u'tourist',
#  u'street tree',
#  u'Police Districts',
#  u'plant',
#  u'open spaces city planning',
#  u'prostitution',
#  u'CNN',
#  u'tax lots',
#  u'fiber',
#  u'low income',
#  u'avl',
#  u'UNIVERSITY OF SAN FRANCISCO',
#  u'small business',
#  u'altitude',
#  u'below market rate',
#  u'parklet',
#  u'median rent',
#  u'mortgage',
#  u'uncashed',
#  u'parklets',
#  u'bikeshare',
#  u'river',
#  u'search DataSF',
#  u'gardens',
#  u'birth',
#  u'form 460',
#  u'creek',
#  u'parking lot',
#  u'tree canopy',
#  u'lobbyist activity',
#  u'home',
#  u'eas',
#  u'.csv',
#  u'census 2000 blocks (no water)',
#  u'lyft',
#  u'commute',
#  u'maps',
#  u'prices',
#  u'metro',
#  u'injuries',
#  u'precipitation',
#  u'dog patch',
#  u'parking violations',
#  u'shooting',
#  u'appeals',
#  u'building use',
#  u'property owner',
#  u'land cover',
#  u'developer',
#  u'realtor',
#  u'walk',
#  u'police station',
#  u'certified payroll',
#  u'boundry',
#  u'BAN',
#  u'pbc',
#  u'business location',
#  u'fte',
#  u'grocery store',
#  u'base mao',
#  u'water quality',
#  u'licenses',
#  u'Police',
#  u'bay area counties',
#  u'Schools',
#  u'grocery stores',
#  u'sweeper',
#  u'buisness',
#  u'zipcodes',
#  u'private schools',
#  u'public works',
#  u'Building',
#  u'farmers markets',
#  u'Parking meters',
#  u'appraisal roll',
#  u'lobbying',
#  u'entitlements',
#  u'Property Assessment',
#  u'railroad',
#  u'TAZ',
#  u'WATER',
#  u'rape',
#  u'city facilities',
#  u'street sweeping schedule',
#  u'Campaign Finance',
#  u'street maps',
#  u'cancer risk',
#  u'bicycle theft',
#  u'tow away',
#  u'traffic light',
#  u'precincts',
#  u'people',
#  u'resturant',
#  u'freeways',
#  u'preservation',
#  u'projects',
#  u'2013',
#  u'block groups',
#  u'county boundary',
#  u'taxes',
#  u'diabetes',
#  u'sfopenbook',
#  u'test',
#  u'catalog',
#  u'union square',
#  u'sro',
#  u'census2000_blk_nowater',
#  u'event',
#  u'muni stops',
#  u'bike routes',
#  u'foodtruck',
#  u'DUI',
#  u'baytrail',
#  u'sea level',
#  u'waterfront',
#  u'stop',
#  u'suicide',
#  u'parking restrictions',
#  u'grid',
#  u'homeless shelter',
#  u'sales tax',
#  u'industrial',
#  u'cost of living',
#  u'conference',
#  u'Pedestrian',
#  u'heat',
#  u'senior',
#  u'mental health',
#  u'SF Shoreline and Islands',
#  u'lottery',
#  u'ethnic',
#  u'sf shoreline and islands',
#  u'pdf parcel',
#  u'sexual assault',
#  u'service requests',
#  u'btod',
#  u'land value',
#  u'workforce',
#  u'ownership',
#  u'Basemap Street Centerlines shapefile',
#  u'commute time',
#  u'Taylor',
#  u'san francisco shapefile',
#  u'Bike route network',
#  u'occupation',
#  u'cases by channel',
#  u'SF Solar Map',
#  u'motorcycle',
#  u'dogs',
#  u'VMT',
#  u'sf streets',
#  u'Streets of San Francisco',
#  u'parking signs',
#  u'potholes',
#  u'sffacs',
#  u'cars',
#  u'immigration',
#  u'Ada',
#  u'water bodies in san francisco',
#  u'registered',
#  u'cell',
#  u'entertainment',
#  u'public school',
#  u'checkbook',
#  u'public library',
#  u'grade',
#  u'digital elevation model',
#  u'crime shapefile',
#  u'concealed weapons permits',
#  u'habitat',
#  u'congestion',
#  u'san francisco boundary',
#  u'recreation centers',
#  u'Bay Area - General',
#  u'excavation',
#  u'gay',
#  u'Baker Places',
#  u'tow zone',
#  u'bay outline',
#  u'dpt bike network',
#  u'candidate name',
#  u'sports',
#  u'sea level rise',
#  u'Bus',
#  u'sun',
#  u'Lyft',
#  u'san francisco shoreline',
#  u'condo',
#  u'resiliency',
#  u'street of san francisco',
#  u'women',
#  u'grafitti',
#  u'lgbt',
#  u'music',
#  u'motorcycle parking',
#  u'Shapefile',
#  u'SRO',
#  u'property records',
#  u'traffic signals',
#  u'SFFD',
#  u'open business locations',
#  u'sale',
#  u'shelters',
#  u'disabled parking',
#  u'bay area cities',
#  u'SF Flower mart',
#  u'stops',
#  u'enforcement',
#  u'arrest',
#  u'Parcels',
#  u'benchmarking',
#  u'claims',
#  u'SEWER',
#  u'central subway',
#  u'CONTOUR',
#  u'foreclosure',
#  u'sport',
#  u'planning cases',
#  u'area',
#  u'water use',
#  u'bus line',
#  u'business certificate',
#  u'neighborhood boundaries',
#  u'recycle',
#  u'companies',
#  u'bcdc',
#  u'drainage',
#  u'floodplain',
#  u'impervious',
#  u'recology',
#  u'golden gate bridge',
#  u'value',
#  u'real-time',
#  u'heights',
#  u'Diana Lerner',
#  u'news',
#  u'sanitation',
#  u'home sales',
#  u'PBC',
#  u'street center lines',
#  u'towing',
#  u'urban tree',
#  u'sf boundary',
#  u'abandoned',
#  u'mission',
#  u'incomes',
#  u'meeting time',
#  u'gang',
#  u'block lot',
#  u'sfpuc',
#  u'toilets',
#  u'Population',
#  u'form 700 schedules',
#  u'classification',
#  u'food inspections',
#  u'gdp',
#  u'map of crimes incidents',
#  u'3D',
#  u'plan',
#  u'african american health',
#  u'equity',
#  u'city outline',
#  u'religion',
#  u'manhole',
#  u'web',
#  u'pier',
#  u'employee compensation',
#  u'assess',
#  u'wetlands',
#  u'churches',
#  u'affordable housing units',
#  u'voting',
#  u'Land Use',
#  u'BUS',
#  u'pedestrian injury',
#  u'castro sf',
#  ...]

# %%
string_word = removePunctuation(re.sub("\u" , '', str(word_count_sorted)))
string_word1 = removePunctuation(re.sub("\u" , '', str(query_list)))

# %%
from polyglot.text import Text

NER = Text(string_word1)

NER = NER.entities

for entity in NER:
    if entity.tag == "I-PER":
        print entity
# Out:
# [u'bart', u'bildings']
# [u'bart']
# [u'san', u'francisco']
# [u'francisco']
# [u'francisco']
# [u'polltion']
# [u'bart', u'bart', u'bart']
# [u'bsiness']
# [u'conties']
# [u'crosswalk', u'crb']
# [u'lidar']
# [u'francisco']
# [u'bart', u'bart']
# [u'bart', u'bart', u'basemap']
# [u'bsiness']
# [u'conty', u'bondary', u'cort']
# [u'lyft', u'maher']
# [u'francisco']
# [u'san']
# [u'otline', u'san']
# [u'sanfrancisco']
# [u'ber', u'ber', u'nemployment']
# [u'xls']
# [u'fitzgerald']
# [u'san']
# [u'herrera']
# [u'howard']
# [u'thomas', u'mellon']
# [u'ada']
# [u'apns']
# [u'bart', u'bart', u'bart', u'bart']
# [u'beaty']
# [u'francisco']
# [u'gdb', u'san']
# [u'sanfrancisco']
# [u'taz', u'taz', u'taz']
# [u'adrian', u'santos']
# [u'ariel']
# [u'bart', u'bart', u'bart', u'bart', u'bart', u'bart']
# [u'bart']
# [u'bsines']
# [u'contor']
# [u'crbs']
# [u'david', u'owen']
# [u'ellis', u'ellis']
# [u'formla']
# [u'contribtions']
# [u'lyft', u'lyft', u'maher', u'maher', u'maher']
# [u'msems']
# [u'nancy', u'jeng']
# [u'noe']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'san']
# [u'san']
# [u'shapefile', u'san']
# [u'shapefile']
# [u'santa', u'clara']
# [u'rotes', u'ber', u'ber', u'ber', u'nemployment']
# [u'yearbilt']
# [u'dfsd', u'ami']
# [u'howard']
# [u'harris']
# [u'harris']
# [u'jonathan', u'pearlman', u'kate']
# [u'mary', u'jng']
# [u'sharmin', u'bock', u'sharmon', u'bock']
# [u'alain', u'gervais']
# [u'cindy']
# [u'kim', u'expenditres']
# [u'harris']
# [u'hilary', u'ronen', u'hilary']
# [u'jeanette', u'feddes', u'john', u'ortiz', u'karen']
# [u'karen']
# [u'michael', u'martinez', u'michael', u'yarne', u'miranda', u'nye', u'martin']
# [u'san']
# [u'scriptscriptalert1script']
# [u'sid', u'tsv', u'xlm']
# [u'beatrice']
# [u'dashiell', u'hammet']
# [u'hawkins']
# [u'polk']
# [u'brian', u'dusseault']
# [u'brannan']
# [u'howard']
# [u'geary']
# [u'jackson']
# [u'howard']
# [u'haro']
# [u'sylvan']
# [u'minna']
# [u'powell']
# [u'san']
# [u'noe']
# [u'harrison']
# [u'cort']
# [u'cole']
# [u'lombard']
# [u'randall']
# [u'mcallister']
# [u'avene', u'san']
# [u'carroll']
# [u'egbert']
# [u'san']
# [u'egbert']
# [u'san']
# [u'san']
# [u'san']
# [u'jackson']
# [u'lombard']
# [u'lombard']
# [u'larkin']
# [u'larkin']
# [u'lawrence', u'ave']
# [u'pacheco']
# [u'howard', u'stret']
# [u'maynard']
# [u'ney']
# [u'andreas']
# [u'san']
# [u'broderick', u'st']
# [u'broderick']
# [u'cesar', u'chavez']
# [u'cesar', u'chavez']
# [u'ney']
# [u'stillman']
# [u'stillman']
# [u'stillman']
# [u'stillman']
# [u'san']
# [u'stillman']
# [u'san']
# [u'stillman']
# [u'san']
# [u'stillman']
# [u'stillman']
# [u'stillman']
# [u'hayes']
# [u'silliman']
# [u'filbert']
# [u'broderick']
# [u'larkin']
# [u'larkin']
# [u'jim', u'jones']
# [u'avene', u'san']
# [u'carroll', u'avene']
# [u'1999reports', u'1gagf']
# [u'2br']
# [u'taz']
# [u'herrera']
# [u'contribtions']
# [u'herrera']
# [u
# [u'pickp']
# [u'piotr']
# [u'plawiak']
# [u'reyes']
# [u'indstry', u'poplation']
# [u'zipcode', u'poplation']
# [u'pritzker']
# [u'reqests']
# [u'reqests']
# [u'prchase']
# [u'prchase']
# [u'prchase']
# [u'prchases', u'prchases']
# [u'rashad', u'eid']
# [u'rashad', u'eid']
# [u'ralston']
# [u'raymond', u'chow', u'raymond', u'chow', u'raymond', u'chow']
# [u'bsinesses', u'san']
# [u'bsinesses', u'san']
# [u'remi']
# [u'repaving']
# [u'pblic']
# [u'restarant']
# [u'restarants']
# [u'restarants', u'san']
# [u'restarants', u'san', u'francisco']
# [u'restarent']
# [u'restrant']
# [u'resrfacing']
# [u'bsinesses', u'richard', u'johnson', u'richard']
# [u'richard']
# [u'richard']
# [u'richard']
# [u'richmond']
# [u'roberries', u'robert', u'walsh']
# [u'romania', u'rome', u'romwald', u'ron', u'conway']
# [u'rssell', u'rssell', u'corr']
# [u'rtherford']
# [u'ryan']
# [u'ryan']
# [u'ryan']
# [u'ryan']
# [u'ryan']
# [u'lois']
# [u'lois', u'salar', u'salar']
# [u'samson', u'chow']
# [u'francisco', u'bilding', u'san']
# [u'contor', u'san']
# [u'otline']
# [u'andreas']
# [u'andreas']
# [u'andreas']
# [u'andreas', u'falt']
# [u'diego']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'gdb', u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'basemap', u'san']
# [u'basemap', u'san']
# [u'basemap', u'san']
# [u'basemap', u'san']
# [u'basemap', u'san']
# [u'san']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bilding', u'san']
# [u'bsinesses', u'san']
# [u'bsinesses', u'san']
# [u'bsinesses']
# [u'censs', u'san']
# [u'censs', u'san']
# [u'bondary']
# [u'bondary']
# [u'crbs']
# [u'featre']
# [u'featre']
# [u'featre']
# [u'featre']
# [u'featre']
# [u'shapefile']
# [u'cityfeatres']
# [u'contor', u'san']
# [u'contor', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'bondaries']
# [u'bondaries']
# [u'bondaries']
# [u'bondary']
# [u'bondary']
# [u'bondary']
# [u'bondary']
# [u'bondary']
# [u'jrisdiction']
# [u'shapefile']
# [u'shapefile']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'crimendata', u'san']
# [u'san']
# [u'san']
# [u'districtsd']
# [u'san']
# [u'grond']
# [u'san']
# [u'san']
# [u'geodatabase', u'san']
# [u'san']
# [u'gigants', u'san']
# [u'athority']
# [u'athority']
# [u'athority']
# [u'ineqality']
# [u'san']
# [u'ineqality', u'san']
# [u'landse', u'san']
# [u'neigborhood', u'san']
# [u'neigborhoods']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline']
# [u'san']
# [u'san']
# [u'poplation', u'san']
# [u'poplation', u'san']
# [u'tilities']
# [u'bsinesses']
# [u'residental']
# [u'restarant', u'san']
# [u'restarants']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile']
# [u'stadim', u'san']
# [u'niversity']
# [u'niversity']
# [u'niversity']
# [u'niversity']
# [u'niversity']
# [u'torism', u'san']
# [u'torism', u'san']
# [u'torism', u'san']
# [u'torism']
# [u'rban', u'san']
# [u'tility']
# [u'san']
# [u'san']
# [u'san']
# [u'jose']
# [u'jose']
# [u'jose']
# [u'jose']
# [u'jose', u'san']
# [u'san', u'jose', u'gerrero', u'san']
# [u'shapefile', u'san', u'mateo']
# [u'mateo']
# [u'mateo']
# [u'mateo']
# [u'mateo']
# [u'mateo']
# [u'mateo']
# [u'sanborn', u'sanborn']
# [u'sanchex', u'sanchez', u'sanchez', u'sanchez']
# [u'sano']
# [u'santa', u'clara', u'santa', u'clara', u'santa', u'clara', u'santa', u'clara', u'santa']
# [u'santa', u'monica', u'santa']
# [u'sato', u'sattelite', u'sadi']
# [u'sadi']
# [u'sadi']
# [u'sadi']
# [u'sadi']
# [u'scanlan', u'schedle', u'schedle']
# [u'scott', u'wiener', u'scott', u'wiener']
# [u'scott', u'wiener']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'sfmta']
# [u'sfmta']
# [u'sfpd']
# [u'sfpd']
# [u'precints', u'sfpd']
# [u'shapefile']
# [u'bock', u'sharmin', u'bock', u'shana']
# [u'shevin', u'anne', u'wong']
# [u'shotspotter']
# [u'sid', u'sid', u'sid', u'siddiq']
# [u'sitepx']
# [u'skyler', u'vander']
# [u'smfta', u'smfta', u'smit']
# [u'sonia', u'wong']
# [u'soth', u'san']
# [u'soth', u'san']
# [u'soth', u'san']
# [u'san']
# [u'sothern']
# [u'speef']
# [u'spendings']
# [u'hosing']
# [u'hosing']
# [u'james', u'st', u'james', u'stadim', u'stadim', u'stadim']
# [u'starbacks']
# [u'stella', u'cen', u'stella', u'kim']
# [u'steven', u'holland', u'steven', u'holland', u'steven', u'holland', u'steven', u'holland', u'steven', u'holland', u'stitt']
# [u'sfmta', u'stitt']
# [u'sfmta', u'stitt']
# [u'sfmta', u'stitt']
# [u'sfmta', u'stitt']
# [u'sfmta', u'stitt']
# [u'sfmta', u'stitt']
# [u'sfmta', u'stitt']
# [u'sfmta', u'stitt']
# [u'san', u'francisco']
# [u'cort', u'sperior', u'cort', u'sperior', u'cort', u'sperior', u'cort', u'sperior', u'cort', u'sperior', u'cort', u'sperior', u'cort', u'sperior', u'cort', u'sperior', u'cort']
# [u'cort', u'spreme', u'cort', u'spreme', u'cort', u'spreme', u'cort', u'spreme', u'cort']
# [u'plowshares']
# [u'taiwan', u'bento', u'talbot']
# [u'tanzania', u'taqeria', u'castillo']
# [u'taz', u'taz']
# [u'taz981shp']
# [u'teaheeme']
# [u'teng', u'teng']
# [u'terain']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'raine', u'grop']
# [u'thomas', u'jones']
# [u'tian']
# [u'tilly']
# [u'tommy', u'neeson']
# [u'townsend', u'townsend']
# [u'travis']
# [u'4y3k4vs', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber']
# [u'ber']
# [u'ber']
# [u'ndergronding']
# [u'vadim', u'kogan']
# [u'vallejo', u'vallejo', u'vallejo', u'chapefile', u'vallejo', u'chapefile', u'vallejo', u'chapefile', u'vallejo']
# [u'india', u'vincent', u'vincent', u'kircher']
# [u'vincent', u'kircher']
# [u'watr', u'watson', u'watson', u'watson', u'watson', u'watson', u'watson']
# [u'weil', u'weiner', u'weiner', u'weiner', u'weiner', u'weiner']
# [u'wilfred', u'bcoy', u'william', u'jeff', u'nagel', u'william', u'nagel', u'williamson']
# [u'wong']
# [u'hor']
# [u'hor']
# [u'hor']
# [u'hor']
# [u'yearbilt']
# [u'san', u'francisco']
# [u'yoth']
# [u'poplations', u'yoth']
# [u'poplations', u'yoth']
# [u'yoth']
# [u'yoth', u'injry']
# [u'zidwolde']
# [u'wilson']
# [u'wilson']
# [u'johns']
# [u'johnny']
# [u'johnny']
# [u'jon']
# [u'jon']
# [u'jonathan', u'ross', u'josefowitz', u'joseph', u'wehrer', u'josha', u'pollak']
# [u'bonagro', u'joyce']
'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bilding', u'san']
# [u'bsstops', u'san']
# [u'shapefile']
# [u'chekin', u'san']
# [u'san']
# [u'constrction', u'san']
# [u'contors', u'san']
# [u'conty', u'san']
# [u'san']
# [u'san']
# [u'san', u'francisco']
# [u'san']
# [u'san', u'francisco', u'forsqare']
# [u'landse', u'san']
# [u'otline', u'san']
# [u'shapefile', u'san']
# [u'shapefile']
# [u'featres']
# [u'jose', u'san', u'jose']
# [u'san', u'lorenzo']
# [u'mateo']
# [u'cityies']
# [u'francisco']
# [u'francisco']
# [u'basemap', u'san']
# [u'san']
# [u'bilding', u'san']
# [u'temperatre']
# [u'sanfranciscodevelopmentpipelinedata', u'sanfranciscodevelopmentpipelineq22014', u'sanders']
# [u'sadi', u'arabia']
# [u'seyfarth', u'shaw']
# [u'shannon', u'maloney']
# [u'bock']
# [u'sophia', u'francis', u'sorce']
# [u'soth']
# [u'stanley']
# [u'steven', u'cheng', u'steven', u'holland', u'steven', u'holland', u'steyer']
# [u'san', u'francisco']
# [u'cort', u'spermarket']
# [u'tay', u'taz']
# [u'taz', u'taz']
# [u'george', u'l']
# [u'george']
# [u'tara', u'kini', u'taraval']
# [u'ted']
# [u'ble', u'thomas', u'angelo', u'tia', u'matinez']
# [u'toby']
# [u'lewis']
# [u'joseph', u'tomarah', u'l']
# [u'san', u'francisco']
# [u'shapefiles']
# [u'san']
# [u'valle']
# [u'valverde', u'constrction']
# [u'walter', u'thoma', u'wanderson', u'carlos']
# [u'morris']
# [u'wirelessservicefacilitypermits', u'wiseman']
# [u'woh']
# [u'peskin', u'aaron', u'peskin']
# [u'aaron', u'peskin', u'smmary']
# [u'aaron', u'peskin']
# [u'aaron', u'peskin']
# [u'abse']
# [u'acconting', u'acconting']
# [u'gide']
# [u'actal']
# [u'ada', u'ada', u'adams']
# [u'adrian', u'agielra', u'adrian']
# [u'aed']
# [u'agstin', u'anda', u'agstin', u'anda', u'agstin', u'anda', u'ahmed']
# [u'alain']
# [u'sf311', u'alex', u'alex', u'vartan', u'alexanderson']
# [u'alix', u'rosenthal']
# [u'scott']
# [u'amblance', u'amblance']
# [u'ami', u'ami']
# [u'santiago', u'amont']
# [u'anaya', u'andale', u'andrew', u'benton', u'andrew', u'rex', u'andrew', u'rex', u'san', u'francisco', u'andrew', u'zimmerman']
# [u'tran', u'annlatch']
# [u'tran']
# [u'anson', u'mooney']
# [u'anthony']
# [u'antioqia', u'antonin', u'scalia', u'anza']
# [u'architectre', u'architectre']
# [u'arlo', u'armin', u'arnold', u'eric', u'wong']
# [u'san', u'francisco']
# [u'apair']
# [u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart', u'rotes', u'bart']
# [u'bart']
# [u'bart', u'shapefile', u'bart', u'shapefile', u'bart', u'shapefile', u'bart', u'shapefile', u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart', u'statios', u'bart', u'stattion', u'bart']
# [u'bart']
# [u'bart']
# [u'cort']
# [u'bathymetry']
# [u'bcdc']
# [u'beaty', u'beaty', u'beaty']
# [u'behested']
# [u'conslting']
# [u'walsh']
# [u'berkley']
# [u'berkley', u'berkley', u'berlin', u'bernal']
# [u'bernal']
# [u'bernie', u'sanders', u'bert', u'polacci']
# [u'bicyle']
# [u'bikeshare']
# [u'birmingham', u'birt']
# [u'blake']
# [u'bleprints', u'bleprints']
# [u'bondaries']
# [u'brannan']
# [u'deanna', u'moore']
# [u'briscoe']
# [u'brnofilms', u'brssels', u'bryant']
# [u'bilding', u'constrction']
# [u'bilding', u'plas']
# [u'violatons']
# [u'bilding2012']
# [u'san', u'francisco', u'bildings', u'san']
# [u'bisnesses']
# [u'bart']
# [u'bsiness']
# [u'san', u'francisco', u'bsinesses']
# [u'san', u'francisco', u'bsinesses']
# [u'ots']
# [u'caribbean', u'carl', u'carla', u'narvy', u'carman', u'carmen']
# [u'sanchez', u'casale']
# [u'castro', u'castro', u'castro']
# [u'catherine']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'charles']
# [u'chaz']
# [u'yoth']
# [u'chopsticks', u'christensen', u'christensen', u'christensen', u'christensen', u'christine', u'mcnary', u'christopher']
# [u'christopher', u'webster']
# [u'claremont']
# [u'clearlinghose', u'clearning', u'clementina', u'clementina']
# [u'colma']
# [u'commnity']
# [u'connelly', u'connolly']
# [u'conservatorship']
# [u'consmer']
# [u'contribtion']
# [u'contribtion']
# [u'conway', u'conway']
# [u'cordova']
# [u'bondries']
# [u'conseling']
# [u'assesor']
# [u'cort', u'cort', u'cort', u'cort', u'cort', u'cort', u'cort', u'cort']
# [u'cort']
# [u'reqests']
# [u'haight']
# [u'san']
# [u'rae']
# [u'san']
# [u'san']
# [u'san']
# [u'pland']
# [u'benito', u'crblines', u'crblines']
# [u'crtiss', u'pratt']
# [u'daniel', u'feinberg', u'daniel', u'lcas', u'daniel', u'patterson']
# [u'datm', u'datm']
# [u'david', u'chi', u'david', u'jordan', u'david', u'nale', u'david', u'olson', u'david', u'owen', u'david', u'owen', u'david', u'villaneva', u'david', u'y', u'davie', u'davis']
# [u'grop', u'dawa']
# [u'dawer', u'fazil']
# [u'denge', u'denge', u'dennis', u'herrera', u'dennis', u'niform']
# [u'derek', u'derek']
# [u'diego', u'rivera']
# [u'dilworth']
# [u'francisco']
# [u'tse']
# [u'doherty']
# [u'dolores', u'dolores']
# [u'donorstravel']
# [u'dosas']
# [u'yoth', u'doglas', u'legg']
# [u'dden']
# [u'corbett']
# [u'corbett']
# [u'corbett']
# [u'dmpl']
# [u'bradstreet']
# [u'eag']
# [u'van']
# [u'edcation']
# [u'edcation', u'edcationrate']
# [u'edcational']
# [u'edward', u'anaya', u'edward']
# [u'edward', u'effordable', u'efordable']
# [u'ellen']
# [u'ellis', u'ellis', u'ellis', u'ellis', u'ellis', u'ellis', u'ellis', u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'emily', u'lloyd']
# [u'san', u'francisco']
# [u'empolyment']
# [u'eric']
# [u'eric', u'sess', u'ermc', u'erna']
# [u'stella']
# [u'eshopping']
# [u'estoppels']
# [u'evacation', u'evacation']
# [u'evicitions']
# [u'jstice', u'cort']
# [u'fehr']
# [u'firestation']
# [u'flynn']
# [u'cort']
# [u'forrest']
# [u'fotopost']
# [u'francis', u'ngyen', u'francis']
# [u'francisco']
# [u'waldron']
# [u'indstry', u'geary']
# [u'geodatabase']
# [u'geoffrey', u'd', u'kostka', u'geoffrey', u'derrick', u'scott', u'geoffrey', u'kostka']
# [u'geoid', u'geojson']
# [u'george']
# [u'george']
# [u'george', u'washington', u'george']
# [u'georgy', u'norkin']
# [u'gordon']
# [u'gos']
# [u'sbsidized']
# [u'bdget']
# [u'graffitt']
# [u'mary', u'jng', u'mary', u'jng', u'dccc']
# [u'mateo']
# [u'matthew', u'dito', u'mattson', u'maher']
# [u'mara', u'hogan']
# [u'mavenlink', u'maximo', u'maximm']
# [u'mel', u'mrphy']
# [u'lok', u'melinda', u'weil', u'mello', u'roos']
# [u'mena']
# [u'michael', u'harris', u'michael', u'hdson', u'michael', u'lasala', u'michael', u'martinez', u'michael', u'skylar', u'michael', u'webster', u'michael', u'wong', u'michael', u'yarne', u'micheal', u'jackson']
# [u'ord', u'minh', u'van']
# [u'mintes', u'mintes']
# [u'mintes']
# [u'mintes']
# [u'mintes']
# [u'datas']
# [u'moldova', u'moldova', u'molina', u'molnar', u'moltai', u'moncler']
# [u'monment', u'monment']
# [u'moscone']
# [u'moseley']
# [u'san']
# [u'mni']
# [u'bart']
# [u'mni']
# [u'mni']
# [u'schedles']
# [u'myles', u'lennon']
# [u'naftaly']
# [u'nancy', u'jeng', u'nancy', u'jenh', u'nancy']
# [u'nargis', u'rabimova']
# [u'nargis', u'rabimova', u'nasa', u'nasdaq', u'nathan', u'hammond']
# [u'naylor']
# [u'neighbrhoods']
# [u'nexmo']
# [u'nhts', u'nicholas', u'peterson', u'nickisha', u'stephenson']
# [u'noah', u'lichtenstein']
# [u'norman', u'wong']
# [u'northrop']
# [u'nrse']
# [u'oceanview', u'poplation', u'octavia', u'octavia', u'octavia', u'octavia', u'blvd']
# [u'constrction']
# [u'orlando']
# [u'osm']
# [u'santana']
# [u'yoth']
# [u'otdoor']
# [u'parasail']
# [u'eric']
# [u'parkings', u'parkinh', u'parkinson']
# [u'dyogi']
# [u'pedes']
# [u'petersen', u'petersen']
# [u'francisco', u'pfister']
# [u'phelps', u'phenaos']
# [u'phil', u'ginsbrg', u'philantropic']
# [u'databas']
# [u'piotr']
# [u'planningneighborhoods']
# [u'plawiak']
# [u'reyes']
# [u'harris']
# [u'polk']
# [u'indstry']
# [u'prescott']
# [u'e']
# [u'reqests']
# [u'pblisher', u'pblishing']
# [u'pblishing']
# [u'peblo', u'perto']
# [u'plmonary']
# [u'prchase']
# [u'prchase']
# [u'prchases', u'prchases']
# [u'raphael', u'needleman', u'rashad', u'eid']
# [u'ralston']
# [u'raymond', u'chow']
# [u'bsinesses', u'san']
# [u'remi']
# [u'pblic']
# [u'restarant']
# [u'restarants']
# [u'francisco']
# [u'restarent']
# [u'restarants']
# [u'resrface']
# [u'rgistered', u'bsinesses', u'richard', u'johnson', u'richard']
# [u'richard']
# [u'richmond']
# [u'san']
# [u'robert', u'retana', u'robert', u'walsh']
# [u'roldan']
# [u'romania', u'rome', u'romwald', u'ron', u'conway', u'ronald', u'mcdonald']
# [u'reter']
# [u'rssell', u'rssell', u'corr']
# [u'rwpa', u'ryan', u'ryan', u'tbman', u'ryan']
# [u'lois', u'saintpetersbrg', u'saintpetrsbrg']
# [u'samson', u'chow']
# [u'bilding', u'san']
# [u'bilding']
# [u'otline']
# [u'contor', u'san']
# [u'contor', u'san']
# [u'otline']
# [u'andreas']
# [u'andreas']
# [u'andreas']
# [u'andreas', u'falt', u'san']
# [u'diego']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'san']
# [u'gdb']
# [u'san']
# [u'san']
# [u'basemap', u'san']
# [u'basemap', u'san']
# [u'basemap', u'san']
# [u'grop']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondaries', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bondary', u'san']
# [u'bilding', u'san']
# [u'bsiness', u'san']
# [u'bsinesses', u'san']
# [u'bsinesses']
# [u'censs', u'san']
# [u'bondary']
# [u'bondary']
# [u'crbs']
# [u'featre']
# [u'shapefile']
# [u'cityfeatres']
# [u'contor', u'san']
# [u'contor', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'conty', u'san']
# [u'bondaries']
# [u'bondary']
# [u'bondary']
# [u'jrisdiction']
# [u'shapefile']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u'crimendata', u'san']
# [u'san']
# [u'san']
# [u'districtsd', u'san']
# [u'dmap']
# [u'san']
# [u'grond']
# [u'san']
# [u'gbd', u'san']
# [u'san']
# [u'san']
# [u'geodatabase', u'san']
# [u'san']
# [u'gigants', u'san']
# [u'athority']
# [u'ineqality']
# [u'san']
# [u'ineqal', u'san']
# [u'ineqality', u'san']
# [u'landse', u'san']
# [u'landse', u'san']
# [u'san']
# [u'neigborhood', u'san']
# [u'neigborhoods']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline', u'san']
# [u'otline']
# [u'san']
# [u'san']
# [u'san']
# [u'poplation', u'san']
# [u'poplation', u'san']
# [u'poplation', u'san']
# [u'poplation', u'san']
# [u'tilities']
# [u'bsinesses']
# [u'residental']
# [u'restarant', u'san']
# [u'restarants']
# [u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shapefile', u'san']
# [u'shoerline']
# [u'shorline', u'san']
# [u'stadim', u'san']
# [u'niversity']
# [u'centerlines']
# [u'terrian', u'san']
# [u'torism', u'san']
# [u'volme']
# [u'francisco', u'rban', u'san']
# [u'tility']
# [u'zipcodes']
# [u'jose']
# [u'jose']
# [u'jose']
# [u'jose', u'bondary', u'san']
# [u'san', u'jose', u'gerrero']
# [u'shapefile', u'san', u'leandro']
# [u'mateo']
# [u'mateo']
# [u'mateo']
# [u'mateo']
# [u'sanfranciscoparkingmetersmapanddataset', u'sanborn', u'sanborn', u'sanborn', u'sanborn']
# [u'sanchez']
# [u'sano']
# [u'santa', u'clara', u'santa', u'clara', u'santa', u'clara', u'santa', u'clara', u'santa']
# [u'santa', u'monica', u'santiago']
# [u'reslts']
# [u'sato', u'sattelite', u'sadi']
# [u'sb272', u'scalia', u'scalia']
# [u'scanlan']
# [u'constrction', u'schneider']
# [u'scott', u'edwards', u'scott', u'wiener', u'scott', u'wiener', u'scott', u'wiener']
# [u'scott', u'wiener']
# [u'scotrfp', u'screendoor']
# [u'campos']
# [u'bart']
# [u'sfcrime']
# [u'sfmta']
# [u'sfpd']
# [u'precints', u'sfpd']
# [u'bart']
# [u'shapefile']
# [u'sharmin', u'bock', u'shana']
# [u'shevin', u'anne', u'wong']
# [u'shotspotter']
# [u'sid', u'siddiq']
# [u'sitepx']
# [u'skyler', u'vander', u'molen']
# [u'smf', u'smfta', u'smit']
# [u'solarmap']
# [u'sonia']
# [u'soth', u'san']
# [u'soth', u'san']
# [u'san']
# [u'sothern']
# [u'speef']
# [u'spendings']
# [u'francis', u'st', u'francis']
# [u'james', u'st', u'james']
# [u'stacie', u'hinman', u'stadim', u'stadim']
# [u'startp']
# [u'stella', u'cen', u'stella', u'kim', u'stephen', u'sprage']
# [u'steven', u'holland', u'steven', u'holland', u'steven', u'holland', u'stillings', u'stitt']
# [u'san', u'francisco']
# [u'cort', u'sperior', u'cort', u'sperior', u'cort']
# [u'hosing', u'spreme', u'cort', u'spreme', u'cort', u'spreme', u'cort', u'jstice', u'spreme', u'cort']
# [u'swede']
# [u'tablea']
# [u'taiwan', u'bento', u'talbot']
# [u'tanzania', u'taqeria', u'castillo', u'taqeria', u'la']
# [u'taz', u'taz']
# [u'taz981shp']
# [u'teaheeme']
# [u'ted']
# [u'tendernob', u'teng']
# [u'tera']
# [u'terain']
# [u'terry', u'francois', u'terry', u'francois']
# [u'castro']
# [u'chai']
# [u'lindsay']
# [u'raine', u'grop']
# [u'thomas', u'coates', u'thomas', u'jones']
# [u'tian']
# [u'tilly']
# [u'tka', u'tl201006075tabblock10']
# [u'waddell', u'tomales', u'tomas', u'aragon']
# [u'tommy', u'neeson']
# [u'townsend']
# [u'geary']
# [u'traffit']
# [u'levis', u'stadim', u'transportatoin']
# [u'travis', u'kalanick']
# [u'instittions', u'trstee', u'tsang']
# [u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber', u'ber']
# [u'ber', u'di', u'ber']
# [u'pandang']
# [u'california']
# [u'rinary']
# [u'rine']
# [u'vadim', u'kogan']
# [u'vallejo', u'vallejo', u'vallejo', u'vallejo', u'chapefile', u'vallejo', u'shapefile']
# [u'van', u'hwang']
# [u'vidal']
# [u'india', u'vincent', u'vincent', u'kircher']
# [u'vincent', u'kircher']
# [u'vooc']
# [u'goliath']
# [u'gide']
# [u'watr', u'watson', u'watson']
# [u'waze']
# [u'weil', u'weiner', u'weiner']
# [u'ellen', u'shaffer']
# [u'wilfred', u'bcoy', u'william', u'jeff', u'nagel', u'william', u'nagel', u'william', u'rdwill', u'williamson']
# [u'wong']
# [u'hor']
# [u'san']
# [u'san']
# [u'y8fpfbf5', u'yael']
# [u'yarne']
# [u'commnity']
# [u'san', u'francisco']
# [u'yoth']
# [u'poplations', u'yoth']
# [u'yoth']
# [u'yoth']
# [u'ziff', u'zika', u'zika']
# [u'zidwolde']
# [u'zshi']
# [u'dfsd', u'ami']
# [u'kate', u'spasde', u'kate', u'spasde', u'kate', u'spasde', u'kate', u'spasde', u'kate', u'spasde', u'kate']
# [u'mary', u'jng']
# [u'sharmin', u'bock', u'sharmon', u'bock']
# [u'airbnb', u'alain', u'gervais']
# [u'kim', u'expenditres']
# [u'harris']
# [u'harris']
# [u'hosing', u'john', u'ortiz']
# [u'ortiz', u'john', u'ortiz', u'karen']
# [u'karen']
# [u'miranda', u'nye', u'martin']
# [u'pblic']
# [u'ryan']
# [u'ryan']
# [u'ryan']
# [u'scriptscriptalert1script']
# [u'dashiell', u'hammet']
# [u'hawkins']
# [u'hawkins']
# [u'brian', u'dusseault']
# [u'fitzgerald']
# [u'san']
# [u'fitzgerald']
# [u'san']
# [u'geary']
# [u'jackson']
# [u'jackson']
# [u'jackson']
# [u'jackson']
# [u'jackson']
# [u'jackson']
# [u'jackson']
# [u'howard']
# [u'haro']
# [u'sylvan']
# [u'minna']
# [u'powell']
# [u'san']
# [u'san']
# [u'san']
# [u'san']
# [u

# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'cort']
# [u'bathymetry']
# [u'bam', u'bam', u'bam']
# [u'bcdc']
# [u'beaty', u'beaty', u'beaty', u'beaty', u'beaty']
# [u'beethoven', u'beethoven', u'beethoven']
# [u'behested', u'behested']
# [u'bella']
# [u'ceccx', u'belmonte']
# [u'walsh']
# [u'berkley', u'berkley', u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bicyle', u'bicyle']
# [u'bikeshare']
# [u'birdsm', u'birt']
# [u'blake', u'rawdin']
# [u'bleprints']
# [u'bondary']
# [u'briscoe']
# [u'btod']
# [u'bilding']
# [u'bilding']
# [u'bilding']
# [u'bilding', u'constrction']
# [u'bilding']
# [u'bilding2012']
# [u'san', u'francisco', u'bildings', u'san']
# [u'bisnesses']
# [u'tenderloin', u'brlingame']
# [u'bart']
# [u'bsiness', u'san']
# [u'san', u'francisco', u'bsinesses']
# [u'san', u'francisco', u'bsinesses']
# [u'san', u'francisco', u'bsinesses']
# [u'schedle']
# [u'carl', u'carman', u'carman', u'carman', u'carmen']
# [u'carmen']
# [u'carsharing', u'carsharing', u'casale']
# [u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'chaz']
# [u'yoth']
# [u'lo', u'christensen', u'christensen', u'christopher']
# [u'christopher', u'webster']
# [u'claremont']
# [u'cleanp', u'clearning', u'clementina', u'cliate']
# [u'commnity']
# [u'condit', u'condit', u'condit']
# [u'consmer']
# [u'taylor', u'taylor', u'taylor', u'taylor', u'taylor', u'taylor', u'taylor', u'taylor', u'taylor']
# [u'thomas', u'angelo', u'thomas', u'angelo', u'thomas', u'angelo', u'thomas', u'angelo', u'thomas', u'angelo', u'tia', u'matinez']
# [u'toby']
# [u'lewis']
# [u'lewis']
# [u'san', u'francisco']
# [u'shapefiles']
# [u'valle']
# [u'vales', u'vales', u'vales', u'valverde', u'constrction', u'valverde', u'constrction']
# [u'vassallo', u'vassallo']
# [u'wiseman']
# [u'peskin', u'aaron', u'peskin']
# [u'aaron', u'peskin', u'smmary']
# [u'aaron', u'peskin']
# [u'aaron', u'peskin']
# [u'acconting', u'acconting']
# [u'ada', u'ada', u'ada', u'ada']
# [u'adrian']
# [u'agstin', u'anda', u'agstin', u'anda', u'ahmed']
# [u'ais', u'alain', u'gervais', u'alain', u'gervais', u'alain', u'gervais', u'alain']
# [u'alzeheimers']
# [u'amblance', u'amblance']
# [u'cp', u'ami', u'ami']
# [u'santiago', u'amont']
# [u'andrew', u'rex', u'andrew', u'rex', u'andrew', u'rex']
# [u'anson', u'mooney', u'anson', u'mooney']
# [u'anthony']
# [u'antioqia', u'antonin', u'scalia']
# [u'architectre', u'architectre']
# [u'ariel', u'ariel', u'ariel', u'armin']
# [u'san', u'francisco']
# [u'apair']
# [u'adax']
# [u'aziza']
# [u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart', u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart', u'rotes', u'bart']
# [u'bart']
# [u'bart', u'shapefile', u'bart', u'shapefile', u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart', u'statios', u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart']
# [u'bart', u'bart', u'bartshape']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'mao']
# [u'cort']
# [u'bathymetry']
# [u'bam', u'bam', u'bam']
# [u'bcdc']
# [u'beaty', u'beaty', u'beaty', u'beaty', u'beaty']
# [u'beethoven', u'beethoven', u'beethoven']
# [u'behested', u'behested']
# [u'bella']
# [u'ceccx', u'belmonte']
# [u'walsh']
# [u'berkley', u'berkley', u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bernal']
# [u'bicyle', u'bicyle']
# [u'bikeshare']
# [u'birdsm', u'birt']
# [u'blake', u'rawdin']
# [u'bleprints']
# [u'bondary']
# [u'briscoe']
# [u'btod']
# [u'bilding']
# [u'bilding']
# [u'bilding']
# [u'bilding', u'constrction']
# [u'bilding']
# [u'bilding2012']
# [u'san', u'francisco', u'bildings', u'san']
# [u'bisnesses']
# [u'tenderloin', u'brlingame']
# [u'bart']
# [u'bsiness', u'san']
# [u'san', u'francisco', u'bsinesses']
# [u'san', u'francisco', u'bsinesses']
# [u'san', u'francisco', u'bsinesses']
# [u'schedle']
# [u'carl', u'carman', u'carman', u'carman', u'carmen']
# [u'carmen']
# [u'carsharing', u'carsharing', u'casale']
# [u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro', u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'castro']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'francisco']
# [u'chaz']
# [u'yoth']
# [u'lo', u'christensen', u'christensen', u'christopher']
# [u'christopher', u'webster']
# [u'claremont']
# [u'cleanp', u'clearning', u'clementina', u'cliate']
# [u'commnity']
# [u'condit', u'condit', u'condit']
# [u'consmer']
# [u'contribtion', u'contribtion']
# [u'contribtion']
# [u'conway']
# [u'copntor']
# [u'bondries']
# [u'conter']
# [u'conter']
# [u'conties']
# [u'assesor']
# [u'cort', u'cort', u'cort', u'cort', u'cort', u'cort', u'cort', u'cort']
# [u'crie', u'crim']
# [u'san']
# [u'pland']
# [u'benito', u'crbs', u'crbs']
# [u'dnn']
# [u'crtiss', u'pratt']
# [u'dangeros', u'daniel', u'feinberg', u'daniel', u'patterson', u'dashboards']
# [u'datm']
# [u'david', u'chi', u'david']
# [u'david', u'chi', u'david', u'jordan', u'david', u'jordan', u'david', u'jordan', u'david', u'jordan', u'david', u'jordan', u'david', u'jordan', u'david', u'villaneva', u'davie', u'davis']
# [u'grop', u'dawer', u'fazil', u'dawer', u'fazil', u'dawer', u'fazil']
# [u'defacation', u'defacation']
# [u'denge', u'dennis', u'herrera']
# [u'derek', u'derek']
# [u'tse']
# [u'docment']
# [u'dolores']
# [u'donorstravel']
# [u'dden']
# [u'corbett']
# [u'dmpl']
# [u'bradstreet']
# [u'edward']
# [u'edward', u'effordable']
# [u'ellen']
# [u'ellis', u'ellis', u'ellis', u'ellis', u'ellis', u'ellis', u'ellis', u'ellis', u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'ellis']
# [u'san', u'francisco']
# [u'ermc', u'erna']
# [u'stella', u'schlee']
# [u'eshopping']
# [u'evicitions']
# [u'fehr']
# [u'firestation']
# [u'francis', u'ngyen', u'francisco', u'dem', u'francisco', u'dem', u'francisco']
# [u'indstry', u'geary']
# [u'geoffrey', u'd', u'kostka', u'geoffrey', u'derrick', u'scott', u'geoffrey', u'kostka']
# [u'george']
# [u'george']
# [u'george', u'washington']
# [u'gordon']
# [u'gos']
# [u'gradates', u'gradates', u'graff', u'graff', u'graff', u'graff']
# [u'gregg', u'brans', u'greywater']
# [u'hala', u'hijazi', u'hamilton']
# [u'san']
# [u'henry', u'adams']
# [u'hilary', u'ronen', u'hilary']
# [u'histor']
# [u'holland', u'holland', u'holland', u'holliday', u'holliday']
# [u'salles']
# [u'howard', u'howth']
# [u'hmanwaste']
# [u'hyan']
# [u'incashed']

# %% [markdown]
# # important people:
# - dennis herrera , city attorney
# - aaron peskin , sf supervisor
# - jane kim , SF District 6 Supervisor
# - hilary ronen , SF District 9 supervisor
# - raymond chow , san francisco gangster/felon (high possibility)
# - Kenneth Malvar , City Sightseeing operator (high possibility)
# http://www.sfgate.com/bayarea/article/Driver-blamed-for-tour-bus-crash-in-SF-s-Union-6994435.php
#
#
# - Blake Rawdin , private MD(possibly)
# - Antonin Scalia, Supreme Court Justice (possibly)
# - charle, walton Co-Founder and Partner, Kindred Partners, LLC (possibly)
# - Henry albert , private eye doctor(possibly)
# - melanie lok , owner of mlok consulting private consulting (possibly)
# - bateman, bateman group(possibly)
# - David Owen , SF Attorney(possibly)
# - Jonah Yee, Private Eye Doctor(possibly)
# - Molly Seager, Private Therapist(possibly)
# - anson mooney(arrested)
# https://jailalert.com/arrest-records/anson-mooney-310655.html
# - alain gervais, private owner salon

# %%
#not_caught = [ '3180 18th street' , '100 church', '17th street' , '800 university avenue, palo alto, california', '17 san andreas way, san francisco' , '2631 23rd']

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF

# %%
vec=CountVectorizer(stop_words='english',analyzer='word')
X_train_counts = vec.fit_transform(word_count_sorted)
vocab = vec.get_feature_names()
nmf = NMF(n_components = 10, random_state = 1)
nmf.fit(X_train_counts)
# Out:
# NMF(alpha=0.0, beta=1, eta=0.1, init=None, l1_ratio=0.0, max_iter=200,
#   n_components=10, nls_max_iter=2000, random_state=1, shuffle=False,
#   solver='cd', sparseness=None, tol=0.0001, verbose=0)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))

# %%
print(print_top_words(nmf, clean_list, 50))
# Out:
# Topic #0:
# green space high injury corridor churches odata open spaces employment movie pedestrian inventory blocks city attorney trees data inventory curbs census tract from 460 rape unemployment home recycling schedule e curb business licenses demographic bay area fire incidents school crime assessor inventory hiv crime homeless collisions crime rate trees building footprint shapefiles pipeline homicide construction murder bridges san francisco buildings buildings land use sanfrancisco.gdb census tracts wind
# Topic #1:
# muni city lots bus stops bridges inventory business account number mental health crime trees parcels curb city boundary curb building permit neighborhood 94109 intersection active businesses odata pipeline bart human waste census neighborhoods topography bart motionloft murder resiliency income park muni sfo elections sf blocks parking crime classification budget median income open spaces business registration certificate 460 schedule a property assessment roll address cab parcels bike theft bikes emergency operate business building footprint
# Topic #2:
# nonprofit sanfrancisco.gdb property census tracts base map parcels published datasets churches historic footprint rent murder meters parcels property tax address population census block recycling foia human poop intersections san francisco dpw evictions cancer crime contours city traffic street census neighborhoods median income shapefiles garden building permits street parking parcels topo population density registered business latitude cost 311 cases historic neighborhoods pipeline elections sfopenbook park
# Topic #3:
# police energy schedule e budget energy planning commission building permit planning cases shp parking meter human waste bay parking meter construction bay area fire parking meters density street trees land-use bike routes landuse rent map of crime incidents crime sf homeless base map parking meters low income bay area 311 resilience electricity use collision pipeline shelter planning applications buildings json human waste blocks planning block parcel traffic address locator inventory demographic census 2000 blocks (no water) population
# Topic #4:
# salary transit pedestrian housing pipeline q4 school meter permit human waste parcels planning neighborhoods bike lane businesses street use topo sidewalk from 460 curbs business location murder traffic income park homeless elevation bike network avl street trees 2013 education bridges school district inspection facilities curb evictions poverty parking population employment zoning districts gentrification fte real time open homelessness bikeway network hiv construction parking meter property
# Topic #5:
# json transit streets pedestrian human waste land-use police stations odata race shoreline bart grants bayarea_bridges bart murder art dpw assessor public schools cab footprint shooting incidents data inventory published datasets population gardens poverty trees bike theft business registration certificate police fte sidewalk murder museum inclusionary housing parking meter neighborhoods homelessness parcel parks business location parcel business property college business locations land use demographics lyft
# Topic #6:
# fire incidents neighborhood transit shapefiles building permits liquor schedule e points intersection jobs open spaces bridges median income buildings eas address locator 460 schedule a city limit planning cases hiv buildings recycling restrooms foia business crime classification planning neighborhood labor pole homelessness fire groundwater point ocean school building footprints building heights shelter playground schools building streets terrain land use public schools shp homicide footprint home
# Topic #7:
# police human waste recycling census tract 460 schedule a neighborhood bay bike network pedestrian bay area police stations city limit budget terrain academy address points street muni business licenses census shapefile highway crime paving dem movie shapefile hospitals parking permit neighborhood liquor berkeley density curb streets bart short term rental city attorney performance measurement map population bicycle open spaces housing inventory published crim sfopenbook hiv pets 94124 trees
# Topic #8:
# bike employment crime employment bike theft land use bart crime sfpd incidents building permits benchmark san francisco boundary hospital shapefile kml lobbyist contacts parking bridges census neighborhoods buildings religion business land use map buisness base map school contour ethnicity budget and spending bart events shoreline green density murder population density housing inventory contracts street cleaning form 460 census block park business registration employment shoreline parcels housing trees bike theft
# Topic #9:
# businesses sweeper scheduled census block streets bart excrement taz homelessness san francisco sidewalk api sanfrancisco.gdb dpw census neighborhoods data inventory mental health payroll crimes existing commercial buildings energy performance ordinance library dataset housing inclusionary housing land use pedestrian land use shoreline median income museum parking meters dataset budget fte retail movie locations json crime fire stations murder solar retail homeless parking permits elevation building footprint library muni bike network payroll homelessness crime taxi zoning districts
# None

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(word_count_sorted)
indices = np.argsort(vectorizer.idf_)
features = vectorizer.get_feature_names()
top_n = 100
top_features = [features[i] for i in indices[:top_n]] 

print top_features
# Out:
# [u'san', u'francisco', u'street', u'city', u'business', u'data', u'shapefile', u'of', u'sf', u'census', u'building', u'map', u'parking', u'and', u'bay', u'crime', u'housing', u'water', u'bike', u'district', u'area', u'public', u'property', u'traffic', u'block', u'in', u'streets', u'food', u'income', u'population', u'by', u'car', u'code', u'campaign', u'open', u'neighborhood', u'bicycle', u'gis', u'use', u'districts', u'2015', u'community', u'tax', u'buildings', u'health', u'transit', u'school', u'park', u'fire', u'planning', u'number', u'permit', u'pipeline', u'2000', u'market', u'land', u'permits', u'2010', u'for', u'muni', u'parks', u'2014', u'bus', u'commercial', u'center', u'police', u'lines', u'parcel', u'zip', u'county', u'rent', u'311', u'sfpd', u'service', u'rate', u'facilities', u'finance', u'460', u'blocks', u'businesses', u'services', u'construction', u'zoning', u'locations', u'assessor', u'restaurant', u'schedule', u'residential', u'space', u'boundary', u'development', u'routes', u'report', u'survey', u'ca', u'no', u'network', u'neighborhoods', u'incidents', u'department']

# %%
import pickle

# %%
pickle.dump(word_count_sorted , open("word_count_sorted.p",'wb'))

# %% [markdown]
# # Recommendations:
#
# - spell corrector for mispelled words
# - recommendations for words while typing of words of correct search keywords, fuzzy matching
# - education for how to properly use the open data portal

# %% [markdown]
# To do:
#
# - create a column
# - functions to tag addresses,links, bad words things i wrote regex for
# - add to tag to column
